# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob
all_f= glob.glob('*/*Test_Pred_Copy*')
all_f
# Out:
# ['BTC-USD_H_W_D/BTC-USD_H_W_D_Test_Pred_Copy.csv',
#  'Apple-USD_H_W_D/Apple-USD_H_W_D_Test_Pred_Copy (1).csv',
#  'POWER_Point_Daily_Presure_Data/POWER_Point_Daily_Presure_Data_Test_Pred_Copy.csv',
#  'PRSA_data_2010_12_data/PRSA_data_2010_12_data_Test_Pred_Copy.csv',
#  'BeijingPM2.5_data/BeijingPM2.5_data_Test_Pred_Copy.csv',
#  'Healthy_control_heart_data/Healthy_control_heart_data_Test_Pred_Copy.csv',
#  'PM2.5_p09_data/PM2.5_p09_data_Test_Pred_Copy.csv',
#  'Daily_Sunspot_data/Daily_Sunspot_data_Test_Pred_Copy.csv',
#  'ETH-USD_H_W_D/ETH-USD_H_W_D_Test_Pred_Copy.csv',
#  'Myocardial_infarction_heart_data/Myocardial_infarction_heart_data_Test_Pred_Copy.csv',
#  'sale_uni_392_data/Sale_Uni_392_data_Test_Pred_Copy.csv',
#  'Microsoft-USD_H_W_D/Microsoft-USD_H_W_D_Test_Pred_Copy.csv',
#  'POWER_Point_Daily_WindSpeed_data/POWER_Point_Daily_WindSpeed_data_Test_Pred_Copy.csv',
#  'SunSpotMonthly_Data/SunSpotMonthly_Data_Test_Pred_Copy.csv',
# ...

# %%
fn=2
d_n=all_f[fn].split(r'/')
dn=d_n[0]
'''dn=dn.split(r'_')
dn=dn[0]+'_'+dn[1]+'_'+dn[2]+'_'+dn[3]'''
dn
# Out:
# 'POWER_Point_Daily_Presure_Data'

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)
df=li[fn]
df
# Out:
#       Unnamed: 0    BiLSTM      LSTM       GRU       CNN       RNN  Test_Data  \
# 0              0  9.240612  8.791965  9.085027  9.478303  9.535596       8.00
# 1              1  7.408661  7.327877  7.446504  7.725802  7.198324       7.14
# 2              2  6.867474  6.872184  7.078023  7.236781  6.867537       5.98
# 3              3  5.929756  5.572148  5.846037  6.009821  5.984245       5.68
# 4              4  5.653889  5.722588  5.781718  5.983895  5.945054       6.47
# ...          ...       ...       ...       ...       ...       ...        ...
# 2932        2932  7.337296  7.119522  7.295877  7.537413  7.204874       6.96
# 2933        2933  7.007779  6.969541  7.173803  7.177718  7.468309       7.26
# 2934        2934  7.580778  7.367643  7.621791  7.568272  7.581436       7.32
# 2935        2935  7.406134  7.174978  7.411148  7.520568  7.581657       8.18
# 2936        2936  8.661009  8.346705  8.585662  8.566573  8.481267      10.93
#
# ...

# %% [markdown]
# # Try

# %%
# Plot the original time series, trend, seasonal, and residual components
fig, ax = plt.subplots(5, 5, figsize=(20, 12),layout='constrained')
c1="#929591" #color code gray
c2="#000000" #color code black

d=0 # dataset index
actual='Actual Rate (USD)'
Pri='Predicted Rate (USD)'
k=2 # columns no.for model
j=7 # Actual data columns 
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[0,0].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[0,0].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh=df.iloc[:,k-1:k].columns[0]
ax[0,0].legend(fancybox=True, framealpha=0.1).set_title(subh)
ax[0,0].set_xlabel(actual,fontsize = 12,weight='bold')
ax[0,0].set_ylabel(Pri,fontsize = 12,weight='bold')


k=3
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[0,1].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[0,1].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh1=df.iloc[:,k-1:k].columns[0]
ax[0,1].legend(fancybox=True, framealpha=0.1).set_title(subh1)
ax[0,1].set_xlabel(actual,fontsize = 12,weight='bold')
ax[0,1].set_ylabel(Pri,fontsize = 12,weight='bold')


k=4
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[0,2].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[0,2].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh2=df.iloc[:,k-1:k].columns[0]
ax[0,2].legend(fancybox=True, framealpha=0.1).set_title(subh2)
ax[0,2].set_xlabel(actual,fontsize = 12,weight='bold')
ax[0,2].set_ylabel(Pri,fontsize = 12,weight='bold')


k=5
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[0,3].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[0,3].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh3=df.iloc[:,k-1:k].columns[0]
ax[0,3].legend(fancybox=True, framealpha=0.1).set_title(subh3)
ax[0,3].set_xlabel(actual,fontsize = 12,weight='bold')
ax[0,3].set_ylabel(Pri,fontsize = 12,weight='bold')


k=6
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[0,4].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[0,4].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh4=df.iloc[:,k-1:k].columns[0]
ax[0,4].legend(fancybox=True, framealpha=0.1).set_title(subh4)
ax[0,4].set_xlabel(actual,fontsize = 12,weight='bold')
ax[0,4].set_ylabel(Pri,fontsize = 12,weight='bold')



Pri1='Predicted Rate with GAB'
k=8
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[1,0].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[1,0].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[1,0].legend(fancybox=True, framealpha=0.1).set_title(subh)
ax[1,0].set_xlabel(actual,fontsize = 12,weight='bold')
ax[1,0].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=9
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[1,1].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[1,1].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[1,1].legend(fancybox=True, framealpha=0.1).set_title(subh1)
ax[1,1].set_xlabel(actual,fontsize = 12,weight='bold')
ax[1,1].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=10
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[1,2].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[1,2].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[1,2].legend(fancybox=True, framealpha=0.1).set_title(subh2)
ax[1,2].set_xlabel(actual,fontsize = 12,weight='bold')
ax[1,2].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=11
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[1,3].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[1,3].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[1,3].legend(fancybox=True, framealpha=0.1).set_title(subh3)
ax[1,3].set_xlabel(actual,fontsize = 12,weight='bold')
ax[1,3].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=12
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[1,4].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[1,4].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[1,4].legend(fancybox=True, framealpha=0.1).set_title(subh4)
ax[1,4].set_xlabel(actual,fontsize = 12,weight='bold')
ax[1,4].set_ylabel(Pri1,fontsize = 12,weight='bold')







d=1 # dataset index
actual='Actual Rate (USD)'
Pri='Predicted Rate (USD)'
k=2 # columns no.for model
j=7 # Actual data columns 
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[2,0].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[2,0].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh=df.iloc[:,k-1:k].columns[0]
ax[2,0].legend(fancybox=True, framealpha=0.1).set_title(subh)
ax[2,0].set_xlabel(actual,fontsize = 12,weight='bold')
ax[2,0].set_ylabel(Pri,fontsize = 12,weight='bold')


k=3
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[2,1].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[2,1].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh1=df.iloc[:,k-1:k].columns[0]
ax[2,1].legend(fancybox=True, framealpha=0.1).set_title(subh1)
ax[2,1].set_xlabel(actual,fontsize = 12,weight='bold')
ax[2,1].set_ylabel(Pri,fontsize = 12,weight='bold')


k=4
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[2,2].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[2,2].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh2=df.iloc[:,k-1:k].columns[0]
ax[2,2].legend(fancybox=True, framealpha=0.1).set_title(subh2)
ax[2,2].set_xlabel(actual,fontsize = 12,weight='bold')
ax[2,2].set_ylabel(Pri,fontsize = 12,weight='bold')


k=5
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[2,3].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[2,3].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh3=df.iloc[:,k-1:k].columns[0]
ax[2,3].legend(fancybox=True, framealpha=0.1).set_title(subh3)
ax[2,3].set_xlabel(actual,fontsize = 12,weight='bold')
ax[2,3].set_ylabel(Pri,fontsize = 12,weight='bold')


k=6
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[2,4].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[2,4].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
subh4=df.iloc[:,k-1:k].columns[0]
ax[2,4].legend(fancybox=True, framealpha=0.1).set_title(subh4)
ax[2,4].set_xlabel(actual,fontsize = 12,weight='bold')
ax[2,4].set_ylabel(Pri,fontsize = 12,weight='bold')



Pri1='Predicted Rate with GAB'
k=8
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[3,0].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[3,0].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[3,0].legend(fancybox=True, framealpha=0.1).set_title(subh)
ax[3,0].set_xlabel(actual,fontsize = 12,weight='bold')
ax[3,0].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=9
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[3,1].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[3,1].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[3,1].legend(fancybox=True, framealpha=0.1).set_title(subh1)
ax[3,1].set_xlabel(actual,fontsize = 12,weight='bold')
ax[3,1].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=10
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[3,2].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[3,2].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[3,2].legend(fancybox=True, framealpha=0.1).set_title(subh2)
ax[3,2].set_xlabel(actual,fontsize = 12,weight='bold')
ax[3,2].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=11
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[3,3].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[3,3].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[3,3].legend(fancybox=True, framealpha=0.1).set_title(subh3)
ax[3,3].set_xlabel(actual,fontsize = 12,weight='bold')
ax[3,3].set_ylabel(Pri1,fontsize = 12,weight='bold')


k=12
j=7
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[3,4].scatter(df.iloc[:,j-1:j] ,df.iloc[:,k-1:k], color = c1 ,  )
ax[3,4].plot([0,df.iloc[:,j-1:j].max()],[0,df.iloc[:,k-1:k].max()],color= c2,label='Actual Reference Line')
ax[3,4].legend(fancybox=True, framealpha=0.1).set_title(subh4)
ax[3,4].set_xlabel(actual,fontsize = 12,weight='bold')
ax[3,4].set_ylabel(Pri1,fontsize = 12,weight='bold')

# Add titles and axis labels
plt.suptitle('"VLSTM" Actual vs Predicted (20 Days) on 17 DataSets',fontsize = 16,weight='bold') #plot heading
# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='No.of Hourse', ylabel='PM2.5') #set lable
    """ax1.set_xlabel('Actual PM2.5',fontsize = 12,weight='bold')
    ax1.set_ylabel('Predicted PM2.5',fontsize = 12,weight='bold')"""
    for tick in ax1.get_xticklabels():#for x_lable rotation
        tick.set_rotation(0) #for x_lable rotation
#ax[.set_ylabel('PM2.5')
#plt.show()
#plt.savefig('scatter PLOT/VLSTM(1)',bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
# Out:
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ...

# %% [markdown]
# #

# %% [markdown]
# # Try

# %%
df
# Out:
#       Unnamed: 0     BiLSTM        LSTM         GRU         CNN         RNN  \
# 0              0  16.027178   442.72750   24.816677   26.169120   27.262194
# 1              1  16.109451   465.42386   24.914026   26.421274   27.366096
# 2              2  16.145426   465.49283   24.918062   26.534136   27.190266
# 3              3  16.183280   462.12918   25.128084   26.714556   27.128027
# 4              4  16.172316   450.75150   25.341780   26.862448   27.257132
# ...          ...        ...         ...         ...         ...         ...
# 2127        2127  12.430520  3041.77370  151.257100  166.508560  169.974610
# 2128        2128  12.433101  3002.78080  149.372270  164.706420  166.875210
# 2129        2129  12.438745  2836.51220  148.811250  163.788770  164.946090
# 2130        2130  12.440805  3009.07200  149.194150  163.094450  164.730820
# 2131        2131  12.439829 -1709.23540  151.972900  164.740860  167.719470
#
# ...

# %%
# Plot the original time series, trend, seasonal, and residual components
fig, ax = plt.subplots(5, 5, figsize=(20, 12),layout='constrained')
c1="#929591" #color code gray
c2="#000000" #color code black

d=0 # dataset index
actual='Actual Rate (USD)'
Pri='Predicted Rate (USD)'

k=2 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
l=0
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,0].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,0].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,0].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,0].legend(fancybox=True, framealpha=0.1)

k=3 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,1].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,1].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,1].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,1].legend(fancybox=True, framealpha=0.1)


k=4 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,2].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,2].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,2].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,2].legend(fancybox=True, framealpha=0.1)

k=5 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,3].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,3].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,3].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,3].legend(fancybox=True, framealpha=0.1)


k=6 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,4].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,4].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,4].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,4].legend(fancybox=True, framealpha=0.1)




d=1
k=2 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
l=1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,0].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,0].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,0].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,0].legend(fancybox=True, framealpha=0.1)

k=3 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,1].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,1].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,1].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,1].legend(fancybox=True, framealpha=0.1)


k=4 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,2].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,2].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,2].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,2].legend(fancybox=True, framealpha=0.1)

k=5 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,3].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,3].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,3].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,3].legend(fancybox=True, framealpha=0.1)


k=6 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,4].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,4].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,4].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,4].legend(fancybox=True, framealpha=0.1)





d=2
k=2 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
l=2
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,0].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,0].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,0].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,0].legend(fancybox=True, framealpha=0.1)


k=3 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,1].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,1].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,1].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,1].legend(fancybox=True, framealpha=0.1)


k=4 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,2].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,2].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,2].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,2].legend(fancybox=True, framealpha=0.1)

k=5 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,3].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,3].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,3].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,3].legend(fancybox=True, framealpha=0.1)


k=6 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,4].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,4].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,4].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,4].legend(fancybox=True, framealpha=0.1)



d=3
k=2 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
l=3
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,0].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,0].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,0].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,0].legend(fancybox=True, framealpha=0.1)


k=3 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,1].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,1].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,1].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,1].legend(fancybox=True, framealpha=0.1)


k=4 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,2].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,2].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,2].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,2].legend(fancybox=True, framealpha=0.1)

k=5 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,3].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,3].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,3].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,3].legend(fancybox=True, framealpha=0.1)


k=6 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,4].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,4].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,4].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,4].legend(fancybox=True, framealpha=0.1)




d=8
k=2 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
l=4
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,0].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,0].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,0].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,0].legend(fancybox=True, framealpha=0.1)


k=3 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,1].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,1].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,1].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,1].legend(fancybox=True, framealpha=0.1)


k=4 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,2].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,2].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,2].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,2].legend(fancybox=True, framealpha=0.1)

k=5 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,3].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,3].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,3].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,3].legend(fancybox=True, framealpha=0.1)


k=6 # columns no.for model
j=7 # Actual data columns 
p=k+j-1
v=all_f[d].split(r"/") #for data set name
D_n=v[0]#for data set name
df=li[d]
ax[l,4].plot(df.iloc[:,j-1:j],label ='Actual')
ax[l,4].plot(df.iloc[:,k-1:k],label='Pre_normal')
ax[l,4].plot(df.iloc[:,p-1:p],label='Pre_w_GAB')
ax[l,4].legend(fancybox=True, framealpha=0.1)

# %%
z=0 #data sets index on stored
v=all_f[z].split(r"/") #for data set name
v_n=v[1]#for data set name
D=v_n.split(r".")#for data set name
D_n=D[0]#for data set name
c1="#929591" #color code gray
c2="#000000" #color code black
fig, ax = plt.subplots(3, 3, figsize=(16 , 12),layout='constrained')

i=2

for j in range(0,3):
    for k in range(0,3):
        if i<11:
            df=li[z]
            ax[j,k].plot(df.iloc[-480:,1:2] , color = c1 , label = df.iloc[:,1:2].columns[0]+' PM2.5')
            ax[j,k].plot(df.iloc[-480:,i:i+1], color= c2, label = df.iloc[:,i:i+1].columns[0]+' PM2.5')
            #ax[2,1].set_axis_off() #blank plot off
            #ax[2,2].set_axis_off() #blank plot off
            ax[j,k].legend(fancybox=True, framealpha=0.1)
            df.reset_index()
            i+=1
        #print(i)
# Add titles and axis labels
plt.suptitle(D_n+' Actual vs Predicted (20 Days) model BY:',fontsize = 16,weight='bold') #plot heading
# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='No.of Hourse', ylabel='PM2.5') #set lable
    ax1.set_xlabel('Hours',fontsize = 12,weight='bold')
    ax1.set_ylabel('PM2.5',fontsize = 12,weight='bold')
    for tick in ax1.get_xticklabels():#for x_lable rotation
        tick.set_rotation(0) #for x_lable rotation
#plt.show()
#ax[1,2].set_axis_off()
plt.savefig('d_graph/'+D_n)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 35
#      32         tick.set_rotation(0) #for x_lable rotation
#      33 #plt.show()
#      34 #ax[1,2].set_axis_off()
# ---> 35 plt.savefig('d_graph/'+D_n)
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
# ...

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 16), layout='constrained')
c1 = "#929591" # gray
c2 = "#000000" # black

for d, df in enumerate(li):
    v = all_f[d].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    l = d
    for idx, k in enumerate(k_vals):
        ax[l, idx].plot(df.iloc[:, j - 1:j], label='Actual')
        ax[l, idx].plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax[l, idx].plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax[l, idx].legend(fancybox=True, framealpha=0.1)

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591" # gray
c2 = "#000000" # black

for d, df in enumerate(li):
    v = all_f[d].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    l = d
    for idx, k in enumerate(k_vals):
        ax[l, idx].plot(df.iloc[:, j - 1:j], label='Actual')
        ax[l, idx].plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax[l, idx].plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax[l, idx].legend(fancybox=True, framealpha=0.1)
        subh3=df.iloc[:,k-1:k].columns[0]
        ax[l, idx].set_title(f'{D_n} - {subh3}', fontsize=12)

# %%
k_vals[idx]

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591" # gray
c2 = "#000000" # black

for d, df in enumerate(li):
    v = all_f[d].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    l = d
    for idx, k in enumerate(k_vals):
        ax[l, idx].plot(df.iloc[:, j - 1:j], label='Actual')
        ax[l, idx].plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax[l, idx].plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax[l, idx].legend(fancybox=True, framealpha=0.1)
        subh3 = df.iloc[:, k-1:k].columns[0]
        ax[l, idx].set_title(f'{subh3}', fontsize=12)

        # add row-wise title
        if idx == 0:
            ax[l, idx].set_ylabel(D_n, fontsize=10, rotation=90, ha='right')

# %%
import textwrap
fig, ax = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')
c1 = "#929591" # gray
c2 = "#000000" # black

for d, df in enumerate(li):
    v = all_f[d].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    l = d
    
    for idx, k in enumerate(k_vals):
        ax[l, idx].plot(df.iloc[:, j - 1:j], label='Actual')
        ax[l, idx].plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax[l, idx].plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax[l, idx].legend(fancybox=True, framealpha=0.1)
        
        # set subplot title
        subh3 = df.iloc[:, k-1:k].columns[0]
        ax[l, idx].set_title(f'{subh3}', fontsize=12)

        # add row-wise title
        if idx == 0:
            ylabel_text = '\n'.join(textwrap.wrap(D_n, width=10))
            ax[l, idx].set_ylabel(ylabel_text, fontsize=10, rotation=90,ha='right', va='center', linespacing=2)

# %%
import textwrap
fig, ax = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')
for d, df in enumerate(li):
    v = all_f[d].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    l = d
    for idx, k in enumerate(k_vals):
        ax[l, idx].plot(df.iloc[:, j - 1:j], label='Actual')
        ax[l, idx].plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax[l, idx].plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax[l, idx].legend(fancybox=True, framealpha=0.1)
        ax[l,idx].set_xlabel('No. of Unit',fontsize = 12,weight='bold')
        ax[l,idx].set_ylabel('Pri',fontsize = 12,weight='bold')
        # set subplot title
        subh3 = df.iloc[:, k-1:k].columns[0]
        ax[l, idx].set_title(f'{subh3}', fontsize=12)

        # add row-wise title
        if idx == 0:
            ylabel_text = '\n'.join(textwrap.wrap(D_n, width=10))
            ax[l, idx].set_ylabel(ylabel_text, fontsize=10, rotation=0, ha='right', va='center', linespacing=1.5)

# %%
import textwrap
fig, axs = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')

for d, df in enumerate(li):
    v = all_f[d].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    l = d
    for idx, k in enumerate(k_vals):
        ax = axs[l, idx]
        ax.plot(df.iloc[:, j - 1:j], label='Actual')
        ax.plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax.plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax.legend(fancybox=True, framealpha=0.1)
        
        
        
        if l == 4:
            # create right y-axis label
            ax.set_xlabel('No. of shamples',fontsize=12, weight='bold')

       # if idx == 0:
            # create left y-axis label
          #  ylabel_text = '\n'.join(textwrap.wrap(D_n, width=15))
         #   ax.set_ylabel(ylabel_text, fontsize=10, rotation=90, ha='right', va='center', linespacing=1.5)
            #ax.yaxis.set_label_coords(-0.25, 0.7)
            
#minual input start
        if l == 0 and idx == 0 :
            ax.set_ylabel('BTC(USD)',fontsize=12, weight='bold')
        if l == 1 and idx == 0:
            ax.set_ylabel('USD',fontsize=12, weight='bold')
        if l == 2 and idx == 0:
            ax.set_ylabel(' pascal ',fontsize=12, weight='bold')
        if l == 3 and idx == 0:
            ax.set_ylabel('PM 2.5',fontsize=12, weight='bold')
        if l == 4 and idx == 0:
            ax.set_ylabel('PM 2.5',fontsize=12, weight='bold')
#minual input end
            
        if idx == 4:
            # create right y-axis label
            ylabel_text = '\n'.join(textwrap.wrap(D_n, width=17))
            #ax2 = ax.twinx()
            ax.set_ylabel(ylabel_text, rotation=270,fontsize=12,va='center', linespacing=1.5)
            #ax2.set_ylabel( ylabel_text, fontsize=12,  rotation=270,  va='center', linespacing=1.5)#weight='bold',
            ax.yaxis.set_label_coords(1.1, .5)
        if l == 0:
            # create right y-axis label
            ax.set_title(df.iloc[:, k-1:k].columns[0], fontsize=12)

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591"  # color code gray
c2 = "#000000"  # color code black

d = 0  # dataset index
actual = 'Actual Rate (USD)'
Pri = 'Predicted Rate (USD)'
k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]
subh = df.iloc[:, k-1:k].columns[0]
subh1 = df.iloc[:, k:k+1].columns[0]
subh2 = df.iloc[:, k+1:k+2].columns[0]
subh3 = df.iloc[:, k+2:k+3].columns[0]
subh4 = df.iloc[:, k+3:k+4].columns[0]
Pri1 = 'Predicted Rate with GAB'
subh_list = [subh, subh1, subh2, subh3, subh4]
col_list = [k, k+1, k+2, k+3, k+4]

for i in range(5):
    ax[0, i].scatter(df.iloc[:, j-1:j], df.iloc[:, col_list[i]-1:col_list[i]], color=c1)
    ax[0, i].plot([0, df.iloc[:, j-1:j].max()], [0, df.iloc[:, col_list[i]-1:col_list[i]].max()], color=c2, label='Actual Reference Line')
    ax[0, i].legend(fancybox=True, framealpha=0.1).set_title(subh_list[i])
    ax[0, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[0, i].set_ylabel(Pri, fontsize=12, weight='bold')

ax[1, 0].scatter(df.iloc[:, j-1:j], df.iloc[:, k+5:k+6], color=c1)
ax[1, 0].plot([0, df.iloc[:, j-1:j].max()], [0, df.iloc[:, k+5:k+6].max()], color=c2, label='Actual Reference Line')
ax[1, 0].legend(fancybox=True, framealpha=0.1).set_title(Pri1)
ax[1, 0].set_xlabel(actual, fontsize=12, weight='bold')
ax[1, 0].set_ylabel(Pri, fontsize=12, weight='bold')

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591"
c2 = "#000000"
d = 0
actual = 'Actual Rate (USD)'
Pri = 'Predicted Rate (USD)'
v = all_f[d].split(r"/")
D_n = v[0]
df = li[d]

for i in range(5):
    for j in range(5):
        k = i + 2
        subh = df.iloc[:, k-1:k].columns[0]
        if j == 0:
            ax[i, j].scatter(df.iloc[:, 6:7], df.iloc[:, k-1:k], color=c1)
            ax[i, j].plot([0, df.iloc[:, 6:7].max()], [0, df.iloc[:, k-1:k].max()], color=c2, label='Actual Reference Line')
            ax[i, j].legend(fancybox=True, framealpha=0.1).set_title(subh)
            ax[i, j].set_xlabel(actual, fontsize=12, weight='bold')
            ax[i, j].set_ylabel(Pri, fontsize=12, weight='bold')
        elif j == 1:
            Pri1 = 'Predicted Rate with GAB'
            k = 8
            ax[i, j].scatter(df.iloc[:, 6:7], df.iloc[:, k-1:k], color=c1)
            ax[i, j].plot([0, df.iloc[:, 6:7].max()], [0, df.iloc[:, k-1:k].max()], color=c2, label='Actual Reference Line')
            ax[i, j].legend(fancybox=True, framealpha=0.1).set_title(Pri1)
            ax[i, j].set_xlabel(actual, fontsize=12, weight='bold')
            ax[i, j].set_ylabel(Pri, fontsize=12, weight='bold')
        else:
            ax[i, j].remove()

# %% [markdown]
# #

# %%
# Plot the original time series, trend, seasonal, and residual components
fig, ax = plt.subplots(6, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591"  # color code gray
c2 = "#000000"  # color code black
d = 0 # dataset index
actual = 'Actual Rate (USD)'
Pri = 'Predicted Rate (USD)'
k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]

for i in range(5):
    k += 1
    gg=0
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[gg, i].set_ylabel(Pri, fontsize=12, weight='bold')

Pri1 = 'Predicted Rate with GAB'
k = 8
df = li[d]

for i in range(5):
    gg1=1
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg1, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg1, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg1, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg1, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[gg1, i].set_ylabel(Pri1, fontsize=12, weight='bold')
    k += 1
    
    
    
d = 1  # dataset index
actual = 'Actual Rate (USD)'
Pri = 'Predicted Rate (USD)'
k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]

for i in range(5):
    k += 1
    gg=2
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[gg, i].set_ylabel(Pri, fontsize=12, weight='bold')

Pri1 = 'Predicted Rate with GAB'
k = 8
df = li[d]

for i in range(5):
    gg1=3
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg1, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg1, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg1, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg1, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[gg1, i].set_ylabel(Pri1, fontsize=12, weight='bold')
    k += 1

    
d = 2  # dataset index
actual = 'Actual Rate (USD)'
Pri = 'Predicted Rate (USD)'
k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]

for i in range(5):
    k += 1
    gg=4
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[gg, i].set_ylabel(Pri, fontsize=12, weight='bold')

Pri1 = 'Predicted Rate with GAB'
k = 8
df = li[d]

for i in range(5):
    gg1=5
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg1, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg1, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg1, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg1, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[gg1, i].set_ylabel(Pri1, fontsize=12, weight='bold')
    k += 1

plt.tight_layout()
plt.show()
# Out:
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ...

# %% [markdown]
# # Try

# %%
import textwrap
fig, axs = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')

for l in range(len(li)):
    df = li[l]
    v = all_f[l].split(r"/")
    D_n = v[0]
    k_vals = [2, 3, 4, 5, 6]
    j = 7
    p_vals = [k + j - 1 for k in k_vals]
    
    for idx, k in enumerate(k_vals):
        ax = axs[l, idx]
        ax.plot(df.iloc[:, j - 1:j], label='Actual')
        ax.plot(df.iloc[:, k - 1:k], label='Pre_normal')
        ax.plot(df.iloc[:, p_vals[idx] - 1:p_vals[idx]], label='Pre_w_GAB')
        ax.legend(fancybox=True, framealpha=0.1)

        if l == 4:
            # create right y-axis label
            ax.set_xlabel('No. of samples',fontsize=12, weight='bold')
            
        if l == 0 and idx == 0 :
            ax.set_ylabel('BTC(USD)',fontsize=12, weight='bold')
        if l == 1 and idx == 0:
            ax.set_ylabel('USD',fontsize=12, weight='bold')
        if l == 2 and idx == 0:
            ax.set_ylabel('pascal',fontsize=12, weight='bold')
        if l == 3 and idx == 0:
            ax.set_ylabel('PM 2.5',fontsize=12, weight='bold')
        if l == 4 and idx == 0:
            ax.set_ylabel('PM 2.5',fontsize=12, weight='bold')

        if idx == 4:
            # create right y-axis label
            ylabel_text = '\n'.join(textwrap.wrap(D_n, width=17))
            ax.set_ylabel(ylabel_text, rotation=270,fontsize=12,va='center', linespacing=1.5)
            ax.yaxis.set_label_coords(1.1, .5)
        if l == 0:
            ax.set_title(df.iloc[:, k-1:k].columns[0], fontsize=12)

# %% [markdown]
# #

# %% [markdown]
# # Finel actual, pri_normal, Pri_w_GAB

# %%
import textwrap

fig, axs = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')

for row in range(5):
    vv=[0,1,2,3,4]
    dataset = li[vv[row]]
    for col, k in enumerate([2, 3, 4, 5, 6]):
        j = 7
        p_val = k + j - 1
        
        ax = axs[row, col]
        ax.plot(dataset.iloc[:, j-1:j], label='Actual')
        ax.plot(dataset.iloc[:, k-1:k], label='Pre_normal')
        ax.plot(dataset.iloc[:, p_val-1:p_val], label='Pre_w_GAB')
        ax.legend(fancybox=True, framealpha=0.1)

        if row == 4:
            ax.set_xlabel('No. of samples', fontsize=12, weight='bold')
        
        if col == 0:
            if row == 0:
                ax.set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            elif row == 1:
                ax.set_ylabel('USD', fontsize=12, weight='bold')
            elif row == 2:
                ax.set_ylabel('pascal', fontsize=12, weight='bold')
            elif row == 3 or row == 4:
                ax.set_ylabel('PM 2.5', fontsize=12, weight='bold')

        if col == 4:
            ylabel_text = '\n'.join(textwrap.wrap(all_f[vv[row]].split(r"/")[0], width=17))
            ax.set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            ax.yaxis.set_label_coords(1.1, .5)

        if row == 0:
            ax.set_title(dataset.iloc[:, k-1:k].columns[0], fontsize=12)

# %%
import textwrap

fig, axs = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')

for row in range(5):
    vv=[5,6,7,8,9]
    dataset = li[vv[row]]
    for col, k in enumerate([2, 3, 4, 5, 6]):
        j = 7
        p_val = k + j - 1
        
        ax = axs[row, col]
        ax.plot(dataset.iloc[:, j-1:j], label='Actual')
        ax.plot(dataset.iloc[:, k-1:k], label='Pre_normal')
        ax.plot(dataset.iloc[:, p_val-1:p_val], label='Pre_w_GAB')
        ax.legend(fancybox=True, framealpha=0.1)

        if row == 4:
            ax.set_xlabel('No. of samples', fontsize=12, weight='bold')
        
        if col == 0:
            if row == 0:
                ax.set_ylabel('BPM', fontsize=12, weight='bold')
            elif row == 1:
                ax.set_ylabel('PM 2.5', fontsize=12, weight='bold')
            elif row == 2:
                ax.set_ylabel('SNS MEGERS', fontsize=12, weight='bold')
            elif row == 3 :
                ax.set_ylabel('USD', fontsize=12, weight='bold')
            elif row == 4:
                ax.set_ylabel('BPM', fontsize=12, weight='bold')


        if col == 4:
            ylabel_text = '\n'.join(textwrap.wrap(all_f[vv[row]].split(r"/")[0], width=17))
            ax.set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            ax.yaxis.set_label_coords(1.1, .5)

        if row == 0:
            ax.set_title(dataset.iloc[:, k-1:k].columns[0], fontsize=12)

# %%
import textwrap

fig, axs = plt.subplots(5, 5, figsize=(22, 12), layout='constrained')

for row in range(5):
    vv=[10,11,12,13,14]
    dataset = li[vv[row]]
    for col, k in enumerate([2, 3, 4, 5, 6]):
        j = 7
        p_val = k + j - 1
        
        ax = axs[row, col]
        ax.plot(dataset.iloc[:, j-1:j], label='Actual')
        ax.plot(dataset.iloc[:, k-1:k], label='Pre_normal')
        ax.plot(dataset.iloc[:, p_val-1:p_val], label='Pre_w_GAB')
        ax.legend(fancybox=True, framealpha=0.1)

        if row == 4:
            ax.set_xlabel('No. of samples', fontsize=12, weight='bold')
        
        if col == 0:
            if row == 0:
                ax.set_ylabel('INR', fontsize=12, weight='bold')
            elif row == 1:
                ax.set_ylabel('USD', fontsize=12, weight='bold')
            elif row == 2:
                ax.set_ylabel('Km/H', fontsize=12, weight='bold')
            elif row == 3:
                ax.set_ylabel('sns magers', fontsize=12, weight='bold')
            elif row == 4:
                ax.set_ylabel('deg. C', fontsize=12, weight='bold')

        if col == 4:
            ylabel_text = '\n'.join(textwrap.wrap(all_f[vv[row]].split(r"/")[0], width=17))
            ax.set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            ax.yaxis.set_label_coords(1.1, .5)

        if row == 0:
            ax.set_title(dataset.iloc[:, k-1:k].columns[0], fontsize=12)

# %% [markdown]
# #

# %%
# Define the colors to use
GRAY = "#929591"
BLACK = "#000000"

# Set up the subplots
fig, ax = plt.subplots(5, 5, figsize=(20, 12), constrained_layout=True)

# Loop through the datasets
for i, dataset in enumerate(li):
    # Get the dataset name
    dataset_name = all_f[i].split(r"/")[0]
    
    # Get the actual rate and predicted rate columns
    actual_rate_col = dataset.columns[6]
    predicted_rate_col = dataset.columns[7]
    
    # Plot the actual vs. predicted rate scatter plot
    ax[i, 0].scatter(dataset[actual_rate_col], dataset[predicted_rate_col], color=GRAY)
    ax[i, 0].plot([0, dataset[actual_rate_col].max()], [0, dataset[predicted_rate_col].max()], color=BLACK, label='Actual Reference Line')
    ax[i, 0].legend(framealpha=0.1).set_title(predicted_rate_col)
    ax[i, 0].set_xlabel("Actual Rate (USD)", fontsize=12, weight='bold')
    ax[i, 0].set_ylabel("Predicted Rate (USD)", fontsize=12, weight='bold')

    # Loop through the columns containing the different components
    for j, component_col in enumerate(dataset.columns[8:]):
        # Plot the component scatter plot
        ax[i, j+1].scatter(dataset[actual_rate_col], dataset[component_col], color=GRAY)
        ax[i, j+1].plot([0, dataset[actual_rate_col].max()], [0, dataset[component_col].max()], color=BLACK, label='Actual Reference Line')
        ax[i, j+1].legend(framealpha=0.1).set_title(component_col)
        ax[i, j+1].set_xlabel("Actual Rate (USD)", fontsize=12, weight='bold')
        ax[i, j+1].set_ylabel("Predicted Rate (USD)", fontsize=12, weight='bold')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 18
#      15 predicted_rate_col = dataset.columns[7]
#      17 # Plot the actual vs. predicted rate scatter plot
# ---> 18 ax[i, 0].scatter(dataset[actual_rate_col], dataset[predicted_rate_col], color=GRAY)
#      19 ax[i, 0].plot([0, dataset[actual_rate_col].max()], [0, dataset[predicted_rate_col].max()], color=BLACK, label='Actual Reference Line')
#      20 ax[i, 0].legend(framealpha=0.1).set_title(predicted_rate_col)
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(5, 5, figsize=(20, 12), constrained_layout=True)
colors = ["#929591", "#000000"]

for i, col in enumerate(["Actual Rate (USD)", "Predicted Rate (USD)"]):
    for j in range(5):
        k = j + i * 5
        if k == 7:
            continue  # skip the actual data column
        ax = axs[0, j]
        df = li[0]
        subh = df.columns[k]
        ax.scatter(df.iloc[:, 6], df.iloc[:, k], color=colors[0])
        ax.plot([0, df.iloc[:, 6].max()], [0, df.iloc[:, k].max()], color=colors[1], label="Actual Reference Line")
        ax.legend(fancybox=True, framealpha=0.1).set_title(subh)
        ax.set_xlabel(col, fontsize=12, weight="bold")
        ax.set_ylabel("Predicted Rate (USD)", fontsize=12, weight="bold")

    if i == 0:
        col = "Predicted Rate with GAB"
    else:
        col = "Trend, Seasonal, and Residual Components"
    for j in range(5):
        k = j + i * 5
        ax = axs[1, j]
        df = li[0]
        subh = df.columns[k]
        ax.scatter(df.iloc[:, 6], df.iloc[:, k], color=colors[0])
        ax.plot([0, df.iloc[:, 6].max()], [0, df.iloc[:, k].max()], color=colors[1], label="Actual Reference Line")
        ax.legend(fancybox=True, framealpha=0.1).set_title(subh)
        ax.set_xlabel("Actual Rate (USD)", fontsize=12, weight="bold")
        ax.set_ylabel(col, fontsize=12, weight="bold")

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591" # color code gray
c2 = "#000000" # color code black
d = 0 # dataset index
actual = 'Actual Rate (USD)'
predicted = 'Predicted Rate (USD)'

v = all_f[d].split(r"/") # extract dataset name
D_n = v[0] # dataset name

li_col = li[d].columns # column names of dataframe
cols = li_col[6:] # columns representing components of time series data

for i, col in enumerate(cols):
    k = i + 7 # column no. for predicted values
    j = 7 # column no. for actual values
    subh = li_col[k] # subplot title

    ax[0, i].scatter(li[d].iloc[:, j], li[d].iloc[:, k], color=c1)
    ax[0, i].plot([0, li[d].iloc[:, j].max()], [0, li[d].iloc[:, k].max()], color=c2, label='Actual Reference Line')
    ax[0, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[0, i].set_xlabel(actual, fontsize=12, weight='bold')
    ax[0, i].set_ylabel(predicted, fontsize=12, weight='bold')

k = 8 # column no. for predicted values with GAB
subh = 'Predicted Rate with GAB'
ax[1, 0].scatter(li[d].iloc[:, j], li[d].iloc[:, k], color=c1)
ax[1, 0].plot([0, li[d].iloc[:, j].max()], [0, li[d].iloc[:, k].max()], color=c2, label='Actual Reference Line')
ax[1, 0].legend(fancybox=True, framealpha=0.1).set_title(subh)
ax[1, 0].set_xlabel(actual, fontsize=12, weight='bold')
ax[1, 0].set_ylabel(predicted, fontsize=12, weight='bold')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 17
#      15 k = i + 7 # column no. for predicted values
#      16 j = 7 # column no. for actual values
# ---> 17 subh = li_col[k] # subplot title
#      19 ax[0, i].scatter(li[d].iloc[:, j], li[d].iloc[:, k], color=c1)
#      20 ax[0, i].plot([0, li[d].iloc[:, j].max()], [0, li[d].iloc[:, k].max()], color=c2, label='Actual Reference Line')
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:5320, in Index.__getitem__(self, key)
#    5317 if is_integer(key) or is_float(key):
#    5318     # GH#44051 exclude bool, which would return a 2d ndarray
#    5319     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5320     return getitem(key)
#    5322 if isinstance(key, slice):
#    5323     # This case is separated from the conditional above to avoid
# ...

# %%
# Plot the original time series, trend, seasonal, and residual components
import textwrap
fig, ax = plt.subplots(6, 5, figsize=(20, 12), layout='constrained')
c1 = "#929591"  # color code gray
c2 = "#000000"  # color code black
d = 0 # dataset index

k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]

for i in range(5):
    k += 1
    gg=0
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg, 0].set_ylabel('Pridicted', fontsize=12, weight='bold')

k = 8
df = li[d]
for i in range(5):
    gg1=1
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg1, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg1, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg1, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    #ax[gg1, 0].set_ylabel('Prid_GAB', fontsize=12, weight='bold')
    k += 1
    if gg1 == 1 & i==0:
        ylabel_text = '\n'.join(textwrap.wrap(D_n, width=17))
        ax.set_ylabel(ylabel_text, rotation=0, fontsize=12, va='center', linespacing=1.5)
        ax.yaxis.set_label_coords(1.1, .5)

    
    
d = d+1  # dataset index
k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]

for i in range(5):
    k += 1
    gg=2
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg, 0].set_ylabel('Pridicted', fontsize=12, weight='bold')

k = 8
df = li[d]
for i in range(5):
    gg1=3
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg1, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg1, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg1, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg1, 0].set_ylabel('Prid_GAB', fontsize=12, weight='bold')
    k += 1

    
d = d+1  # dataset index
k = 2  # columns no.for model
j = 7  # Actual data columns
v = all_f[d].split(r"/")  # for data set name
D_n = v[0]  # for data set name
df = li[d]

for i in range(5):
    k += 1
    gg=4
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg, 0].set_ylabel('Pridicted', fontsize=12, weight='bold')
k = 8
df = li[d]

for i in range(5):
    gg1=5
    subh = df.iloc[:, k - 1:k].columns[0]
    ax[gg1, i].scatter(df.iloc[:, j - 1:j], df.iloc[:, k - 1:k], color=c1)
    ax[gg1, i].plot([0, df.iloc[:, j - 1:j].max()], [0, df.iloc[:, k - 1:k].max()], color=c2, label='Actual Reference Line')
    ax[gg1, i].legend(fancybox=True, framealpha=0.1).set_title(subh)
    ax[gg1, i].set_xlabel('Actual', fontsize=12, weight='bold')
    ax[gg1, 0].set_ylabel('Prid_GAB', fontsize=12, weight='bold')
    k += 1


plt.tight_layout()
plt.show()
# Out:
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ...

# %%
+ j
# Out:
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /home/subham/.local/lib/python3.11/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ...
