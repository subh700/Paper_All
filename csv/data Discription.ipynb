# %%
### Data decribe 
import pandas as pd 
import numpy as np

import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.gridspec as gridspec
import time
#from pycaret.time_series import TSForecastingExperiment
import statsmodels.api as sm

# %%
import glob
all_f= glob.glob('Datasets/*.csv')
all_f
# Out:
# ['Datasets\\BeijingPM2.5_data.csv',
#  'Datasets\\Daily_Sunspot_data.csv',
#  'Datasets\\Healthy_control_heart_data.csv',
#  'Datasets\\Myocardial_infarction_heart_data.csv',
#  'Datasets\\PM2.5_p09_data.csv',
#  'Datasets\\POWER_Point_Daily_Presure_Data.csv',
#  'Datasets\\POWER_Point_Daily_Temperature_Data.csv',
#  'Datasets\\POWER_Point_Daily_WindSpeed_data.csv',
#  'Datasets\\PRSA_data_2010_12_data.csv',
#  'Datasets\\SunSpotMonthly_Data.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %%
#D_n=all_f[1].split('\\')[1].split('_data')[0]
li[0].describe()
# Out:
#        Train_BeigingPM2.5
# count        17520.000000
# mean            90.229966
# std             91.404991
# min              1.000000
# 25%             24.000000
# 50%             63.000000
# 75%            121.000000
# max            722.000000

# %%
df1=pd.DataFrame()
for i in range(len(all_f)):
    df=li[i]
    D_n=all_f[i].split('\\')[1].split('_data')[0]
    df1[D_n]=df.describe()
df1=df1.T    
df1.to_csv('Describe.csv')

# %%
li[0]
# Out:
#        Train_BeigingPM2.5
# 0                      53
# 1                      65
# 2                      70
# 3                      79
# 4                      92
# ...                   ...
# 17515                 133
# 17516                 169
# 17517                 203
# 17518                 212
# 17519                 235
#
# [17520 rows x 1 columns]

# %%
Greenfig, ax = plt.subplots(10, 4, figsize=(20 , 30),layout='constrained')
i=0
j=0

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df.index, df[df.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:1920,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
# ax[j,3].tsaplots.plot_acf(df, lags=24)
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])

ax[j,0].set_title('Orignal',fontsize = 14,weight='bold')
ax[j,1].set_title('Seasonal',fontsize = 14,weight='bold')
ax[j,2].set_title('Trand',fontsize = 14,weight='bold')

i=1
j=1

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=25, ax=ax[j,3])


i=j=2
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])

i=j=3
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])


i=j=4
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])


i=j=5
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])

i=j=6
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])

i=j=7
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])

i=j=8
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[:3840,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000") 
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])



i=j=9
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=12)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
df1=df.iloc[-960:,-1:]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=12)
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[j,3])

# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='DATE', ylabel='PM2.5')
   # ax1.set_xlabel('DATE',fontsize = 14,weight='bold')
    #ax1.set_ylabel('PM2.5',fontsize = 14,weight='bold')
    for tick in ax1.get_xticklabels():
        tick.set_rotation(18)
#plt.show()
# plt.savefig('gr2_st_g',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')

# %%
Greenfig, ax = plt.subplots(10, 4, figsize=(20 , 30),layout='constrained')
i=0
j=0

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
# ax[j,3].tsaplots.plot_acf(df, lags=24)
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})

ax[j,0].set_title('Orignal',fontsize = 14,weight='bold')
ax[j,1].set_title('Seasonal',fontsize = 14,weight='bold')
ax[j,2].set_title('Trand',fontsize = 14,weight='bold')
ax[j,3].set_title('Autocorrelation',fontsize = 14,weight='bold')

i=1
j=1

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=2
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=3
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=4
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=5
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=6
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=7
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=8
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000") 
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=9
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=12)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=60, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')
# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='DATE', ylabel='PM2.5')
   # ax1.set_xlabel('DATE',fontsize = 14,weight='bold')
    #ax1.set_ylabel('PM2.5',fontsize = 14,weight='bold')
    for tick in ax1.get_xticklabels():
        tick.set_rotation(18)
#plt.show()
plt.savefig('gr2_st+acf_g=60.jpeg',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')

# %%
len(df)/4
# Out:
# 10439.25

# %%
from statsmodels.graphics import tsaplots

# Display 
fig = tsaplots.plot_acf(df, lags= 24);tsaplots.plot_acf(df, lags=24);

# %%
import statsmodels.api as sm
fig, ax = plt.subplots(1,2,figsize=(10,5))
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[0],color="#000000",vlines_kwargs={"colors": "#000000"})
sm.graphics.tsa.plot_acf(df, lags=25, ax=ax[1])

plt.show()Partial Autocorrelation

# %%
import glob
all_f= glob.glob('Origna*/*.csv')
all_f
# Out:
# ['Orignal Data\\PM2.5_p09_data.csv',
#  'Orignal Data\\PRSA_data_2010_12_data.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %%
v=all_f[1].split("\\")[1].split("_data.csv")[0]
v
# Out:
# 'PRSA_data_2010_12'

# %%
df1=li[0].iloc[:120,:]

# %%
decomposition = sm.tsa.seasonal_decompose(df1.iloc[:,-1:], model='additive',period=24)
plt.plot(df1.index, df1.iloc[:,-1:],color= "#000000" )

# %%
plt.plot(df1.index, decomposition.seasonal,color= "#000000")

# %%
plt.plot(df1.index, decomposition.trend,color= "#000000")

# %%
Greenfig, ax = plt.subplots(10, 3, figsize=(20 , 30),layout='constrained')
i=0
j=0

df=li[i]
df['DATE']=pd.to_datetime(df[df.iloc[:-1:2].columns[0]])
df=df.set_index('DATE')
df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
# ax[j,0].legend(fancybox=True, framealpha=0.1).set_title(D_n)
ax[j,0].set_ylabel(D_n,fontsize = 14,weight='bold')
ax[j,0].set_title('Orignal',fontsize = 14,weight='bold')
# ax[j,0].spines['top'].set_color('red') 
# ax[j,0].spines['top'].set_linewidth(3) 

ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
# ax[j,1].legend(fancybox=True, framealpha=0.7).set_title(D_n)
ax[j,1].set_title('Seasonal',fontsize = 14,weight='bold')
# ax[j,1].spines['top'].set_color('red')
# ax[j,1].spines['top'].set_linewidth(3)

ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
# ax[j,2].legend(fancybox=True, framealpha=0.1).set_title(D_n)
# ax[j,2].set_ylabel('Trand',fontsize = 14,weight='bold')
ax[j,2].set_title('Trand',fontsize = 14,weight='bold')
# ax[j,2].spines['top'].set_color('red')
# ax[j,2].spines['top'].set_linewidth(3)





i=1
j=1

df=li[i]
df['DATE']=pd.to_datetime(df[df.iloc[:-1:2].columns[0]])
df=df.set_index('DATE')
df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 14,weight='bold')

ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")

ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")




# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='DATE', ylabel='PM2.5')
   # ax1.set_xlabel('DATE',fontsize = 14,weight='bold')
    #ax1.set_ylabel('PM2.5',fontsize = 14,weight='bold')
    for tick in ax1.get_xticklabels():
        tick.set_rotation(18)
#plt.show()

# %%
df.iloc[:-1:].columns[0]
# Out:
# 'date'

# %%
df1
# Out:
#                      PM2_5
# DATE
# 2019-11-10 01:00:00  44.07
# 2019-11-10 02:00:00  41.68
# 2019-11-10 03:00:00  63.87
# 2019-11-10 04:00:00  56.16
# 2019-11-10 05:00:00  51.03
# ...                    ...
# 2019-11-29 20:00:00  19.57
# 2019-11-29 21:00:00  18.26
# 2019-11-29 22:00:00  25.52
# 2019-11-29 23:00:00  25.55
# 2019-11-30 00:00:00  24.51
#
# [480 rows x 1 columns]
