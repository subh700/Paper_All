# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import textwrap
import os

# %%
import glob
all_f= glob.glob('*/*_LOSS.csv')
all_f
# Out:
# ['BTC-USD_H_W_D/BTC-USD_H_W_D_ALL_LOSS.csv',
#  'BTC-USD_H_W_D/BTC-USD_H_W_D_ALL_VAL_LOSS.csv',
#  'Apple-USD_H_W_D/Apple-USD_H_W_D_ALL_VAL_LOSS.csv',
#  'Apple-USD_H_W_D/Apple-USD_H_W_D_ALL_LOSS.csv',
#  'POWER_Point_Daily_Presure_Data/POWER_Point_Daily_Presure_Data_ALL_VAL_LOSS.csv',
#  'POWER_Point_Daily_Presure_Data/POWER_Point_Daily_Presure_Data_ALL_LOSS.csv',
#  'PRSA_data_2010_12_data/PRSA_data_2010_12_data_ALL_VAL_LOSS.csv',
#  'PRSA_data_2010_12_data/PRSA_data_2010_12_data_ALL_LOSS.csv',
#  'BeijingPM2.5_data/BeijingPM2.5_data_ALL_VAL_LOSS.csv',
#  'BeijingPM2.5_data/BeijingPM2.5_data_ALL_LOSS.csv',
#  'Healthy_control_heart_data/Healthy_control_heart_data_ALL_VAL_LOSS.csv',
#  'Healthy_control_heart_data/Healthy_control_heart_data_ALL_LOSS.csv',
#  'PM2.5_p09_data/PM2.5_p09_data_ALL_LOSS.csv',
#  'PM2.5_p09_data/PM2.5_p09_data_ALL_VAL_LOSS.csv',
#  'Daily_Sunspot_data/Daily_Sunspot_data_ALL_LOSS.csv',
#  'Daily_Sunspot_data/Daily_Sunspot_data_ALL_VAL_LOSS.csv',
# ...

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %% [markdown]
# #

# %% [markdown]
# a=1
# if all_f[a].split(r'_')[-2] == 'ALL':
#     loss=li[a]
# elif all_f[a].split(r'_')[-2] == 'VAL':
#     V_loss=li[a]

# %%
a=1
if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
    if all_f[a].split(r'_')[-2] == 'ALL':
        loss=li[a]
        print(all_f[a].split(r'/')[1])
    elif all_f[a].split(r'_')[-2] == 'VAL':
        V_loss=li[a]
        print(all_f[a].split(r'/')[1])
    if all_f[a+1].split(r'_')[-2]=='VAL':
        V_loss=li[a+1]
        print(all_f[a+1].split(r'/')[1])
    elif all_f[a+1].split(r'_')[-2] == 'ALL':
        loss=li[a+1]
        print(all_f[a+1].split(r'/')[1])
else:
    if all_f[a].split(r'_')[-2] == 'ALL':
        loss=li[a]
        print(all_f[a].split(r'/')[1])
    elif all_f[a].split(r'_')[-2] == 'VAL':
        V_loss=li[a]
        print(all_f[a].split(r'/')[1])
    if all_f[a-1].split(r'_')[-2]=='VAL':
        V_loss=li[a-1]
        print(all_f[a-1].split(r'/')[1])
    elif all_f[a-1].split(r'_')[-2] == 'ALL':
        loss=li[a-1]
        print(all_f[a-1].split(r'/')[1])
# Out:
# BTC-USD_H_W_D_ALL_VAL_LOSS.csv
# BTC-USD_H_W_D_ALL_LOSS.csv

# %%
for dd in range(28):
    a=dd
    d_n=all_f[a].split(r'/')
    dn=d_n[0]
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss=li[a]
            print(all_f[a].split(r'/')[1])
        elif all_f[a].split(r'_')[-2] == 'VAL':
            V_loss=li[a]
            print(all_f[a].split(r'/')[1])
        if all_f[a+1].split(r'_')[-2]=='VAL':
            V_loss=li[a+1]
            print(all_f[a+1].split(r'/')[1])
        elif all_f[a+1].split(r'_')[-2] == 'ALL':
            loss=li[a+1]
            print(all_f[a+1].split(r'/')[1])
    else:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss=li[a]
            print(all_f[a].split(r'/')[1])
        elif all_f[a].split(r'_')[-2] == 'VAL':
            V_loss=li[a]
            print(all_f[a].split(r'/')[1])
        if all_f[a-1].split(r'_')[-2]=='VAL':
            V_loss=li[a-1]
            print(all_f[a-1].split(r'/')[1])
        elif all_f[a-1].split(r'_')[-2] == 'ALL':
            loss=li[a-1]
            print(all_f[a-1].split(r'/')[1])
    
    plt.plot(V_loss.iloc[:,5:6].dropna(),color='red',label='v_loss')
    plt.plot(loss.iloc[:,5:6].dropna(),label='loss')
    plt.legend(loc="best")
    plt.savefig('LOSS/'+dn+'_'+loss.iloc[:,5:6].columns[0]+'.png',bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
    plt.cla()
    plt.plot(V_loss.iloc[:,1:2].dropna(),color='red',label='v_loss')
    plt.plot(loss.iloc[:,1:2].dropna(),label='loss')
    plt.legend(loc="best")
    plt.savefig('LOSS/'+dn+'_'+loss.iloc[:,1:2].columns[0]+'.png',bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
    plt.cla()
    plt.plot(V_loss.iloc[:,2:3].dropna(),color='red',label='v_loss')
    plt.plot(loss.iloc[:,2:3].dropna(),label='loss')
    plt.legend(loc="best")
    plt.savefig('LOSS/'+dn+'_'+loss.iloc[:,2:3].columns[0]+'.png',bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
    plt.cla()
    plt.plot(V_loss.iloc[:,3:4].dropna(),color='red',label='v_loss')
    plt.plot(loss.iloc[:,3:4].dropna(),label='loss')
    plt.legend(loc="best")
    plt.savefig('LOSS/'+dn+'_'+loss.iloc[:,3:4].columns[0]+'.png',bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
    plt.cla()
    plt.plot(V_loss.iloc[:,4:5].dropna(),color='red',label='v_loss')
    plt.plot(loss.iloc[:,4:5].dropna(),label='loss')
    plt.legend(loc="best")
    plt.savefig('LOSS/'+dn+'_'+loss.iloc[:,4:5].columns[0]+'.png',bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
    plt.cla()
# Out:
# BTC-USD_H_W_D_ALL_LOSS.csv
# BTC-USD_H_W_D_ALL_VAL_LOSS.csv
# BTC-USD_H_W_D_ALL_VAL_LOSS.csv
# BTC-USD_H_W_D_ALL_LOSS.csv
# Apple-USD_H_W_D_ALL_VAL_LOSS.csv
# Apple-USD_H_W_D_ALL_LOSS.csv
# Apple-USD_H_W_D_ALL_LOSS.csv
# Apple-USD_H_W_D_ALL_VAL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_VAL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_VAL_LOSS.csv
# PRSA_data_2010_12_data_ALL_VAL_LOSS.csv
# PRSA_data_2010_12_data_ALL_LOSS.csv
# PRSA_data_2010_12_data_ALL_LOSS.csv
# PRSA_data_2010_12_data_ALL_VAL_LOSS.csv
# BeijingPM2.5_data_ALL_VAL_LOSS.csv
# BeijingPM2.5_data_ALL_LOSS.csv
# BeijingPM2.5_data_ALL_LOSS.csv
# BeijingPM2.5_data_ALL_VAL_LOSS.csv
# Healthy_control_heart_data_ALL_VAL_LOSS.csv
# Healthy_control_heart_data_ALL_LOSS.csv
# Healthy_control_heart_data_ALL_LOSS.csv
# Healthy_control_heart_data_ALL_VAL_LOSS.csv
# PM2.5_p09_data_ALL_LOSS.csv
# PM2.5_p09_data_ALL_VAL_LOSS.csv
# ...

# %%
loss
# Out:
#     Unnamed: 0    LSTM_LOSS  GRU_LOSS  CNN_LOSS  RNN_LOSS  BiLSTM_LOSS
# 0            0     2.997582  1.145930  0.455709  0.957959     0.602249
# 1            1  4431.410156  0.841452  0.045119  0.888229     0.209190
# 2            2     2.021496  0.065854  0.024499  1.238809     0.097629
# 3            3     0.770770  0.117422  0.023269  0.565113     0.028415
# 4            4    17.223743  0.036033  0.028046  0.294270     0.029801
# ..         ...          ...       ...       ...       ...          ...
# 56          56          NaN       NaN       NaN       NaN     0.012147
# 57          57          NaN       NaN       NaN       NaN     0.010383
# 58          58          NaN       NaN       NaN       NaN     0.007335
# 59          59          NaN       NaN       NaN       NaN     0.009039
# 60          60          NaN       NaN       NaN       NaN     0.018475
#
# [61 rows x 6 columns]

# %%
V_loss
# Out:
#     Unnamed: 0  LSTM_VAL_LOSS  GRU_VAL_LOSS  CNN_VAL_LOSS  RNN_VAL_LOSS  \
# 0            0   2.448242e+01    181.685532      3.162215      9.039866
# 1            1   2.159865e+01     81.126976      1.688685      0.945031
# 2            2   1.977416e+01      4.135346      0.421739     15.738980
# 3            3   5.194667e+01      4.039112      0.363788      0.731440
# 4            4   2.948099e+06      1.143834      0.323904      1.799679
# ..         ...            ...           ...           ...           ...
# 56          56            NaN           NaN           NaN           NaN
# 57          57            NaN           NaN           NaN           NaN
# 58          58            NaN           NaN           NaN           NaN
# 59          59            NaN           NaN           NaN           NaN
# 60          60            NaN           NaN           NaN           NaN
#
#     BiLSTM_VAL_LOSS
# 0         16.938540
# 1         20.679054
# 2         13.960411
# ...

# %%
plt.plot(V_loss.iloc[:,5:6].dropna(),color='red')
plt.plot(loss.iloc[:,5:6].dropna())

# %%
os.mkdir('LOSS')

# %%
fig, axs = plt.subplots(14, 5, figsize=(22, 12), layout='constrained')
for dd in range(28):
    a=dd
    d_n=all_f[a].split(r'/')
    dn=d_n[0]
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss=li[a]
            print(all_f[a].split(r'/')[1])
            if all_f[a+1].split(r'_')[-2]=='VAL':
                V_loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
            else:
                loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
        else:
            V_loss=li[a]
            print(all_f[a].split(r'/')[1])
            if all_f[a+1].split(r'_')[-2]=='VAL':
                V_loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
            else:
                loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
        
        for col in range(5):
            ax=axs[dd,col]
            ax.plot(V_loss.iloc[:,col+1:col+2].dropna(),color='red')
            ax.plot(loss.iloc[:,col+1:col+2].dropna())
# Out:
# BTC-USD_H_W_D_ALL_LOSS.csv
# BTC-USD_H_W_D_ALL_VAL_LOSS.csv
# Apple-USD_H_W_D_ALL_VAL_LOSS.csv
# Apple-USD_H_W_D_ALL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_VAL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_LOSS.csv
# PRSA_data_2010_12_data_ALL_VAL_LOSS.csv
# PRSA_data_2010_12_data_ALL_LOSS.csv
# BeijingPM2.5_data_ALL_VAL_LOSS.csv
# BeijingPM2.5_data_ALL_LOSS.csv
# Healthy_control_heart_data_ALL_VAL_LOSS.csv
# Healthy_control_heart_data_ALL_LOSS.csv
# PM2.5_p09_data_ALL_LOSS.csv
# PM2.5_p09_data_ALL_VAL_LOSS.csv
# Daily_Sunspot_data_ALL_LOSS.csv
# Daily_Sunspot_data_ALL_VAL_LOSS.csv
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 27
#      24         print(all_f[a+1].split(r'/')[1])
#      26 for col in range(5):
# ---> 27     ax=axs[dd,col]
#      28     ax.plot(V_loss.iloc[:,col+1:col+2].dropna(),color='red')
# ...

# %%
for i=1:
# Out:
#   Cell In[34], line 1
#     for i==1:
#          ^
# SyntaxError: invalid syntax

# %%
fig, axs = plt.subplots(14, 5, figsize=(22, 12), layout='constrained')

for dd in range(0,28,2):
    a=dd
    d_n=all_f[a].split(r'/')
    dn=d_n[0]
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss=li[a]
            print(all_f[a].split(r'/')[1])
            if all_f[a+1].split(r'_')[-2]=='VAL':
                V_loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
            else:
                loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
        else:
            V_loss=li[a]
            print(all_f[a].split(r'/')[1])
            if all_f[a+1].split(r'_')[-2]=='VAL':
                V_loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
            else:
                loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
        for row in range(0,14):
            for col in range(5):
                ax=axs[row,col]
                ax.plot(V_loss.iloc[:,col+1:col+2].dropna(),color='red')
                ax.plot(loss.iloc[:,col+1:col+2].dropna())
            row +=2
# Out:
# BTC-USD_H_W_D_ALL_LOSS.csv
# BTC-USD_H_W_D_ALL_VAL_LOSS.csv
# Apple-USD_H_W_D_ALL_VAL_LOSS.csv
# Apple-USD_H_W_D_ALL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_VAL_LOSS.csv
# POWER_Point_Daily_Presure_Data_ALL_LOSS.csv
# PRSA_data_2010_12_data_ALL_VAL_LOSS.csv
# PRSA_data_2010_12_data_ALL_LOSS.csv
# BeijingPM2.5_data_ALL_VAL_LOSS.csv
# BeijingPM2.5_data_ALL_LOSS.csv
# Healthy_control_heart_data_ALL_VAL_LOSS.csv
# Healthy_control_heart_data_ALL_LOSS.csv
# PM2.5_p09_data_ALL_LOSS.csv
# PM2.5_p09_data_ALL_VAL_LOSS.csv
# Daily_Sunspot_data_ALL_LOSS.csv
# Daily_Sunspot_data_ALL_VAL_LOSS.csv
# ETH-USD_H_W_D_ALL_LOSS.csv
# ETH-USD_H_W_D_ALL_VAL_LOSS.csv
# Myocardial_infarction_heart_data_ALL_LOSS.csv
# Myocardial_infarction_heart_data_ALL_VAL_LOSS.csv
# Sale_Uni_392_data_ALL_VAL_LOSS.csv
# Sale_Uni_392_data_ALL_LOSS.csv
# Microsoft-USD_H_W_D_ALL_VAL_LOSS.csv
# Microsoft-USD_H_W_D_ALL_LOSS.csv
# POWER_Point_Daily_WindSpeed_data_ALL_VAL_LOSS.csv
# ...

# %%
fig, axs = plt.subplots(7, 5, figsize=(22, 12), layout='constrained')

for dd in range(0,28,2):
    a=dd
    d_n=all_f[a].split(r'/')
    dn=d_n[0]
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss=li[a]
            print(all_f[a].split(r'/')[1])
            if all_f[a+1].split(r'_')[-2]=='VAL':
                V_loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
            else:
                loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
        else:
            V_loss=li[a]
            print(all_f[a].split(r'/')[1])
            if all_f[a+1].split(r'_')[-2]=='VAL':
                V_loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
            else:
                loss=li[a+1]
                print(all_f[a+1].split(r'/')[1])
        df=pd.concat([loss, V_loss], axis=1)
        #print(df)
        plt.plot(df.iloc[:,1:6])
        plt.plot(df.iloc[:,8:])
        plt.legend(fancybox=True,framealpha=1)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
df.head(45)
# Out:
#     Unnamed: 0  LSTM_LOSS  GRU_LOSS  CNN_LOSS  RNN_LOSS  BiLSTM_LOSS  \
# 0            0   1.278101  1.611576  0.411202  0.522326     1.383736
# 1            1   0.278400  0.232434  0.215248  0.181384     0.261174
# 2            2   0.191887  0.189454  0.197681  0.163050     0.216593
# 3            3   0.193401  0.172049  0.186327  0.163321     0.193244
# 4            4   0.179568  0.166491  0.175829  0.162533     0.178486
# 5            5   0.172471  0.163215  0.167107  0.159690     0.175217
# 6            6   0.163579  0.161040  0.160981  0.156266     0.174887
# 7            7   0.164646  0.159584  0.157263  0.153222     0.176434
# 8            8   0.161541  0.158560  0.155140  0.152313     0.177872
# 9            9   0.160454  0.157978  0.153910  0.149296     0.177429
# 10          10   0.159561  0.157519  0.153180  0.147665     0.173899
# 11          11   0.157997  0.157138  0.152747  0.145803     0.169032
# 12          12   0.157273  0.156798  0.152507  0.146353     0.165146
# ...

# %%
os.mkdir('su')

# %%
# Loop over range of 28
for dd in range(0,28,2):
    a = dd
    d_n = all_f[a].split(r'/')
    dn = d_n[0]
    
    # Get loss and validation loss dataframes
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a+1].split(r'_')[-2]=='VAL':
            val_loss_df = li[a+1]
        elif all_f[a+1].split(r'_')[-2] == 'ALL':
            loss_df = li[a+1]
    else:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a-1].split(r'_')[-2]=='VAL':
            val_loss_df = li[a-1]
        elif all_f[a-1].split(r'_')[-2] == 'ALL':
            loss_df = li[a-1]
    
    # Plot and save loss and validation loss plots
    for i in range(1, 6):
        plt.plot(val_loss_df.iloc[:,i], color='red', label='v_loss')
        plt.plot(loss_df.iloc[:,i], label='loss')
        plt.legend(loc='best')
        plt.savefig(f'su/{dn}_{loss_df.iloc[:,i-1:i].columns[0]}.png', bbox_inches='tight', pad_inches=0.1, transparent=False, facecolor='w', edgecolor='w', orientation='landscape')
        plt.cla()

# %%
fig, axs = plt.subplots(14, 5, figsize=(22, 12), layout='constrained')
fig.subplots_adjust(right=0.8) # Add space for legend
# Loop over range of 28
for dd in range(0,28,2):
    a = dd
    d_n = all_f[a].split(r'/')
    dn = d_n[0]
    
    # Get loss and validation loss dataframes
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a+1].split(r'_')[-2]=='VAL':
            val_loss_df = li[a+1]
        elif all_f[a+1].split(r'_')[-2] == 'ALL':
            loss_df = li[a+1]
    else:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a-1].split(r'_')[-2]=='VAL':
            val_loss_df = li[a-1]
        elif all_f[a-1].split(r'_')[-2] == 'ALL':
            loss_df = li[a-1]
    for j in range(14):
    # Plot and save loss and validation loss plots
        for k in range(5):
            for i in range(1, 6):
                ax=axs[j,k]
                ax.plot(val_loss_df.iloc[:,i], color='red', label='v_loss')
                ax.plot(loss_df.iloc[:,i], label='loss')
                ax.legend(loc='best')
            ax.cla()
# Out:
# /tmp/ipykernel_4270/269045089.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend

# %% [markdown]
# #

# %%
fig, axs = plt.subplots(6, 5, figsize=(22, 12), layout='constrained')
fig.subplots_adjust(right=0.8) # Add space for legend
# Loop over range of 28
loss_df_list = []
name = []
v_loss=[]
for dd in range(0,28,2):
    a = dd
    d_n = all_f[a].split(r'/')
    dn = d_n[0]
    
    # Get loss and validation loss dataframes
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a+1].split(r'_')[-2]=='VAL':
            val_loss_df = li[a+1]
        elif all_f[a+1].split(r'_')[-2] == 'ALL':
            loss_df = li[a+1]
    else:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a-1].split(r'_')[-2]=='VAL':
            val_loss_df = li[a-1]
        elif all_f[a-1].split(r'_')[-2] == 'ALL':
            loss_df = li[a-1]
    #print(loss_df)
    #print(dn)
    #print(val_loss_df)
    v_loss.append(val_loss_df)
    loss_df_list.append(loss_df)
    name.append(dn)

for mn in range(0,6,2):
    for co in range(0,5):
        
        axs[mn,co].plot(loss_df_list[mn].iloc[:,1:6].dropna(), label=loss_df_list[mn].iloc[:,1:6].columns)
        #axs[mn,co].plot(loss_df_list[mn].iloc[:,2:3].dropna(), label=loss_df_list[mn].iloc[:,2:3].columns[0])
        #axs[mn,co].plot(loss_df_list[mn].iloc[:,3:4].dropna(), label=loss_df_list[mn].iloc[:,3:4].columns[0])
        #axs[mn,co].plot(loss_df_list[mn].iloc[:,4:5].dropna(), label=loss_df_list[mn].iloc[:,4:5].columns[0])
        #axs[mn,co].plot(loss_df_list[mn].iloc[:,5:6].dropna(), label=loss_df_list[mn].iloc[:,5:6].columns[0])
        axs[mn,co].legend()
        axs[mn+1,co].plot(v_loss[mn].iloc[:,1:6].dropna(), label=v_loss[mn].iloc[:,1:6].columns)
        #axs[mn+1,co].plot(v_loss[mn].iloc[:,2:3].dropna(), label=v_loss[mn].iloc[:,2:3].columns[0])
        #axs[mn+1,co].plot(v_loss[mn].iloc[:,3:4].dropna(), label=v_loss[mn].iloc[:,3:4].columns[0])
        #axs[mn+1,co].plot(v_loss[mn].iloc[:,4:5].dropna(), label=v_loss[mn].iloc[:,4:5].columns[0])
        #axs[mn+1,co].plot(v_loss[mn].iloc[:,5:6].dropna(), label=v_loss[mn].iloc[:,5:6].columns[0])
        axs[mn+1,co].legend()
        #axs[mn,1].plot(val_loss_df)
    #for r in range(6):
        #c=0
        
        #axs[r,c].plot(loss_df.iloc[:,1:2].dropna(),label=loss_df.iloc[:,1:2].columns[0])
        #axs[r,c].plot(loss_df.iloc[:,2:3].dropna(),label=loss_df.iloc[:,2:3].columns[0])
        #axs[r,c].plot(loss_df.iloc[:,3:4].dropna(),label=loss_df.iloc[:,3:4].columns[0])
        #axs[r,c].plot(loss_df.iloc[:,4:5].dropna(),label=loss_df.iloc[:,4:5].columns[0])
        #axs[r,c].plot(loss_df.iloc[:,5:6].dropna(),label=loss_df.iloc[:,5:6].columns[0])
        #axs[r,c].legend()
        #axs[r,c+1].plot(val_loss_df.iloc[:,1:2].dropna(),label=val_loss_df.iloc[:,1:2].columns[0])
        #axs[r,c+1].plot(val_loss_df.iloc[:,2:3].dropna(),label=val_loss_df.iloc[:,2:3].columns[0])
        #axs[r,c+1].plot(val_loss_df.iloc[:,3:4].dropna(),label=val_loss_df.iloc[:,3:4].columns[0])
        #axs[r,c+1].plot(val_loss_df.iloc[:,4:5].dropna(),label=val_loss_df.iloc[:,4:5].columns[0])
        #axs[r,c+1].plot(val_loss_df.iloc[:,5:6].dropna(),label=val_loss_df.iloc[:,5:6].columns[0])
        #axs[r,c+1].legend()
# Out:
# /tmp/ipykernel_4270/1845097672.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend

# %%
fig, axs = plt.subplots(6, 5, figsize=(22, 12), constrained_layout=True)
fig.subplots_adjust(right=0.8) # Add space for legend

# Loop over range of 28
loss_df_list = []
name = []
v_loss = []

for dd in range(0, 28, 2):
    a = dd
    d_n = all_f[a].split(r'/')
    dn = d_n[0]
    
    # Get loss and validation loss dataframes
    if all_f[a].split(r'/')[0] == all_f[a+1].split(r'/')[0]:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a+1].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a+1]
        elif all_f[a+1].split(r'_')[-2] == 'ALL':
            loss_df = li[a+1]
    else:
        if all_f[a].split(r'_')[-2] == 'ALL':
            loss_df = li[a]
        elif all_f[a].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a]
        if all_f[a-1].split(r'_')[-2] == 'VAL':
            val_loss_df = li[a-1]
        elif all_f[a-1].split(r'_')[-2] == 'ALL':
            loss_df = li[a-1]
    
    v_loss.append(val_loss_df)
    loss_df_list.append(loss_df)
    name.append(dn)

for mn, row in enumerate(axs[::2]):
    for co, ax in enumerate(row):
        ax.plot(loss_df_list[mn].iloc[:,1:6].dropna(), label=loss_df_list[mn].iloc[:,1:6].columns)
        ax.legend()
        
        ax2 = axs[mn+1,co]
        ax2.plot(v_loss[mn].iloc[:,1:6].dropna(), label=v_loss[mn].iloc[:,1:6].columns)
        ax2.legend()
# Out:
# /tmp/ipykernel_4270/2370680655.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend

# %%
fig, axs = plt.subplots(6, 5, figsize=(22, 12), constrained_layout=True)
fig.subplots_adjust(right=0.8)  # Add space for legend

# Loop over range of 28
loss_df_list = []
name = []
v_loss = []

for dd in range(0, 28, 2):
    a = dd
    d_n = all_f[a].split('/')
    dn = d_n[0]
    # Get loss and validation loss dataframes
    if all_f[a].split('_')[-2] == 'ALL':
        loss_df = li[a]
        val_loss_df = li[a+1]
    else:
        loss_df = li[a+1]
        val_loss_df = li[a]

    v_loss.append(val_loss_df)
    loss_df_list.append(loss_df)
    name.append(dn)

for mn in range(0, 6, 2):
    for co in range(0, 5):
        axs[mn, co].plot(loss_df_list[co].iloc[:, 1:6].dropna(), label=loss_df_list[co].columns[1:6])
        axs[mn, co].legend()
        #if mn == 0 and mm==2:
        axs[mn,co].set_title(name[co], fontsize=12)
        if co == 4:
            axs[mn,co].set_ylabel('Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
            axs[mn, co].yaxis.set_label_coords(1.05, .5)
        #if co == 4:
            #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
            #axs[mn, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            #axs[mn, co].yaxis.set_label_coords(1.1, .5)
        if mn == 4:
            axs[mn+1, co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')
        #if co == 0:
            #if mn == 0:
                #axs[mn, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            #elif mn == 2:
                #axs[mn, co].set_ylabel('pascal', fontsize=12, weight='bold')
            #elif mn == 4:
                #axs[mn, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')

        axs[mn+1, co].plot(v_loss[co].iloc[:, 1:6].dropna(), label=v_loss[co].columns[1:6])
        axs[mn+1, co].legend()
        if co == 4:
            axs[mn+1,co].set_ylabel('Val_Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
            axs[mn+1, co].yaxis.set_label_coords(1.05, .5)
        #if co == 4:
            #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
            #axs[mn+1, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            #axs[mn+1, co].yaxis.set_label_coords(1.1, .5)
        if mn == 4:
            axs[mn+1,co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')
            
        #if co == 0:
            #if mn+1 == 1:
                #axs[mn+1, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            #elif mn+1 == 3:
                #axs[mn+1, co].set_ylabel('pascal', fontsize=12, weight='bold')
            #elif mn+1 == 5:
                #axs[mn+1, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')
# Add a common legend outside of the subplots
        axs[mn,co].legend().set_visible(False)
        axs[mn+1,co].legend().set_visible(False)
    
handles, labels = axs[mn,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.4, 1.04), fontsize=12, fancybox=True, framealpha=1)
        
handles, labels = axs[mn+1,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(1, 1.04), fontsize=12, fancybox=True, framealpha=1)
# Out:
# /tmp/ipykernel_60174/2582101990.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8)  # Add space for legend

# %%
fig, axs = plt.subplots(6, 5, figsize=(22, 12), constrained_layout=True)
fig.subplots_adjust(right=0.8)  # Add space for legend
i=0
# Loop over range of 28
loss_df_list = []
name = []
v_loss = []

for dd in range(0, 28, 2):
    a = dd
    d_n = all_f[a].split('/')
    dn = d_n[0]
    # Get loss and validation loss dataframes
    if all_f[a].split('_')[-2] == 'ALL':
        loss_df = li[a]
        val_loss_df = li[a+1]
    else:
        loss_df = li[a+1]
        val_loss_df = li[a]

    v_loss.append(val_loss_df)
    loss_df_list.append(loss_df)
    name.append(dn)

for mn in range(0, 6, 2):
    
    if i<11:
        for co in range(0, 5):
            axs[mn, co].plot(loss_df_list[co+i].iloc[:, 1:6].dropna(), label=loss_df_list[co+i].columns[1:6])
            axs[mn, co].legend()
            #if mn == 0 and mm==2:
            axs[mn,co].set_title(name[co+i], fontsize=12)
            if co == 4:
                axs[mn,co].set_ylabel('Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
                axs[mn, co].yaxis.set_label_coords(1.05, .5)
            #if co == 4:
                #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
                #axs[mn, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
                #axs[mn, co].yaxis.set_label_coords(1.1, .5)
            if mn == 4:
                axs[mn+1, co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')
            #if co == 0:
                #if mn == 0:
                    #axs[mn, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
                #elif mn == 2:
                    #axs[mn, co].set_ylabel('pascal', fontsize=12, weight='bold')
                #elif mn == 4:
                    #axs[mn, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')

            axs[mn+1, co].plot(v_loss[co+i].iloc[:, 1:6].dropna(), label=v_loss[co+i].columns[1:6])
            axs[mn+1, co].legend()
            if co == 4:
                axs[mn+1,co].set_ylabel('Val_Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
                axs[mn+1, co].yaxis.set_label_coords(1.05, .5)
            #if co == 4:
                #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
                #axs[mn+1, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
                #axs[mn+1, co].yaxis.set_label_coords(1.1, .5)
            if mn == 4:
                axs[mn+1,co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')

            #if co == 0:
                #if mn+1 == 1:
                    #axs[mn+1, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
                #elif mn+1 == 3:
                    #axs[mn+1, co].set_ylabel('pascal', fontsize=12, weight='bold')
                #elif mn+1 == 5:
                    #axs[mn+1, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')
    # Add a common legend outside of the subplots
            axs[mn,co].legend().set_visible(False)
            axs[mn+1,co].legend().set_visible(False)
        i +=5
        print(i)
handles, labels = axs[mn,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.4, 1.04), fontsize=12, fancybox=True, framealpha=1)
        
handles, labels = axs[mn+1,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(1, 1.04), fontsize=12, fancybox=True, framealpha=1)
# Out:
# /tmp/ipykernel_60174/3401551441.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8)  # Add space for legend
# 5
# 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 29
#      27 if i<11:
#      28     for co in range(0, 5):
# ---> 29         axs[mn, co].plot(loss_df_list[co+i].iloc[:, 1:6].dropna(), label=loss_df_list[co+i].columns[1:6])
#      30         axs[mn, co].legend()
#      31         #if mn == 0 and mm==2:
#
# IndexError: list index out of range

# %%
print(i)
# Out:
# 1

# %% [markdown]
# # sk

# %%
fig, axs = plt.subplots(6, 5, figsize=(22, 12), constrained_layout=True)
fig.subplots_adjust(right=0.8)  # Add space for legend

# Loop over range of 28
loss_df_list = []

loss_df_list1 = []
loss_df_list2 = []
loss_df_list3 = []

name = []
v_loss = []

for dd in range(0, 28, 2):
    a = dd
    d_n = all_f[a].split('/')
    dn = d_n[0]
    # Get loss and validation loss dataframes
    if all_f[a].split('_')[-2] == 'ALL':
        loss_df = li[a]
        val_loss_df = li[a+1]
    else:
        loss_df = li[a+1]
        val_loss_df = li[a]

    v_loss.append(val_loss_df)
    loss_df_list.append(loss_df)
    name.append(dn)
    
for kj in range(0,6):
    
    loss_df_list1.append(loss_df_list[kj])
for kj2 in range(6,10):
    
    loss_df_list2.append(loss_df_list[kj2])
    

for mn in range(0, 6, 2):
    
    for co in range(0, 14):
        if(co<5):
            axs[mn, co].plot(loss_df_list1[co].iloc[:, 1:6].dropna(), label=loss_df_list1[co].columns[1:6])
            axs[mn, co].legend()
            #if mn == 0 and mm==2:
            axs[mn,co].set_title(name[co], fontsize=12)
        elif(co>=5):
            axs[mn, co].plot(loss_df_list2[co].iloc[:, 1:6].dropna(), label=loss_df_list2[co].columns[1:6])
            axs[mn, co].legend()
            #if mn == 0 and mm==2:
            axs[mn,co].set_title(name[co], fontsize=12)
        
            
            
        if co == 4:
            axs[mn,co].set_ylabel('Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
            axs[mn, co].yaxis.set_label_coords(1.05, .5)
        #if co == 4:axs[mn, co].plot(loss_df_list[co].iloc[:, 1:6].dropna(), label=loss_df_list[co].columns[1:6])axs[mn, co].plot(loss_df_list[co].iloc[:, 1:6].dropna(), label=loss_df_list[co].columns[1:6])
            axs[mn, co].legend()
            #if mn == 0 and mm==2:
            axs[mn,co].set_title(name[co], fontsize=12)
            axs[mn, co].legend()
            #if mn == 0 and mm==2:
            axs[mn,co].set_title(name[co], fontsize=12)
            #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
            #axs[mn, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            #axs[mn, co].yaxis.set_label_coords(1.1, .5)
        if mn == 4:
            axs[mn+1, co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')
        #if co == 0:
            #if mn == 0:
                #axs[mn, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            #elif mn == 2:
                #axs[mn, co].set_ylabel('pascal', fontsize=12, weight='bold')
            #elif mn == 4:
                #axs[mn, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')

        axs[mn+1, co].plot(v_loss[co].iloc[:, 1:6].dropna(), label=v_loss[co].columns[1:6])
        axs[mn+1, co].legend()
        if co == 4:
            axs[mn+1,co].set_ylabel('Val_Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
            axs[mn+1, co].yaxis.set_label_coords(1.05, .5)
        #if co == 4:
            #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
            #axs[mn+1, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            #axs[mn+1, co].yaxis.set_label_coords(1.1, .5)
        if mn == 4:
            axs[mn+1,co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')
            
        #if co == 0:
            #if mn+1 == 1:
                #axs[mn+1, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            #elif mn+1 == 3:
                #axs[mn+1, co].set_ylabel('pascal', fontsize=12, weight='bold')
            #elif mn+1 == 5:
                #axs[mn+1, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')
# Add a common legend outside of the subplots
        axs[mn,co].legend().set_visible(False)
        axs[mn+1,co].legend().set_visible(False)
    
handles, labels = axs[mn,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.4, 1.04), fontsize=12, fancybox=True, framealpha=1)
        
handles, labels = axs[mn+1,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(1, 1.04), fontsize=12, fancybox=True, framealpha=1)
# Out:
# /tmp/ipykernel_60174/1658143848.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8)  # Add space for legend
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 47
#      45     axs[mn,co].set_title(name[co], fontsize=12)
#      46 elif(co>=5):
# ---> 47     axs[mn, co].plot(loss_df_list2[co].iloc[:, 1:6].dropna(), label=loss_df_list2[co].columns[1:6])
#      48     axs[mn, co].legend()
#      49     #if mn == 0 and mm==2:
#
# IndexError: index 5 is out of bounds for axis 1 with size 5

# %% [markdown]
# # sk

# %% [markdown]
# # Try

# %%
fig, axs = plt.subplots(6, 5, figsize=(22, 12), constrained_layout=True)
fig.subplots_adjust(right=0.8)  # Add space for legend

# Loop over range of 28
loss_df_list = []
name = []
v_loss = []

for dd in range(0, 28, 2):
    a = dd
    d_n = all_f[a].split('/')
    dn = d_n[0]
    # Get loss and validation loss dataframes
    if all_f[a].split('_')[-2] == 'ALL':
        loss_df = li[a]
        val_loss_df = li[a+1]
    else:
        loss_df = li[a+1]
        val_loss_df = li[a]

    v_loss.append(val_loss_df)
    loss_df_list.append(loss_df)
    name.append(dn)
for mn in range(0, 6, 2):
    for co in range(0, 5):
        axs[mn, co].plot(loss_df_list[co].iloc[:, 1:6].dropna(), label=loss_df_list[co].columns[1:6])
        axs[mn, co].legend()
        #if mn == 0 and mm==2:
        axs[mn,co].set_title(name[co], fontsize=12)
        if co == 4:
            axs[mn,co].set_ylabel('Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
            axs[mn, co].yaxis.set_label_coords(1.05, .5)
        #if co == 4:
            #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
            #axs[mn, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            #axs[mn, co].yaxis.set_label_coords(1.1, .5)
        if mn == 4:
            ax.set_xlabel('No. of Epocs', fontsize=12, weight='bold')
        if co == 0:
            if mn == 0:
                axs[mn, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            elif mn == 2:
                axs[mn, co].set_ylabel('pascal', fontsize=12, weight='bold')
            elif mn == 4:
                axs[mn, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')

        axs[mn+1, co].plot(v_loss[co].iloc[:, 1:6].dropna(), label=v_loss[co].columns[1:6])
        axs[mn+1, co].legend()
        if co == 4:
            axs[mn+1,co].set_ylabel('Val_Loss',rotation=270,fontsize=12,va='center',linespacing=1.5)
            axs[mn+1, co].yaxis.set_label_coords(1.05, .5)
        #if co == 4:
            #ylabel_text = '\n'.join(textwrap.wrap(name[mn], width=17))
            #axs[mn+1, co].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5)
            #axs[mn+1, co].yaxis.set_label_coords(1.1, .5)
        if mn == 4:
            axs[mn+1,co].set_xlabel('No. of Epocs', fontsize=12, weight='bold')
            
        if co == 0:
            if mn+1 == 1:
                axs[mn+1, co].set_ylabel('BTC(USD)', fontsize=12, weight='bold')
            elif mn+1 == 3:
                axs[mn+1, co].set_ylabel('pascal', fontsize=12, weight='bold')
            elif mn+1 == 5:
                axs[mn+1, co].set_ylabel('PM 2.5', fontsize=12, weight='bold')
# Add a common legend outside of the subplots
        axs[mn,co].legend().set_visible(False)
        axs[mn+1,co].legend().set_visible(False)
handles, labels = axs[mn,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.4, 1.04), fontsize=12, fancybox=True, framealpha=1)
        
handles, labels = axs[mn+1,co].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, bbox_to_anchor=(1, 1.04), fontsize=12, fancybox=True, framealpha=1)
# Out:
# /tmp/ipykernel_4270/1830027975.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8)  # Add space for legend

# %% [markdown]
# # end
