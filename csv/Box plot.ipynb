# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob

# %%
import glob
all_f= glob.glob('*/*_Results.csv')
all_f
# Out:
# ['BeijingPM2.5_data\\BeijingPM2.5_data_Results.csv',
#  'Daily_Sunspot_data\\Daily_Sunspot_data_Results.csv',
#  'Healthy_control_heart_data\\Healthy_control_heart_data_Results.csv',
#  'Myocardial_infarction_heart_data\\Myocardial_infarction_heart_data_Results.csv',
#  'PM2.5_p09_data\\PM2.5_p09_data_Results.csv',
#  'POWER_Point_Daily_Presure_Data\\POWER_Point_Daily_Presure_Data_Results.csv',
#  'POWER_Point_Daily_Temperature\\POWER_Point_Daily_Temperature_Data_Results.csv',
#  'POWER_Point_Daily_WindSpeed_data\\POWER_Point_Daily_WindSpeed_data_Results.csv',
#  'PRSA_data_2010_12_data\\PRSA_data_2010_12_data_Results.csv',
#  'SunSpotMonthly_Data\\SunSpotMonthly_Data_Results.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)
li[0]
# Out:
#     Unnamed: 0                                       iteration_No  models  \
# 0            0                                                  0  BiLSTM
# 1            1                                                  0    LSTM
# 2            2  <keras.engine.sequential.Sequential object at ...     GRU
# 3            3                                                  0     CNN
# 4            4                                                  0     RNN
# 5            5                                                  1  BiLSTM
# 6            6                                                  1    LSTM
# 7            7  <keras.engine.sequential.Sequential object at ...     GRU
# 8            8                                                  1     CNN
# 9            9                                                  1     RNN
# 10          10                                                  2  BiLSTM
# 11          11                                                  2    LSTM
# 12          12  <keras.engine.sequential.Sequential object at ...     GRU
# 13          13                                                  2     CNN
# 14          14                                                  2     RNN
# 15          15                                                  3  BiLSTM
# 16          16                                                  3    LSTM
# 17          17  <keras.engine.sequential.Sequential object at ...     GRU
# 18          18                                                  3     CNN
# 19          19                                                  3     RNN
# 20          20                                                  4  BiLSTM
# 21          21                                                  4    LSTM
# 22          22  <keras.engine.sequential.Sequential object at ...     GRU
# 23          23                                                  4     CNN
# 24          24                                                  4     RNN
# 25          25                                                  5  BiLSTM
# 26          26                                                  5    LSTM
# 27          27  <keras.engine.sequential.Sequential object at ...     GRU
# 28          28                                                  5     CNN
# 29          29                                                  5     RNN
# 30          30                                                  6  BiLSTM
# 31          31                                                  6    LSTM
# 32          32  <keras.engine.sequential.Sequential object at ...     GRU
# 33          33                                                  6     CNN
# 34          34                                                  6     RNN
# 35          35                                                  7  BiLSTM
# 36          36                                                  7    LSTM
# 37          37  <keras.engine.sequential.Sequential object at ...     GRU
# 38          38                                                  7     CNN
# 39          39                                                  7     RNN
# 40          40                                                  8  BiLSTM
# 41          41                                                  8    LSTM
# 42          42  <keras.engine.sequential.Sequential object at ...     GRU
# 43          43                                                  8     CNN
# 44          44                                                  8     RNN
# 45          45                                                  9  BiLSTM
# 46          46                                                  9    LSTM
# 47          47  <keras.engine.sequential.Sequential object at ...     GRU
# 48          48                                                  9     CNN
# 49          49                                                  9     RNN
#
#      A_B_rmse       RMSE    A_B_mape       MAPE
# 0   12.828912  22.738890   64.235273  37.210338
# 1    8.069432  21.096737  141.613619  45.738380
# 2    6.777292  20.642714   14.040358  18.839975
# 3    6.839708  20.472244   15.583330  20.379311
# 4    7.459232  20.866884   12.977223  19.552249
# 5   14.539915  22.470206   57.365427  63.811468
# 6   16.294088  23.327983   18.285212  39.041316
# 7    7.421167  20.636389   14.563676  18.180728
# 8    5.567624  20.397597   13.551267  19.552045
# 9   10.759485  21.860277   41.507072  23.819846
# 10  10.252425  21.645353   15.869395  21.988207
# 11  13.819176  22.100543   80.527939  23.859969
# 12  14.524010  21.359367   28.403387  21.574363
# 13   6.980228  20.442483   14.943492  20.717528
# 14  10.192996  21.650163   12.634143  19.184068
# 15  11.357360  21.693087  123.118839  20.261634
# 16  11.665303  21.175614   33.190053  20.186952
# 17  10.732054  21.256968   22.093524  21.935543
# 18   6.754573  20.396963   15.062744  19.478443
# 19  10.678847  21.414805   14.930673  19.395245
# 20  10.888849  21.975352   15.308895  34.914616
# 21  10.023995  22.362353   14.193895  28.343641
# 22   8.528138  21.283622   12.387729  19.656534
# 23   6.706698  20.740410   14.510894  24.863777
# 24  12.945939  21.086420   17.066145  19.855851
# 25  15.055758  22.351109  792.975294  63.213605
# 26  11.336111  20.942154   23.079635  20.243416
# 27  12.001439  21.146058   24.189301  18.506336
# 28   6.798876  20.438816   16.972480  19.904846
# 29  13.193961  21.120546   17.960818  19.174906
# 30  11.061456  21.786657   16.601339  27.368774
# 31  13.514279  22.021857   26.106747  22.712966
# 32  14.428674  21.544424   28.724900  30.152175
# 33   7.618465  20.651999   15.857032  18.997751
# 34  13.325827  21.640688   25.984547  21.250834
# 35  12.963668  21.442467  111.998761  39.703271
# 36  11.874799  21.765234   29.135501  18.918437
# 37   9.480801  21.540398   13.521536  24.840698
# 38   6.266978  20.539516   14.448041  25.547773
# 39  10.659719  21.248716   13.687528  19.616849
# 40  10.816563  21.914938   14.173540  26.281620
# 41  12.183316  22.080510   28.744439  19.024722
# 42   9.310451  21.005240   20.966542  18.809861
# 43   8.227868  20.722901   17.841070  19.437385
# 44  11.973749  21.051042   17.661068  18.460950
# 45  12.409492  21.957099   76.148720  47.316098
# 46  11.241862  21.927431   29.706961  21.286857
# 47   7.601150  21.228885   11.529964  19.486246
# 48   6.913511  20.505519   15.422169  18.834971
# 49  14.450923  20.879868   13.233242  19.183642

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    df=df.iloc[:,-5:-2]
    if df.iloc[:,0:1].columns[0] == '1':
        BiLSTM = df[df['1'] == 'BiLSTM']
        BiLSTM=BiLSTM.reset_index()
        LSTM= df[df['1'] == 'LSTM']
        LSTM=LSTM.reset_index()
        GRU = df[df['1'] == 'GRU']
        GRU=GRU.reset_index()
        CNN= df[df['1'] == 'CNN']
        CNN=CNN.reset_index()
        RNN= df[df['1'] == 'RNN']
        RNN=RNN.reset_index()
    elif df.iloc[:,0:1].columns[0] == 'Models':
        BiLSTM = df[df['Models'] == 'BiLSTM']
        BiLSTM=BiLSTM.reset_index()
        LSTM= df[df['Models'] == 'LSTM']
        LSTM=LSTM.reset_index()
        GRU = df[df['Models'] == 'GRU']
        GRU=GRU.reset_index()
        CNN= df[df['Models'] == 'CNN']
        CNN=CNN.reset_index()
        RNN= df[df['Models'] == 'RNN']
        RNN=RNN.reset_index()
    elif df.iloc[:,0:1].columns[0] == 'models':
        BiLSTM = df[df['models'] == 'BiLSTM']
        BiLSTM=BiLSTM.reset_index()
        LSTM= df[df['models'] == 'LSTM']
        LSTM=LSTM.reset_index()
        GRU = df[df['models'] == 'GRU']
        GRU=GRU.reset_index()
        CNN= df[df['models'] == 'CNN']
        CNN=CNN.reset_index()
        RNN= df[df['models'] == 'RNN']
        RNN=RNN.reset_index()

        
    df1=pd.DataFrame()
    df1['BiLSTM-Tred_RMSE']=BiLSTM.iloc[:,-1:]
    df1['BiLSTM-GAB_RMSE']=BiLSTM.iloc[:,-2:-1]
    df1['LSTM-Tred_RMSE']=LSTM.iloc[:,-1:]
    df1['LSTM-GAB_RMSE']=LSTM.iloc[:,-2:-1]
    df1['GRU-Tred_RMSE']=GRU.iloc[:,-1:]
    df1['GRU-GAB_RMSE']=GRU.iloc[:,-2:-1]
    df1['CNN-Tred_RMSE']=CNN.iloc[:,-1:]
    df1['CNN-GAB_RMSE']=CNN.iloc[:,-2:-1]
    df1['RNN-Tred_RMSE']=RNN.iloc[:,-1:]
    df1['RNN-GAB_RMSE']=RNN.iloc[:,-2:-1]
    df1.to_csv('Boxplot/'+file_name.split('\\')[0]+'_rmse.csv')
    li.append(df1)
li[9]
# Out:
#    BiLSTM-Tred_RMSE  BiLSTM-GAB_RMSE  LSTM-Tred_RMSE  LSTM-GAB_RMSE  \
# 0         19.697700        10.139263       19.251095      10.637627
# 1         20.098820        12.224259       21.780466      14.958933
# 2         19.459119         9.990801       19.238519      10.684717
# 3         19.441378         9.836955       21.793081      14.777249
# 4         21.066589        13.025996       21.131749      13.222675
# 5         19.240783         9.458783       19.610266       9.655906
# 6         19.316327        10.507238       19.804918      10.947150
# 7         20.300945        10.815721       23.272856      16.500732
# 8         19.587389        11.605832       19.227936       8.669516
# 9         19.058965         8.794185       19.924860      11.261074
#
#    GRU-Tred_RMSE  GRU-GAB_RMSE  CNN-Tred_RMSE  CNN-GAB_RMSE  RNN-Tred_RMSE  \
# 0      21.539329     13.681508      18.842803      6.131081      20.148390
# 1      18.592475      7.175896      18.893761      6.132443      20.211301
# 2      20.813556     13.658226      18.863991      6.158619      20.215902
# 3      18.670288      8.269053      18.838124      6.040319      20.447020
# 4      19.476229     12.201350      18.894765      6.086061      19.211079
# 5      20.372964     14.092828      18.898920      6.134520      21.693583
# 6      20.497789     13.337313      18.900614      6.102641      19.796582
# 7      20.663706     13.966106      18.858133      6.140575      20.998010
# 8      18.639176      6.476013      18.931194      6.183731      21.832914
# 9      20.680293     11.028296      18.828116      6.001280      21.373934
#
#    RNN-GAB_RMSE
# 0      8.966318
# 1     12.991141
# 2     10.804868
# 3      9.685118
# 4      8.032561
# 5     11.335326
# 6     10.324505
# 7      9.745960
# 8     15.197577
# 9     14.059081

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    df2=df.copy()
    df3=df.iloc[:,-2:]
    df3['models']=df2.iloc[:,-5:-4]
    df=df3
    #df=df.iloc[:,-5:-2]
    if df.iloc[:,-1:].columns[0] == '1':
        BiLSTM = df[df['1'] == 'BiLSTM']
        BiLSTM=BiLSTM.reset_index()
        LSTM= df[df['1'] == 'LSTM']
        LSTM=LSTM.reset_index()
        GRU = df[df['1'] == 'GRU']
        GRU=GRU.reset_index()
        CNN= df[df['1'] == 'CNN']
        CNN=CNN.reset_index()
        RNN= df[df['1'] == 'RNN']
        RNN=RNN.reset_index()
    elif df.iloc[:,-1:].columns[0] == 'Models':
        BiLSTM = df[df['Models'] == 'BiLSTM']
        BiLSTM=BiLSTM.reset_index()
        LSTM= df[df['Models'] == 'LSTM']
        LSTM=LSTM.reset_index()
        GRU = df[df['Models'] == 'GRU']
        GRU=GRU.reset_index()
        CNN= df[df['Models'] == 'CNN']
        CNN=CNN.reset_index()
        RNN= df[df['Models'] == 'RNN']
        RNN=RNN.reset_index()
    elif df.iloc[:,-1:].columns[0] == 'models':
        BiLSTM = df[df['models'] == 'BiLSTM']
        BiLSTM=BiLSTM.reset_index()
        LSTM= df[df['models'] == 'LSTM']
        LSTM=LSTM.reset_index()
        GRU = df[df['models'] == 'GRU']
        GRU=GRU.reset_index()
        CNN= df[df['models'] == 'CNN']
        CNN=CNN.reset_index()
        RNN= df[df['models'] == 'RNN']
        RNN=RNN.reset_index()

        
    df1=pd.DataFrame()
    df1['BiLSTM-Tred_MAPE']=BiLSTM.iloc[:,-2:-1]
    df1['BiLSTM-GAB_MAPE']=BiLSTM.iloc[:,-3:-2]
    df1['LSTM-Tred_MAPE']=LSTM.iloc[:,-2:-1]
    df1['LSTM-GAB_MAPE']=LSTM.iloc[:,-3:-2]
    df1['GRU-Tred_MAPE']=GRU.iloc[:,-2:-1]
    df1['GRU-GAB_MAPE']=GRU.iloc[:,-3:-2]
    df1['CNN-Tred_MAPE']=CNN.iloc[:,-2:-1]
    df1['CNN-GAB_MAPE']=CNN.iloc[:,-3:-2]
    df1['RNN-Tred_MAPE']=RNN.iloc[:,-2:-1]
    df1['RNN-GAB_MAPE']=RNN.iloc[:,-3:-2]
    df1.to_csv('Boxplot/'+file_name.split('\\')[0]+'_MAPE.csv')
    li.append(df1)
li[9]
# Out:
#    BiLSTM-Tred_MAPE  BiLSTM-GAB_MAPE  LSTM-Tred_MAPE  LSTM-GAB_MAPE  \
# 0         25.982233        13.322632       26.556839      13.058973
# 1         26.637963        14.406453       29.789300      13.573056
# 2         26.173132        13.897643       25.579246      13.428357
# 3         26.570090        13.759085       27.589270      14.943462
# 4         26.455585        19.412329       27.705687      13.540477
# 5         32.511411        12.066388       38.180916      14.778081
# 6         26.176170        12.894759       26.123974      13.876429
# 7         28.711841        16.420319       28.924776      15.423991
# 8         26.484010        53.730344       32.304561      15.478088
# 9         33.969143        11.077013       31.054686      14.021421
#
#    GRU-Tred_MAPE  GRU-GAB_MAPE  CNN-Tred_MAPE  CNN-GAB_MAPE  RNN-Tred_MAPE  \
# 0      30.705499     15.308953      36.739663     17.001670      27.303757
# 1      26.033982     12.796631      37.336107     19.379967      28.318287
# 2      25.963894     15.149618      38.412496     15.751298      31.579641
# 3      25.896076     12.295137      37.625793     16.402312      28.943666
# 4      26.576150     13.384962      37.680350     14.318391      25.378938
# 5      27.139528     14.879913      37.681637     17.201356      28.352091
# 6      26.769956     15.904506      37.707277     17.515641      27.859014
# 7      26.639956     16.777950      42.879717     15.730858      29.927186
# 8      25.977714     10.640897      37.653485     20.343840      26.321139
# 9      32.259657     12.970316      44.480161     16.694094      27.558700
#
#    RNN-GAB_MAPE
# 0     13.861484
# 1     17.700195
# 2     14.821760
# 3     14.664119
# 4     12.526494
# 5     16.525594
# 6     14.547273
# 7     14.310848
# 8     16.325456
# 9     16.829702

# %%
all_f= glob.glob('Boxplot/*_rmse.csv')
all_f
# Out:
# ['Boxplot\\BeijingPM2.5_data_rmse.csv',
#  'Boxplot\\Daily_Sunspot_data_rmse.csv',
#  'Boxplot\\Healthy_control_heart_data_rmse.csv',
#  'Boxplot\\Myocardial_infarction_heart_data_rmse.csv',
#  'Boxplot\\PM2.5_p09_data_rmse.csv',
#  'Boxplot\\POWER_Point_Daily_Presure_data_rmse.csv',
#  'Boxplot\\POWER_Point_Daily_Temperature_rmse.csv',
#  'Boxplot\\POWER_Point_Daily_WindSpeed_data_rmse.csv',
#  'Boxplot\\PRSA_data_2010_12_data_rmse.csv',
#  'Boxplot\\SunSpotMonthly_data_rmse.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df.iloc[:,1:])

# %%
fig, axs = plt.subplots(2,5, figsize=(21, 12), layout='constrained')
handles, labels = None, None # Initialize handles and labels
d=0
dd0 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd1 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
ticks=[]
def set_box_color(bp, color,facecolor, edgecolor):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    for box in bp['boxes']:
        box.set(facecolor=facecolor, edgecolor=edgecolor)
b0=axs[0,0].boxplot(dd0, positions=np.array(range(len(dd0))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b1=axs[0,0].boxplot(dd1, positions=np.array(range(len(dd1))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
##set_box_color(b0, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b1, '#2C7BB6')
# Custom fill colors for each box
axs[0,0].set_title(all_f[d].split('\\')[1].split('_data')[0])

for d in range(5):
    b0['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b1['boxes'][d].set(facecolor='#00FF00') 
    b0['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b1['medians'][d].set(color='#000000')  
axs[0,0].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[0,0].set_ylabel('MAPE')


d=1
dd2 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd3 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b2=axs[0,1].boxplot(dd2, positions=np.array(range(len(dd2))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b3=axs[0,1].boxplot(dd3, positions=np.array(range(len(dd3))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
##set_box_color(b2, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b3, '#2C7BB6')
axs[0,1].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b2['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b3['boxes'][d].set(facecolor='#00FF00')
    b2['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b3['medians'][d].set(color='#000000')  
axs[0,1].set_xticks(range(0, len(ticks) * 2, 2), ticks)


d=2
dd4 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd5 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b4=axs[0,2].boxplot(dd4, positions=np.array(range(len(dd4))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b5=axs[0,2].boxplot(dd5, positions=np.array(range(len(dd5))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b4, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b5, '#2C7BB6')
axs[0,2].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b4['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b5['boxes'][d].set(facecolor='#00FF00') 
    b4['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b5['medians'][d].set(color='#000000')  
axs[0,2].set_xticks(range(0, len(ticks) * 2, 2), ticks)

d=3
dd6 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd7 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b6=axs[0,3].boxplot(dd6, positions=np.array(range(len(dd6))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b7=axs[0,3].boxplot(dd7, positions=np.array(range(len(dd7))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b6, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b7, '#2C7BB6')
axs[0,3].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b6['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b7['boxes'][d].set(facecolor='#00FF00') 
    b6['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b7['medians'][d].set(color='#000000')  
axs[0,3].set_xticks(range(0, len(ticks) * 2, 2), ticks)

d=4
dd8 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd9 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b8=axs[0,4].boxplot(dd8, positions=np.array(range(len(dd8))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b9=axs[0,4].boxplot(dd9, positions=np.array(range(len(dd9))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b6, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b7, '#2C7BB6')
axs[0,4].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b8['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b9['boxes'][d].set(facecolor='#00FF00') 
    b8['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b9['medians'][d].set(color='#000000')  
axs[0,4].set_xticks(range(0, len(ticks) * 2, 2), ticks)








d=5
ticks = ['LSTM','CNN','BiLSTM','GRU','RNN']
dd10 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd11 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b10=axs[1,0].boxplot(dd10, positions=np.array(range(len(dd10))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b11=axs[1,0].boxplot(dd11, positions=np.array(range(len(dd11))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)

#set_box_color(b8, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b9, '#2C7BB6')
axs[1,0].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b10['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b11['boxes'][d].set(facecolor='#00FF00') 
    b10['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b11['medians'][d].set(color='#000000')  
axs[1,0].set_xticks(range(0, len(ticks) * 2, 2), ticks)

axs[1,0].set_ylabel('MAPE')
axs[1,0].set_xlabel('Models')

d=6
dd12 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd13 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b12=axs[1,1].boxplot(dd12, positions=np.array(range(len(dd12))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b13=axs[1,1].boxplot(dd13, positions=np.array(range(len(dd13))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b10, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b11, '#2C7BB6')
axs[1,1].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b12['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b13['boxes'][d].set(facecolor='#00FF00') 
    b12['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b13['medians'][d].set(color='#000000')  
axs[1,1].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,1].set_xlabel('Models')

d=7
dd14 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd15 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b14=axs[1,2].boxplot(dd14, positions=np.array(range(len(dd14))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b15=axs[1,2].boxplot(dd15, positions=np.array(range(len(dd15))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b12, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b13, '#2C7BB6')
axs[1,2].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b14['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b15['boxes'][d].set(facecolor='#00FF00') 
    b14['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b15['medians'][d].set(color='#000000')  

axs[1,2].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,2].set_xlabel('Models')


d=8
dd16 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd17 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b16=axs[1,3].boxplot(dd16, positions=np.array(range(len(dd16))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b17=axs[1,3].boxplot(dd17, positions=np.array(range(len(dd17))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b12, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b13, '#2C7BB6')
axs[1,3].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b16['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b17['boxes'][d].set(facecolor='#00FF00') 
    b16['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b17['medians'][d].set(color='#000000')  

axs[1,3].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,3].set_xlabel('Models')

d=9
dd18 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd19 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b18=axs[1,4].boxplot(dd18, positions=np.array(range(len(dd18))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b19=axs[1,4].boxplot(dd19, positions=np.array(range(len(dd19))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b14, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b15, '#2C7BB6')
axs[1,4].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b18['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b19['boxes'][d].set(facecolor='#00FF00') 
    b18['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b19['medians'][d].set(color='#000000')  
#axs[1,3].set_facecolor('#D7191C')
axs[1,4].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,4].set_xlabel('Models')
#axs[1,3].legend()
#axs.legend().set_visible(False)
#handles, labels = axs.get_legend_handles_labels()
#fig.legend(handles, labels, ncol=5, bbox_to_anchor=(1, 1.01), fontsize=12, fancybox=True, framealpha=1)
# Create legend handles and labels
legend_handles = [plt.Rectangle((0,0), 1, 1, fc='#FF0000'), plt.Rectangle((0,0), 1, 1, fc='#00FF00')]
legend_labels = ['Traditian', 'GR2']

# Display the legend
fig.legend(legend_handles, legend_labels, loc='upper right', ncol=2,bbox_to_anchor=(1, 1.025))
plt.savefig('Boxplot/rmse/Box_RMSE.JPG',dpi=400,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')

# %%
all_f= glob.glob('Boxplot/*_mape.csv')
all_f
# Out:
# ['Boxplot\\BeijingPM2.5_data_MAPE.csv',
#  'Boxplot\\Daily_Sunspot_data_MAPE.csv',
#  'Boxplot\\Healthy_control_heart_data_MAPE.csv',
#  'Boxplot\\Myocardial_infarction_heart_data_MAPE.csv',
#  'Boxplot\\PM2.5_p09_data_MAPE.csv',
#  'Boxplot\\POWER_Point_Daily_Presure_data_MAPE.csv',
#  'Boxplot\\POWER_Point_Daily_Temperature_MAPE.csv',
#  'Boxplot\\POWER_Point_Daily_WindSpeed_data_MAPE.csv',
#  'Boxplot\\PRSA_data_2010_12_data_MAPE.csv',
#  'Boxplot\\SunSpotMonthly_data_MAPE.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df.iloc[:,1:])

# %%
fig, axs = plt.subplots(2,5, figsize=(21, 12), layout='constrained')
handles, labels = None, None # Initialize handles and labels
d=0
dd0 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd1 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
ticks=[]
def set_box_color(bp, color,facecolor, edgecolor):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    for box in bp['boxes']:
        box.set(facecolor=facecolor, edgecolor=edgecolor)
b0=axs[0,0].boxplot(dd0, positions=np.array(range(len(dd0))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b1=axs[0,0].boxplot(dd1, positions=np.array(range(len(dd1))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
##set_box_color(b0, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b1, '#2C7BB6')
# Custom fill colors for each box
axs[0,0].set_title(all_f[d].split('\\')[1].split('_data')[0])

for d in range(5):
    b0['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b1['boxes'][d].set(facecolor='#00FF00') 
    b0['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b1['medians'][d].set(color='#000000')  
axs[0,0].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[0,0].set_ylabel('MAPE')


d=1
dd2 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd3 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b2=axs[0,1].boxplot(dd2, positions=np.array(range(len(dd2))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b3=axs[0,1].boxplot(dd3, positions=np.array(range(len(dd3))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
##set_box_color(b2, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b3, '#2C7BB6')
axs[0,1].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b2['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b3['boxes'][d].set(facecolor='#00FF00')
    b2['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b3['medians'][d].set(color='#000000')  
axs[0,1].set_xticks(range(0, len(ticks) * 2, 2), ticks)


d=2
dd4 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd5 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b4=axs[0,2].boxplot(dd4, positions=np.array(range(len(dd4))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b5=axs[0,2].boxplot(dd5, positions=np.array(range(len(dd5))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b4, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b5, '#2C7BB6')
axs[0,2].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b4['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b5['boxes'][d].set(facecolor='#00FF00') 
    b4['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b5['medians'][d].set(color='#000000')  
axs[0,2].set_xticks(range(0, len(ticks) * 2, 2), ticks)

d=3
dd6 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd7 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b6=axs[0,3].boxplot(dd6, positions=np.array(range(len(dd6))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b7=axs[0,3].boxplot(dd7, positions=np.array(range(len(dd7))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b6, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b7, '#2C7BB6')
axs[0,3].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b6['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b7['boxes'][d].set(facecolor='#00FF00') 
    b6['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b7['medians'][d].set(color='#000000')  
axs[0,3].set_xticks(range(0, len(ticks) * 2, 2), ticks)

d=4
dd8 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd9 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b8=axs[0,4].boxplot(dd8, positions=np.array(range(len(dd8))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b9=axs[0,4].boxplot(dd9, positions=np.array(range(len(dd9))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b6, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b7, '#2C7BB6')
axs[0,4].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b8['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b9['boxes'][d].set(facecolor='#00FF00') 
    b8['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b9['medians'][d].set(color='#000000')  
axs[0,4].set_xticks(range(0, len(ticks) * 2, 2), ticks)








d=5
ticks = ['LSTM','CNN','BiLSTM','GRU','RNN']
dd10 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd11 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b10=axs[1,0].boxplot(dd10, positions=np.array(range(len(dd10))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b11=axs[1,0].boxplot(dd11, positions=np.array(range(len(dd11))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)

#set_box_color(b8, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b9, '#2C7BB6')
axs[1,0].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b10['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b11['boxes'][d].set(facecolor='#00FF00') 
    b10['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b11['medians'][d].set(color='#000000')  
axs[1,0].set_xticks(range(0, len(ticks) * 2, 2), ticks)

axs[1,0].set_ylabel('MAPE')
axs[1,0].set_xlabel('Models')

d=6
dd12 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd13 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b12=axs[1,1].boxplot(dd12, positions=np.array(range(len(dd12))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b13=axs[1,1].boxplot(dd13, positions=np.array(range(len(dd13))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b10, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b11, '#2C7BB6')
axs[1,1].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b12['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b13['boxes'][d].set(facecolor='#00FF00') 
    b12['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b13['medians'][d].set(color='#000000')  
axs[1,1].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,1].set_xlabel('Models')

d=7
dd14 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd15 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b14=axs[1,2].boxplot(dd14, positions=np.array(range(len(dd14))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b15=axs[1,2].boxplot(dd15, positions=np.array(range(len(dd15))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b12, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b13, '#2C7BB6')
axs[1,2].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b14['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b15['boxes'][d].set(facecolor='#00FF00') 
    b14['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b15['medians'][d].set(color='#000000')  

axs[1,2].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,2].set_xlabel('Models')


d=8
dd16 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd17 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b16=axs[1,3].boxplot(dd16, positions=np.array(range(len(dd16))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b17=axs[1,3].boxplot(dd17, positions=np.array(range(len(dd17))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b12, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b13, '#2C7BB6')
axs[1,3].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b16['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b17['boxes'][d].set(facecolor='#00FF00') 
    b16['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b17['medians'][d].set(color='#000000')  

axs[1,3].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,3].set_xlabel('Models')

d=9
dd18 = [li[d].iloc[:, 0].values, li[d].iloc[:, 2].values, li[d].iloc[:, 4].values, li[d].iloc[:, 6].values, li[d].iloc[:, 8].values]
dd19 = [li[d].iloc[:, 1].values, li[d].iloc[:, 3].values, li[d].iloc[:, 5].values, li[d].iloc[:, 7].values, li[d].iloc[:, 9].values]
b18=axs[1,4].boxplot(dd18, positions=np.array(range(len(dd18))) * 2.0 -.05, sym='', widths=0.5,patch_artist=True)
b19=axs[1,4].boxplot(dd19, positions=np.array(range(len(dd19))) * 2.0 +.5, sym='', widths=0.5,patch_artist=True)
#set_box_color(b14, '#D7191C')  # colors are from http://colorbrewer2.org/
#set_box_color(b15, '#2C7BB6')
axs[1,4].set_title(all_f[d].split('\\')[1].split('_data')[0])
for d in range(5):
    b18['boxes'][d].set(facecolor='#FF0000')  # Set the fill color for the first box in the first boxplot
    b19['boxes'][d].set(facecolor='#00FF00') 
    b18['medians'][d].set(color='#000000')  # Set the color for the medians in the first boxplot
    b19['medians'][d].set(color='#000000')  
#axs[1,3].set_facecolor('#D7191C')
axs[1,4].set_xticks(range(0, len(ticks) * 2, 2), ticks)
axs[1,4].set_xlabel('Models')
#axs[1,3].legend()
#axs.legend().set_visible(False)
#handles, labels = axs.get_legend_handles_labels()
#fig.legend(handles, labels, ncol=5, bbox_to_anchor=(1, 1.01), fontsize=12, fancybox=True, framealpha=1)
# Create legend handles and labels
legend_handles = [plt.Rectangle((0,0), 1, 1, fc='#FF0000'), plt.Rectangle((0,0), 1, 1, fc='#00FF00')]
legend_labels = ['Traditian', 'GR2']

# Display the legend
fig.legend(legend_handles, legend_labels, loc='upper right', ncol=2,bbox_to_anchor=(1, 1.025))
plt.savefig('Boxplot/mape/Box_MAPE.JPG',dpi=400,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')

# %% [markdown]
# BiLSTM

# %% [markdown]
# BiLSTM = li[0][li[0]['models'] == 'BiLSTM']
# LSTM= li[0][li[0]['models'] == 'LSTM']
# GRU = li[0][li[0]['models'] == 'GRU']
# CNN= li[0][li[0]['models'] == 'CNN']
# RNN= li[0][li[0]['models'] == 'RNN']
# BiLSTM,LSTM,GRU,CNN,RNN

# %% [markdown]
# sns.set(rc={'figure.figsize':(8,8)})
# li=[]
# for j in range(10):
#     d_n=all_f[j].split(r'/')
#     dn=d_n[0]
#     for file_name in all_f:
#         df=pd.read_csv(file_name)
#         li.append(df)
#     df1=li[j].iloc[:,-5:-2]
#     if df1.iloc[:,0:1].columns[0] == 'models':
#         df=pd.melt(df1, id_vars=['models'], value_vars=['A_B_rmse', 'RMSE'])
#         df=df.rename(columns={'models':'Models','value':'RMSE'})
#         df['variable']=df['variable'].replace(['A_B_rmse','RMSE'],['GAB','Normal'])
#     elif df1.iloc[:,0:1].columns[0] == '1':
#         df=pd.melt(df1, id_vars=['1'], value_vars=['2', '3'])
#         df=df.rename(columns={'1':'Models','value':'RMSE'})
#         df['variable']=df['variable'].replace(['2','3'],['GAB','Normal'])
#     else:
#         df=pd.melt(df1, id_vars=['Models'], value_vars=['A_B_rmse', 'RMSE'])
#         df=df.rename(columns={'Models':'Models','value':'RMSE'})
#         df['variable']=df['variable'].replace(['A_B_rmse','RMSE'],['GAB','Normal'])
#     ax = sns.boxplot(x="Models", y="RMSE", hue="variable", data=df)
#     plt.legend(loc='best')
#     plt.savefig('Boxplot/rmse/'+dn+'_rmse.png')
#     plt.cla()

# %% [markdown]
# d = {}
#         com=['df0','df1','df2','df3','df4','df5','df6','df7','df8','df9','df10','df11','df12','df13','df14']
#         for i in com:
#             d[i] = pd.DataFrame()
#             d[i]=df
#         print(d)
#          ax = sns.boxplot(x="Models", y="RMSE", hue="variable", data=df)
#         plt.legend(loc='best')
#         plt.savefig('Boxplot/rmse/'+dn+'_rmse.png')

# %% [markdown]
# fn=3
# d_n=all_f[fn].split(r'/')
# dn=d_n[0]#+d_n[1]
# '''dn=dn.split(r'_')
# dn=dn[0]+'_'+dn[1]+'_'+dn[2]+'_'+dn[3]
# dn'''
# dn

# %% [markdown]
# li=[]
# for file_name in all_f:
#     df=pd.read_csv(file_name)
#     li.append(df)
# df1=li[fn].iloc[:,-5:-2]

# %% [markdown]
# df1.head(6)

# %% [markdown]
# if df1.iloc[:,0:1].columns[0] == 'models':
#     df=pd.melt(df1, id_vars=['models'], value_vars=['A_B_rmse', 'RMSE'])
#     df=df.rename(columns={'models':'Models','value':'RMSE'})
#     df['variable']=df['variable'].replace(['A_B_rmse','RMSE'],['GAB','Normal'])
#     df
# elif df1.iloc[:,0:1].columns[0] == '1':
#     df=pd.melt(df1, id_vars=['1'], value_vars=['2', '3'])
#     df=df.rename(columns={'1':'Models','value':'RMSE'})
#     df['variable']=df['variable'].replace(['2','3'],['GAB','Normal'])
#     df
# else:
#     df=pd.melt(df1, id_vars=['Models'], value_vars=['A_B_rmse', 'RMSE'])
#     df=df.rename(columns={'Models':'Models','value':'RMSE'})
#     df['variable']=df['variable'].replace(['A_B_rmse','RMSE'],['GAB','Normal'])
#     df
# df

# %% [markdown]
# #import os
# #os.mkdir('Boxplot/rmse')
# sns.set(rc={'figure.figsize':(8,8)})
# print(dn)
# ax = sns.boxplot(x="Models", y="RMSE", hue="variable", data=df)  # RUN PLOT
# plt.legend(loc='best')
# plt.savefig('Boxplot/rmse/'+dn+'_rmse.png')
