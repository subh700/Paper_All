# %%
import pandas as pd

# %%
import glob
all_f= glob.glob('Rmse*.csv')
all_f
# Out:
# ['Rmse_Mape 09-PM2.5_p09_data-.csv',
#  'Rmse_Mape 09-POWER_Point_Daily_Temperature_Data-.csv',
#  'Rmse_Mape 09-Daily_Sunspot_data-.csv',
#  'Rmse_Mape 09-Healthy_control_heart_data-.csv',
#  'Rmse_Mape 09-Metro_Interstate_Traffic_Volume_PD-.csv',
#  'Rmse_Mape 09-POWER_Point_Daily_Presure_Data-.csv',
#  'Rmse_Mape 09-Myocardial_infarction_heart_data-.csv',
#  'Rmse_Mape 09-Tetuan_City_Power_Consumption_Zone1_processed-.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df.iloc[:,1:])

# %%
d=7

rmse= li[d].filter(regex='_Rmse$')
rmse
# Out:
#    LSTM-Tred_Rmse  LSTM-GAB_Rmse  CNN-Tred_Rmse  CNN-GAB_Rmse  \
# 0      462.564148     399.920108     486.173775    411.448231
# 1      485.607021     353.023490     605.386746    408.656667
# 2      421.097357     342.230000     547.155657    409.665040
# 3      468.873047     364.370408     577.308334    407.713438
# 4      418.719336     356.766621     625.977963    406.772527
# 5      485.698138     337.185773     447.696071    407.269752
# 6      398.670669     355.618933     435.591955    404.475734
# 7      451.953759     343.000478     461.132946    408.268401
# 8      457.583559     351.200391     514.944299    407.477678
#
#    BiLSTM-Tred_Rmse  BiLSTM-GAB_Rmse  GRU-Tred_Rmse  GRU-GAB_Rmse  \
# 0        472.387582       412.886632     453.331486    379.532676
# 1        456.953864       395.668888     410.812983    368.340672
# 2        451.962161       399.318067     449.821662    368.206465
# 3        446.815982       425.005009     455.143513    360.600601
# ...

# %%
Ds_N=all_f[d].split('/')[-1].split('.csv')[0].split(r'-')[1]
Ds_N
# Out:
# 'Tetuan_City_Power_Consumption_Zone1_processed'

# %%
c=0

data = {
    rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c:c+1].values.flatten().tolist(),
    rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c+1:c+2].values.flatten().tolist()
}

df0 = pd.DataFrame(data)

# Add the 'Model' column and set its value as 'LSTM' for all rows
df0['Model'] = rmse.iloc[:,c:c+11].columns[0].split(r'-')[0]

# Reorder the columns to match the desired format
df0 = df0[['Model', rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1], rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]]]

# Print the modified DataFrame
df0
# Out:
#   Model        Tred         GAB
# 0  LSTM  462.564148  399.920108
# 1  LSTM  485.607021  353.023490
# 2  LSTM  421.097357  342.230000
# 3  LSTM  468.873047  364.370408
# 4  LSTM  418.719336  356.766621
# 5  LSTM  485.698138  337.185773
# 6  LSTM  398.670669  355.618933
# 7  LSTM  451.953759  343.000478
# 8  LSTM  457.583559  351.200391

# %%
c=2

data = {
    rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c:c+1].values.flatten().tolist(),
    rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c+1:c+2].values.flatten().tolist()
}

df1 = pd.DataFrame(data)

# Add the 'Model' column and set its value as 'LSTM' for all rows
df1['Model'] = rmse.iloc[:,c:c+11].columns[0].split(r'-')[0]

# Reorder the columns to match the desired format
df1 = df1[['Model', rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1], rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]]]

# Print the modified DataFrame
df1
# Out:
#   Model        Tred         GAB
# 0   CNN  486.173775  411.448231
# 1   CNN  605.386746  408.656667
# 2   CNN  547.155657  409.665040
# 3   CNN  577.308334  407.713438
# 4   CNN  625.977963  406.772527
# 5   CNN  447.696071  407.269752
# 6   CNN  435.591955  404.475734
# 7   CNN  461.132946  408.268401
# 8   CNN  514.944299  407.477678

# %%
c=4

data = {
    rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c:c+1].values.flatten().tolist(),
    rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c+1:c+2].values.flatten().tolist()
}

df2 = pd.DataFrame(data)

# Add the 'Model' column and set its value as 'LSTM' for all rows
df2['Model'] = rmse.iloc[:,c:c+11].columns[0].split(r'-')[0]

# Reorder the columns to match the desired format
df2 = df2[['Model', rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1], rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]]]

# Print the modified DataFrame
df2
# Out:
#     Model        Tred         GAB
# 0  BiLSTM  472.387582  412.886632
# 1  BiLSTM  456.953864  395.668888
# 2  BiLSTM  451.962161  399.318067
# 3  BiLSTM  446.815982  425.005009
# 4  BiLSTM  448.477880  363.065827
# 5  BiLSTM  490.165858  390.833229
# 6  BiLSTM  446.834758  376.252001
# 7  BiLSTM  469.076831  397.730048
# 8  BiLSTM  485.826922  410.087186

# %%
c=6

data = {
    rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c:c+1].values.flatten().tolist(),
    rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c+1:c+2].values.flatten().tolist()
}

df3 = pd.DataFrame(data)

# Add the 'Model' column and set its value as 'LSTM' for all rows
df3['Model'] = rmse.iloc[:,c:c+11].columns[0].split(r'-')[0]

# Reorder the columns to match the desired format
df3 = df3[['Model', rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1], rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]]]

# Print the modified DataFrame
df3
# Out:
#   Model        Tred         GAB
# 0   GRU  453.331486  379.532676
# 1   GRU  410.812983  368.340672
# 2   GRU  449.821662  368.206465
# 3   GRU  455.143513  360.600601
# 4   GRU  413.533940  359.964011
# 5   GRU  423.284919  350.125087
# 6   GRU  455.521730  342.698976
# 7   GRU  442.538979  350.120357
# 8   GRU  432.802615  353.306977

# %%
c=8

data = {
    rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c:c+1].values.flatten().tolist(),
    rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]: rmse.iloc[:,c+1:c+2].values.flatten().tolist()
}

df4 = pd.DataFrame(data)

# Add the 'Model' column and set its value as 'LSTM' for all rows
df4['Model'] = rmse.iloc[:,c:c+11].columns[0].split(r'-')[0]

# Reorder the columns to match the desired format
df4 = df4[['Model', rmse.iloc[:,c:c+1].columns[0].split(r'_')[0].split(r'-')[1], rmse.iloc[:,c+1:c+2].columns[0].split(r'_')[0].split(r'-')[1]]]

# Print the modified DataFrame
df4
# Out:
#   Model        Tred         GAB
# 0   RNN  414.718288  362.794460
# 1   RNN  404.994816  366.301476
# 2   RNN  408.115113  364.085310
# 3   RNN  400.136294  386.009053
# 4   RNN  384.565832  356.897722
# 5   RNN  411.848048  369.774096
# 6   RNN  407.207662  364.102579
# 7   RNN  418.611369  361.070605
# 8   RNN  403.265772  357.113704

# %%
vr=df0.append([df1,df2,df3,df4])
vr=vr.reset_index().iloc[:,1:]
if vr.columns[0] == "Model":
    new_rmse=pd.melt(vr, id_vars=['Model'], value_vars=['Tred', 'GAB'])
    new_rmse=new_rmse.rename(columns={'value':'RMSE'})
new_rmse.to_csv('box_'+Ds_N+'.csv')
# Out:
# /tmp/ipykernel_60981/3491295510.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vr=df0.append([df1,df2,df3,df4])

# %%
new_rmse
# Out:
#    Model variable        RMSE
# 0   LSTM     Tred  462.564148
# 1   LSTM     Tred  485.607021
# 2   LSTM     Tred  421.097357
# 3   LSTM     Tred  468.873047
# 4   LSTM     Tred  418.719336
# ..   ...      ...         ...
# 85   RNN      GAB  356.897722
# 86   RNN      GAB  369.774096
# 87   RNN      GAB  364.102579
# 88   RNN      GAB  361.070605
# 89   RNN      GAB  357.113704
#
# [90 rows x 3 columns]

# %%
import seaborn as sns
#sns.set_theme(style="ticks", palette="pastel")
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Model", y="RMSE",
            hue="variable",
            data=new_rmse)
# Out:
# <Axes: xlabel='Model', ylabel='RMSE'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
ax[0,0].sns.boxplot(x="Model", y="RMSE",hue="variable",data=new_rmse)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3 import matplotlib.pyplot as plt
#       4 fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
# ----> 5 ax[0,0].sns.boxplot(x="Model", y="RMSE",hue="variable",data=new_rmse)
#
# AttributeError: 'Axes' object has no attribute 'sns'
