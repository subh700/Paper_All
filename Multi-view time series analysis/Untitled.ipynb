# %%
import pandas as pd

# Assuming you have two DataFrames, df1 and df2, with multi-index columns

# Concatenate the two DataFrames along axis=1 (columns)
combined_df = pd.concat([df1, df2], axis=1)

# Print the combined DataFrame
print(combined_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 import pandas as pd
#       3 # Assuming you have two DataFrames, df1 and df2, with multi-index columns
#       4
#       5 # Concatenate the two DataFrames along axis=1 (columns)
# ----> 6 combined_df = pd.concat([df1, df2], axis=1)
#       8 # Print the combined DataFrame
#       9 print(combined_df)
#
# NameError: name 'df1' is not defined

# %%
import glob
all_f= glob.glob('Im*.csv')
all_f
# Out:
# ['Improv_POWER_Point_Daily_Temperature_Data-All_models_Result.csv',
#  'Improv_Daily_Sunspot_data-All_models_Result.csv',
#  'Improv_PM2.5_p09_data-All_models_Result.csv',
#  'Improv_Healthy_control_heart_data-All_models_Result.csv',
#  'Improv_Myocardial_infarction_heart_data-All_models_Result.csv',
#  'Improv_Tetuan_City_Power_Consumption_Zone1_processed-All_models_Result.csv',
#  'Improv_POWER_Point_Daily_Presure_Data-All_models_Result.csv']

# %%
import pandas as pd

li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %%
df1=li[0]
df1
# Out:
#    Unnamed: 0                LSTM              LSTM.1              LSTM.2  \
# 0         NaN                RMSE                RMSE                RMSE
# 1         NaN                mean                best             improve
# 2         0.0  1.1569447248481595  0.7997220089602592  30.876385726620008
#
#               LSTM.3             LSTM.4              LSTM.5  \
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  3.934513311685807  2.459752582530028  1.4747607291557787
#
#                   CNN               CNN.1              CNN.2  ...  \
# 0                RMSE                RMSE               RMSE  ...
# 1                mean                best            improve  ...
# 2  1.1686198020753868  0.7807409645448941  33.19119159555975  ...
#
#                GRU.2              GRU.3              GRU.4  \
# 0               RMSE               MAPE               MAPE
# ...

# %%
df2=li[1]
df2
# Out:
#    Unnamed: 0                LSTM              LSTM.1             LSTM.2  \
# 0         NaN                RMSE                RMSE               RMSE
# 1         NaN                mean                best            improve
# 2         0.0  14.974558141928128  13.664189158813674  8.750635382325418
#
#               LSTM.3             LSTM.4              LSTM.5  \
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  33.66626994724139  30.66675162689384  2.9995183203475477
#
#                   CNN               CNN.1              CNN.2  ...  \
# 0                RMSE                RMSE               RMSE  ...
# 1                mean                best            improve  ...
# 2  14.878173661533392  11.100603271338553  25.39001409804428  ...
#
#                 GRU.2              GRU.3               GRU.4  \
# 0                RMSE               MAPE                MAPE
# ...

# %%
df3=li[2]
df3
# Out:
#    Unnamed: 0              LSTM              LSTM.1              LSTM.2  \
# 0         NaN              RMSE                RMSE                RMSE
# 1         NaN              mean                best             improve
# 2         0.0  5.66029289474096  4.6558703107187585  17.745063774975694
#
#                LSTM.3             LSTM.4             LSTM.5  \
# 0                MAPE               MAPE               MAPE
# 1                mean               best            improve
# 2  16.754966370973946  9.055729903396958  7.699236467576988
#
#                  CNN               CNN.1              CNN.2  ...  \
# 0               RMSE                RMSE               RMSE  ...
# 1               mean                best            improve  ...
# 2  5.846917306107325  3.7919920615992044  35.14544736867877  ...
#
#                GRU.2              GRU.3              GRU.4  \
# 0               RMSE               MAPE               MAPE
# ...

# %%
df4=li[3]
df4
# Out:
#    Unnamed: 0                 LSTM                LSTM.1             LSTM.2  \
# 0         NaN                 RMSE                  RMSE               RMSE
# 1         NaN                 mean                  best            improve
# 2         0.0  0.05538925194278408  0.007068033860059498  87.23934046381305
#
#               LSTM.3              LSTM.4             LSTM.5  \
# 0               MAPE                MAPE               MAPE
# 1               mean                best            improve
# 2  5.798561842701674  0.7114697799853297  5.087092062716344
#
#                     CNN                 CNN.1               CNN.2  ...  \
# 0                  RMSE                  RMSE                RMSE  ...
# 1                  mean                  best             improve  ...
# 2  0.018893525838208063  0.019555197978655098  -3.502110437793172  ...
#
#                 GRU.2               GRU.3               GRU.4  \
# 0                RMSE                MAPE                MAPE
# ...

# %%
df5=li[4]
df5
# Out:
#    Unnamed: 0                  LSTM                LSTM.1             LSTM.2  \
# 0         NaN                  RMSE                  RMSE               RMSE
# 1         NaN                  mean                  best            improve
# 2         0.0  0.011609419977660669  0.007518753802725168  35.23574978600939
#
#               LSTM.3              LSTM.4             LSTM.5  \
# 0               MAPE                MAPE               MAPE
# 1               mean                best            improve
# 2  15.19267712094705  10.973518729978277  4.219158390968772
#
#                     CNN                 CNN.1              CNN.2  ...  \
# 0                  RMSE                  RMSE               RMSE  ...
# 1                  mean                  best            improve  ...
# 2  0.011386277456837148  0.007026622513840338  38.28867651893514  ...
#
#                  GRU.2               GRU.3              GRU.4  \
# 0                 RMSE                MAPE               MAPE
# ...

# %%
df6=li[5]
df6
# Out:
#    Unnamed: 0                LSTM            LSTM.1             LSTM.2  \
# 0         NaN                RMSE              RMSE               RMSE
# 1         NaN                mean              best            improve
# 2         0.0  450.08522591497524  337.185772717184  25.08401669223394
#
#               LSTM.3             LSTM.4              LSTM.5  \
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  1.218768846988777  0.828452207058559  0.3903166399302179
#
#                  CNN              CNN.1               CNN.2  ...  \
# 0               RMSE               RMSE                RMSE  ...
# 1               mean               best             improve  ...
# 2  522.3741939504807  404.4757337960452  22.569732869616438  ...
#
#                 GRU.2               GRU.3               GRU.4  \
# 0                RMSE                MAPE                MAPE
# ...

# %%
df7=li[6]
df7
# Out:
#    Unnamed: 0            LSTM (1)          LSTM (1).1         LSTM (1).2  \
# 0         NaN                RMSE                RMSE               RMSE
# 1         NaN                mean                best            improve
# 2         0.0  1.0590548780913525  0.6758395982749128  36.18464800493408
#
#            LSTM (1).3         LSTM (1).4          LSTM (1).5  \
# 0                MAPE               MAPE                MAPE
# 1                mean               best             improve
# 2  10.153757730577704  5.862375702873894  4.2913820277038095
#
#                   CNN               CNN.1               CNN.2  ...  \
# 0                RMSE                RMSE                RMSE  ...
# 1                mean                best             improve  ...
# 2  1.0704807118599426  0.6249621333407492  41.618552635582965  ...
#
#                 GRU.2               GRU.3              GRU.4  \
# 0                RMSE                MAPE               MAPE
# ...

# %% [markdown]
# df8=li[7]
# df8

# %%
combined_df = pd.concat([df1, df2], axis=0)

# Print the combined DataFram

combined_df
# Out:
#    Unnamed: 0                LSTM              LSTM.1              LSTM.2  \
# 0         NaN                RMSE                RMSE                RMSE
# 1         NaN                mean                best             improve
# 2         0.0  1.1569447248481595  0.7997220089602592  30.876385726620008
# 0         NaN                RMSE                RMSE                RMSE
# 1         NaN                mean                best             improve
# 2         0.0  14.974558141928128  13.664189158813674   8.750635382325418
#
#               LSTM.3             LSTM.4              LSTM.5  \
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  3.934513311685807  2.459752582530028  1.4747607291557787
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  33.66626994724139  30.66675162689384  2.9995183203475477
#
# ...

# %%
appended_df = pd.concat([df1, df2], axis=0)

# Add the DataFrame name as the first cell in each row
#appended_df.index = pd.MultiIndex.from_tuples([(all_f[0], *index) for index in appended_df.index])

# %%
uu=appended_df.iloc[-2:-1,:]
uu
# Out:
#    Unnamed: 0  LSTM LSTM.1   LSTM.2 LSTM.3 LSTM.4   LSTM.5   CNN CNN.1  \
# 1         NaN  mean   best  improve   mean   best  improve  mean  best
#
#      CNN.2  ...    GRU.2 GRU.3 GRU.4    GRU.5   RNN RNN.1    RNN.2 RNN.3  \
# 1  improve  ...  improve  mean  best  improve  mean  best  improve  mean
#
#   RNN.4    RNN.5
# 1  best  improve
#
# [1 rows x 31 columns]

# %%
appended_df
# Out:
#    Unnamed: 0                LSTM              LSTM.1              LSTM.2  \
# 0         NaN                RMSE                RMSE                RMSE
# 1         NaN                mean                best             improve
# 2         0.0  1.1569447248481595  0.7997220089602592  30.876385726620008
# 0         NaN                RMSE                RMSE                RMSE
# 1         NaN                mean                best             improve
# 2         0.0  14.974558141928128  13.664189158813674   8.750635382325418
#
#               LSTM.3             LSTM.4              LSTM.5  \
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  3.934513311685807  2.459752582530028  1.4747607291557787
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  33.66626994724139  30.66675162689384  2.9995183203475477
#
# ...

# %%
df2 = df1.combine_first(df2)

# Display the updated df2 DataFrame
df2
# Out:
#    Unnamed: 0                LSTM              LSTM.1              LSTM.2  \
# 0         NaN                RMSE                RMSE                RMSE
# 1         NaN                mean                best             improve
# 2         0.0  1.1569447248481595  0.7997220089602592  30.876385726620008
#
#               LSTM.3             LSTM.4              LSTM.5  \
# 0               MAPE               MAPE                MAPE
# 1               mean               best             improve
# 2  3.934513311685807  2.459752582530028  1.4747607291557787
#
#                   CNN               CNN.1              CNN.2  ...  \
# 0                RMSE                RMSE               RMSE  ...
# 1                mean                best            improve  ...
# 2  1.1686198020753868  0.7807409645448941  33.19119159555975  ...
#
#                GRU.2              GRU.3              GRU.4  \
# 0               RMSE               MAPE               MAPE
# ...
