for vv in m1['GAB_results']:
    #mi=min(vv)
    lm1.append(vv[2][1])
lm1
mp1=pd.DataFrame(lm1)
mp1.describe().loc['min'].values[0]
#best view mape
# Out:
# 1.7495360019881838

# %%
li=[]
for vv in m1['GAB_results']:
    #mi=min(vv)
    li.append(vv[1][0])
li
m01=pd.DataFrame(li)
m01.describe().loc['mean'].values[0]
#rmse mean
# Out:
# 0.018893525838208063

# %%
li1=[]
for vv in m1['GAB_results']:
    #mi=min(vv)
    li1.append(vv[1][1])
li1
m11=pd.DataFrame(li1)
m11.describe().loc['mean'].values[0]
#Mape mean
# Out:
# 4.509042485287608

# %%
id=1
# Specify the path to the .pkl file
file_path = all_f[id]
D_n=all_f[id].split('.')[-2].split('_')[-1]
mod2=m2=D_n
# Load the object from the .pkl file
with open(file_path, 'rb') as file:
    m2 = pickle.load(file)

# Use the loaded object
print(mod2,m2)
# Out:
# BiLSTM {'Dataset_name': 'Healthy_control_heart_data.csv', 'GAB_results': [[2, [0.030894726673858938, 5.705766295846646], [0.01132972326908754, 1.130330891294298]], [3, [0.018866312149186694, 5.780650983663979], [0.013148827149454406, 1.1171240190655813]], [4, [0.020092541385008458, 5.051624659043927], [0.02837217009745318, 2.210383066573555]], [5, [0.018056858971822205, 4.412125851660634], [0.012996408879583149, 1.1932774295633921]], [6, [0.03401525815401916, 4.837620606525174], [0.03051990418421705, 2.595039623052625]], [7, [0.015889692454801683, 1.6969598108486381], [0.01304645709507936, 1.4044906021365273]], [8, [0.015345711184975887, 1.9922582492263787], [0.023203646531965466, 2.3261324864044273]], [9, [0.02158784434095611, 8.381734981856182], [0.014999694425701635, 1.444060079226499]], [10, [0.03994742381924007, 8.533054462516677], [0.015004931006327167, 1.689393412788492]]], 'best_views': 2, 'y_test': [-1.397, -1.407, -1.416, -1.419, -1.425, -1.439, -1.446, -1.446, -1.456, -1.462, -1.468, -1.47, -1.468, -1.479, -1.486, -1.484, -1.488, -1.491, -1.492, -1.492, -1.494, -1.498, -1.504, -1.504, -1.506, -1.513, -1.516, -1.52, -1.523, -1.522, -1.524, -1.526, -1.52, -1.524, -1.528, -1.522, -1.524, -1.523, -1.522, -1.52, -1.52, -1.524, -1.524, -1.522, -1.52, -1.525, -1.526, -1.526, -1.532, -1.532, -1.529, -1.53, -1.524, -1.524, -1.528, -1.524, -1.528, -1.525, -1.522, -1.521, -1.52, -1.522, -1.523, -1.522, -1.52, -1.527, -1.524, -1.524, -1.526, -1.527, -1.528, -1.528, -1.522, -1.52, -1.526, -1.522, -1.52, -1.525, -1.523, -1.523, -1.52, -1.52, -1.525, -1.522, -1.522, -1.528, -1.528, -1.528, -1.53, -1.532, -1.534, -1.533, -1.528, -1.526, -1.528, -1.526, -1.525, -1.526, -1.522, -1.522, -1.522, -1.52, -1.525, -1.526, -1.522, -1.526, -1.526, -1.528, -1.532, -1.533, -1.533, -1.533, -1.532, -1.528, -1.528, -1.529, -1.528, -1.528, -1.526, -1.526, -1.524, -1.522, -1.524, -1.522, -1.52, -1.526, -1.528, -1.526, -1.528, -1.53, -1.532, -1.533, -1.53, -1.528, -1.527, -1.526, -1.524, -1.526, -1.527, -1
#   [0.015345711184975887, 1.9922582492263787],
#   [0.023203646531965466, 2.3261324864044273]],
#  [9,
#   [0.02158784434095611, 8.381734981856182],
#   [0.014999694425701635, 1.444060079226499]],
#  [10,
#   [0.03994742381924007, 8.533054462516677],
#   [0.015004931006327167, 1.689393412788492]]]

# %%
lm2=[]
for vv in m2['GAB_results']:
    #mi=min(vv)
    lm2.append(vv[2][1])
lm2
mp2=pd.DataFrame(lm2)
print( mp2.describe().loc['min'].values[0])
#best view mape

li2=[]
for vv in m2['GAB_results']:
    #mi=min(vv)
    li2.append(vv[1][0])
li2
m02=pd.DataFrame(li2)
print(m02.describe().loc['mean'].values[0])
#rmse mean

li3=[]
for vv in m2['GAB_results']:
    #mi=min(vv)
    li3.append(vv[1][1])
li3
m12=pd.DataFrame(li3)
m12.describe().loc['mean'].values[0]
#Mape mean
# Out:
# 1.1171240190655813
# 0.02385515212598547
# 5.154643989020915

# %%
id=2
# Specify the path to the .pkl file
file_path = all_f[id]
D_n=all_f[id].split('.')[-2].split('_')[-1]
mod3=m3=D_n
# Load the object from the .pkl file
with open(file_path, 'rb') as file:
    m3 = pickle.load(file)

# Use the loaded object
print(mod3,m3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-fc2978118379> in <cell line: 3>()
#       1 id=2
#       2 # Specify the path to the .pkl file
# ----> 3 file_path = all_f[id]
#       4 D_n=all_f[id].split('.')[-2].split('_')[-1]
#       5 mod3=m3=D_n
#
# IndexError: list index out of range

# %%
m3['GAB_results']
# Out:
# [[2,
#   [0.015840932488762442, 1.8053467558747143],
#   [0.0059775073554287515, 0.8596094526563776]],
#  [3,
#   [0.00929198033948846, 1.2702884345326313],
#   [0.021892591059456384, 1.7572892920318919]],
#  [4,
#   [0.008748125728077689, 0.9757719751682822],
#   [0.011337155628229076, 1.107492265115508]],
#  [5,
#   [0.009790948597624183, 1.5639840494132289],
#   [0.017617504264999036, 1.4589333707072611]],
#  [6,
#   [0.009830234816406819, 3.6939677173242798],
#   [0.011700161824709359, 1.2395922757502815]],
#  [7,
#   [0.008732380689189962, 1.2940702347761328],
#   [0.02320397782652182, 2.3823985477643377]],
#  [8,
#   [0.011163765663727631, 1.4433339357758257],
#   [0.018068918267813535, 1.5227736894875223]],
#  [9,
#   [0.014273238085241013, 4.055779726309167],
#   [0.019193873949371547, 1.9987064857727568]],
#  [10,
#   [0.011348403658988064, 2.0637355079032536],
#   [0.02199125383229805, 1.8674942666975614]]]

# %%
lm3=[]
for vv in m3['GAB_results']:
    #mi=min(vv)
    lm3.append(vv[2][1])
lm3
mp3=pd.DataFrame(lm3)
print( mp3.describe().loc['min'].values[0])
#best view mape

li4=[]
for vv in m3['GAB_results']:
    #mi=min(vv)
    li4.append(vv[1][0])
li4
m03=pd.DataFrame(li4)
print(m03.describe().loc['mean'].values[0])
#rmse mean

li5=[]
for vv in m3['GAB_results']:
    #mi=min(vv)
    li5.append(vv[1][1])
li5
m13=pd.DataFrame(li5)
m13.describe().loc['mean'].values[0]
#Mape mean
# Out:
# 0.8596094526563776
# 0.01100222334083403
# 2.0184753707863905

# %%
id=3
# Specify the path to the .pkl file
file_path = all_f[id]
D_n=all_f[id].split('.')[-2].split('_')[-1]
#best view mape

li8=[]
for vv in m5['GAB_results']:
    #mi=min(vv)
    li8.append(vv[1][0])
li8
m05=pd.DataFrame(li8)
print(m05.describe().loc['mean'].values[0])
#rmse mean

li9=[]
for vv in m5['GAB_results']:
    #mi=min(vv)
    li9.append(vv[1][1])
li9
m15=pd.DataFrame(li9)
m15.describe().loc['mean'].values[0]
#Mape mean
# Out:
# 0.939959998091591
# 0.02385572632278313
# 5.149925333372307

# %% [markdown]
# # New section

# %%
r=pd.DataFrame()

# %%
r['Test']=m1['y_test']
r[mod1 + '-Tred_Pred']=m1['Trad_predictions']
r[mod1 + '-GAB_Pred']=m1['GAB_predictions']

#r[mod2 + '-test']=m2['y_test']
r[mod2 + '-Tred_Pred']=m2['Trad_predictions']
r[mod2 + '-GAB_Pred']=m2['GAB_predictions']

#r[mod3 + '-test']=m3['y_test']
r[mod3 + '-Tred_Pred']=m3['Trad_predictions']
r[mod3 + '-GAB_Pred']=m3['GAB_predictions']

#r[mod4 + '-test']=m4['y_test']
r[mod4 + '-Tred_Pred']=m4['Trad_predictions']
r[mod4 + '-GAB_Pred']=m4['GAB_predictions']

#r[mod5 + '-test']=m5['y_test']
r[mod5 + '-Tred_Pred']=m5['Trad_predictions']
r[mod5 + '-GAB_Pred']=m5['GAB_predictions']
r.to_csv('Test+Pred_'+Ds_N+'-All_models_Result.csv')
r
# Out:
#        Test  CNN-Tred_Pred  CNN-GAB_Pred  BiLSTM-Tred_Pred  BiLSTM-GAB_Pred
# 0    -1.397      -1.401846     -1.471957         -1.418981        -1.418768
# 1    -1.407      -1.407312     -1.478412         -1.424085        -1.427104
# 2    -1.416      -1.414761     -1.486719         -1.430320        -1.436621
# 3    -1.419      -1.423313     -1.495880         -1.437337        -1.444009
# 4    -1.425      -1.429536     -1.502278         -1.443234        -1.448563
# ...     ...            ...           ...               ...              ...
# 1992 -1.653      -1.648343     -1.739637         -1.653624        -1.665761
# 1993 -1.645      -1.649366     -1.738729         -1.654896        -1.657594
# 1994 -1.648      -1.645347     -1.735470         -1.653169        -1.657520
# 1995 -1.649      -1.644180     -1.734632         -1.652019        -1.661352
# 1996 -1.639      -1.643830     -1.734632         -1.651347        -1.661352
#
# [1997 rows x 5 columns]

# %%
tpp=pd.DataFrame(
    [
        [m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],
         m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],
         m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],
         m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],
         m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],],
        ],
    columns=pd.MultiIndex.from_product([[mod1,mod2,mod3,mod4,mod5],['Test','Trad_predictions','GAB_predictions']])
)
tpp
# Out:
#                                                  RNN  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                 LSTM  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                       GRU(2-10 view)  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                  CNN  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                               BiLSTM  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....

# %%
import pandas as pd

# Create an empty multi-index column DataFrame
columns = pd.MultiIndex.from_product([[mod1,mod2,mod3,mod4,mod5],['Test','Trad_predictions','GAB_predictions']])

df = pd.DataFrame(columns=columns)

# List of values to insert
values = [m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],m1['y_test'],m1['Trad_predictions'],m1['GAB_predictions'],]

# Insert the values into the multi-index columns
df.loc[0] = values

df
# Out:
#                                                  RNN  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                 LSTM  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                       GRU(2-10 view)  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                  CNN  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                                       \
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#                                               BiLSTM  \
#                                                 Test
# 0  [-1.397, -1.407, -1.416, -1.419, -1.425, -1.43...
#
#                                                       \
#                                     Trad_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....
#
#
#                                      GAB_predictions
# 0  [-1.3774352073669434, -1.3838554620742798, -1....

# %%
imp = pd.DataFrame(
    [
        [m01.describe().loc['mean'].values[0],m1['GAB_results'][m1['best_views']-2][2][0],((m01.describe().loc['mean'].values[0]-m1['GAB_results'][m1['best_views']-2][2][0])*100)/m01.describe().loc['mean'].values[0],
         m11.describe().loc['mean'].values[0],mp1.describe().loc['min'].values[0],m11.describe().loc['mean'].values[0]-mp1.describe().loc['min'].values[0],
         m02.describe().loc['mean'].values[0],m2['GAB_results'][m2['best_views']-2][2][0],((m02.describe().loc['mean'].values[0]-m2['GAB_results'][m2['best_views']-2][2][0])*100)/m02.describe().loc['mean'].values[0],
         m12.describe().loc['mean'].values[0],mp2.describe().loc['min'].values[0],m12.describe().loc['mean'].values[0]-mp2.describe().loc['min'].values[0],
         m03.describe().loc['mean'].values[0],m3['GAB_results'][m3['best_views']-2][2][0],((m03.describe().loc['mean'].values[0]-m3['GAB_results'][m3['best_views']-2][2][0])*100)/m03.describe().loc['mean'].values[0],
         m13.describe().loc['mean'].values[0],mp3.describe().loc['min'].values[0],m13.describe().loc['mean'].values[0]-mp3.describe().loc['min'].values[0],
         m04.describe().loc['mean'].values[0],m4['GAB_results'][m4['best_views']-6][2][0],((m04.describe().loc['mean'].values[0]-m4['GAB_results'][m4['best_views']-6][2][0])*100)/m04.describe().loc['mean'].values[0],
         m14.describe().loc['mean'].values[0],mp4.describe().loc['min'].values[0],m14.describe().loc['mean'].values[0]-mp4.describe().loc['min'].values[0],
         m05.describe().loc['mean'].values[0],m5['GAB_results'][m4['best_views']-2][2][0],((m05.describe().loc['mean'].values[0]-m5['GAB_results'][m5['best_views']-2][2][0])*100)/m05.describe().loc['mean'].values[0],
         m15.describe().loc['mean'].values[0],mp5.describe().loc['min'].values[0],m15.describe().loc['mean'].values[0]-mp4.describe().loc['min'].values[0],],
    ],

    columns = pd.MultiIndex.from_product([[mod1,mod2,mod3,mod4,mod5],['RMSE','MAPE'],['mean','best','improve']])
)
#imp.to_csv('Improv_'+Ds_N+'-All_models_Result.csv')

imp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6ace432c4d74> in <cell line: 1>()
#       5          m02.describe().loc['mean'].values[0],m2['GAB_results'][m2['best_views']-2][2][0],((m02.describe().loc['mean'].values[0]-m2['GAB_results'][m2['best_views']-2][2][0])*100)/m02.describe().loc['mean'].values[0],
#       6          m12.describe().loc['mean'].values[0],mp2.describe().loc['min'].values[0],m12.describe().loc['mean'].values[0]-mp2.describe().loc['min'].values[0],
# ----> 7          m03.describe().loc['mean'].values[0],m3['GAB_results'][m3['best_views']-2][2][0],((m03.describe().loc['mean'].values[0]-m3['GAB_results'][m3['best_views']-2][2][0])*100)/m03.describe().loc['mean'].values[0],
#       8          m13.describe().loc['mean'].values[0],mp3.describe().loc['min'].values[0],m13.describe().loc['mean'].values[0]-mp3.describe().loc['min'].values[0],
#       9          m04.describe().loc['mean'].values[0],m4['GAB_results'][m4['best_views']-6][2][0],((m04.describe().loc['mean'].values[0]-m4['GAB_results'][m4['best_views']-6][2][0])*100)/m04.describe().loc['mean'].values[0],
#
# NameError: name 'm03' is not defined
