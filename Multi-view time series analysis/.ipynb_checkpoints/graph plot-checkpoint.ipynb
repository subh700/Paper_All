# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob
all_f= glob.glob('Test+Pre*.csv')
all_f
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %%
all_f
# Out:
# ['Test+Pred_Tetuan_City_Power_Consumption_Zone1_processed-All_models_Result.csv',
#  'Test+Pred_PM2.5_p09_data-All_models_Result.csv',
#  'Test+Pred_POWER_Point_Daily_Presure_Data-All_models_Result.csv',
#  'Test+Pred_Healthy_control_heart_data-All_models_Result.csv',
#  'Test+Pred_POWER_Point_Daily_Temperature_Data-All_models_Result.csv',
#  'Test+Pred_Myocardial_infarction_heart_data-All_models_Result.csv',
#  'Test+Pred_Daily_Sunspot_data-All_models_Result.csv']

# %%
li[0]
# Out:
#        Unnamed: 0         Test  LSTM-Tred_Pred  LSTM-GAB_Pred  CNN-Tred_Pred  \
# 0               0  26758.16193    27290.158203   26915.545446   27646.851562
# 1               1  26707.74617    26983.933594   26630.308258   27173.585938
# 2               2  27054.35449    26987.734375   26793.090194   27147.447266
# 3               3  26827.48359    27434.189453   26951.539541   27675.427734
# 4               4  26487.17724    27024.992188   26346.760666   27150.158203
# ...           ...          ...             ...            ...            ...
# 10475       10475  31160.45627    31853.476562   31961.874329   31705.132812
# 10476       10476  30430.41825    30688.371094   30840.837311   30518.515625
# 10477       10477  29590.87452    30042.988281   30125.146074   29941.300781
# 10478       10478  28958.17490    29118.742188   29185.706378   29094.712891
# 10479       10479  28349.80989    28588.238281   29185.706378   28582.986328
#
# ...

# %%
v=all_f[0].split(r"Pred_")
v_n=v[1]
D=v_n.split(r"-")
D_n=D[0]
D_n
# Out:
# 'Tetuan_City_Power_Consumption_Zone1_processed'

# %%
"""df=li[0]
df=df.iloc[:,-11:]"""
fig, ax = plt.subplots(4, 4, figsize=(18 , 12),layout='constrained')
#ax[0,0].plot(df.iloc[:120,:])
#ax[0,0].plot(df.iloc[:120,0:2])
#ax[0,0].plot(df.iloc[:120,4:5])

d=0 #df sirla no.
n=12 # no of data points
r=0 #row number 
col=0 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

d=1 #df sirla no.
n=12 # no of data points
r=0 #row number 
col=2 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

d=2 #df sirla no.
n=12 # no of data points
r=1 #row number 
col=0 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

d=3 #df sirla no.
n=12 # no of data points
r=1 #row number 
col=2 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

d=4 #df sirla no.
n=12 # no of data points
r=2 #row number 
col=0 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

d=5 #df sirla no.
n=12 # no of data points
r=2 #row number 
col=2 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

d=6 #df sirla no.
n=12 # no of data points
r=3 #row number 
col=0 #column no
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,1:2],label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,3:4],label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,5:6],label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,7:8],label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0])
ax[r,col].plot(li[d].iloc[:,-11:].iloc[:n,9:10],label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0])
ax[r,col].legend()
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,2:3],label=li[d].iloc[:,-11:].iloc[:n,2:3].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5],label=li[d].iloc[:,-11:].iloc[:n,4:5].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,6:7],label=li[d].iloc[:,-11:].iloc[:n,6:7].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,8:9],label=li[d].iloc[:,-11:].iloc[:n,8:9].columns[0])
ax[r,col+1].plot(li[d].iloc[:,-11:].iloc[:n,10:11],label=li[d].iloc[:,-11:].iloc[:n,10:11].columns[0])
ax[r,col+1].legend()

# %%
df=li[2]
df
# Out:
#       Unnamed: 0   Test  LSTM (1)-Tred_Pred  LSTM (1)-GAB_Pred  CNN-Tred_Pred  \
# 0              0   8.00            9.228134           8.152745       9.412119
# 1              1   7.14            7.585484           7.209561       7.696990
# 2              2   5.98            7.029132           6.545438       7.187947
# 3              3   5.68            5.814093           6.072080       5.993716
# 4              4   6.47            5.764594           6.955918       5.930829
# ...          ...    ...                 ...                ...            ...
# 2932        2932   6.96            7.470569           7.292533       7.533046
# 2933        2933   7.26            7.017481           7.685044       7.130601
# 2934        2934   7.32            7.535564           7.608163       7.522304
# 2935        2935   8.18            7.418070           8.423802       7.458185
# 2936        2936  10.93            8.541460           8.423802       8.482602
#
# ...

# %% [markdown]
# ## scatter plot

# %%
fig, axs = plt.subplots(5, 4, figsize=(22, 12), layout='constrained')
#axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label='Trad')
axs[0,0].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,1:2].min(),li[0].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Actual Reference Line')

axs[0,1].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='Gab')
axs[0,1].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,2:3].min(),li[0].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Actual Reference Line')

#ax.scatter(df.iloc[:, j-1:j],df.iloc[:,k-1:k],color= "#00000F",marker='^',label='Normal')
#ax.scatter(df.iloc[:, j-1:j],df.iloc[:,j+k-2:j+k-1],color='#737373',label='GAB')

axs[0,2].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label='Trad')
axs[0,2].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,3:4].min(),li[0].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Actual Reference Line')

axs[0,3].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='Gab')
axs[0,3].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,4:5].min(),li[0].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Actual Reference Line')



axs[1,0].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label='Trad')
axs[1,0].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,3:4].min(),li[0].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Actual Reference Line')

axs[1,0].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='Gab') # ,alpha=0.1 control transprancy
axs[1,0].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,4:5].min(),li[0].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Actual Reference Line')
