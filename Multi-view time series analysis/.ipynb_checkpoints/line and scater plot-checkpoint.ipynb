# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import textwrap
import os
from sklearn.metrics import r2_score

# %%
import glob
all_f= glob.glob('Test+Pre*.csv')
all_f
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %%
all_f
# Out:
# ['Test+Pred_Daily_Sunspot_data-All_models_Result.csv',
#  'Test+Pred_Healthy_control_heart_data-All_models_Result.csv',
#  'Test+Pred_Metro_Interstate_Traffic_Volume_PD-All_models_Result.csv',
#  'Test+Pred_Myocardial_infarction_heart_data-All_models_Result.csv',
#  'Test+Pred_PM2.5_p09_data-All_models_Result.csv',
#  'Test+Pred_POWER_Point_Daily_Presure_Data-All_models_Result.csv',
#  'Test+Pred_POWER_Point_Daily_Temperature_Data-All_models_Result.csv',
#  'Test+Pred_Tetuan_City_Power_Consumption_Zone1_processed-All_models_Result.csv']

# %%
li[0]
# Out:
#        Unnamed: 0   Test  LSTM-Tred_Pred  LSTM-GAB_Pred  CNN-Tred_Pred  \
# 0               0  291.0      230.313385     255.966437     233.638214
# 1               1  284.0      309.078857     322.788381     307.180511
# 2               2  319.0      299.443054     294.869075     305.604553
# 3               3  364.0      322.494019     322.964144     331.830566
# 4               4  340.0      375.635162     366.149889     375.881287
# ...           ...    ...             ...            ...            ...
# 14973       14973   84.0      108.567627     107.355693     109.549316
# 14974       14974   84.0       85.980049      79.099776      84.455849
# 14975       14975   77.0       86.211266      87.925219      83.363495
# 14976       14976   75.0       80.417221      82.025664      79.958000
# 14977       14977   77.0       80.245071      82.025664      79.834099
#
#        CNN-GAB_Pred  BiLSTM-Tred_Pred  BiLSTM-GAB_Pred  GRU-Tred_Pred  \
# ...

# %%
v=all_f[0].split(r"Pred_")
v_n=v[1]
D=v_n.split(r"-")[0].split("_data")
D_n=D[0]
D_n
# Out:
# 'Daily_Sunspot'

# %%
fig, ax = plt.subplots(8, 5, figsize=(21, 16), layout='constrained')
fig.subplots_adjust(right=0.8) # Add space for legend
handles, labels = None, None # Initialize handles and labels
n = 72  # number of data points

row = 0  # row number
col = 0  # column number

for d in range(8):
    ax[row, col].plot(li[d].iloc[:,-11:].iloc[:n,0:1], label='Orignal_Test')
    ax[row, col].plot(li[d].iloc[:,-11:].iloc[:n,1:2], label=li[d].iloc[:,-11:].iloc[:n,1:2].columns[0].split(r'_')[0]+'_Pred.')
    ax[row, col].plot(li[d].iloc[:,-11:].iloc[:n,2:3], label='MvGR2_Pred')
    #ax[row, col].legend(fancybox=True, framealpha=1)
    ax[row, col].legend().set_visible(False)

    ax[row, col+1].plot(li[d].iloc[:,-11:].iloc[:n,0:1], label='Orignal_Test')
    ax[row, col+1].plot(li[d].iloc[:,-11:].iloc[:n,3:4], label=li[d].iloc[:,-11:].iloc[:n,3:4].columns[0].split(r'_')[0]+'_Pred.')
    ax[row, col+1].plot(li[d].iloc[:,-11:].iloc[:n,4:5], label='MvGR2_Pred')
    #ax[row, col+1].legend(fancybox=True, framealpha=1)
    ax[row, col+1].legend().set_visible(False)

    ax[row, col+2].plot(li[d].iloc[:,-11:].iloc[:n,0:1], label='Orignal_test')
    ax[row, col+2].plot(li[d].iloc[:,-11:].iloc[:n,5:6], label=li[d].iloc[:,-11:].iloc[:n,5:6].columns[0].split(r'_')[0]+'_Pred.')
    ax[row, col+2].plot(li[d].iloc[:,-11:].iloc[:n,6:7], label='MvGR2_Pred')
    #ax[row, col+2].legend(fancybox=True, framealpha=1)
    ax[row, col+2].legend().set_visible(False)

    ax[row, col+3].plot(li[d].iloc[:,-11:].iloc[:n,0:1], label='Orignal_test')
    ax[row, col+3].plot(li[d].iloc[:,-11:].iloc[:n,7:8], label=li[d].iloc[:,-11:].iloc[:n,7:8].columns[0].split(r'_')[0]+'_Pred.')
    ax[row, col+3].plot(li[d].iloc[:,-11:].iloc[:n,8:9], label='MvGR2_Pred')
    #ax[row, col+3].legend(fancybox=True, framealpha=1)
    ax[row, col+3].legend().set_visible(False)

    ax[row, col+4].plot(li[d].iloc[:,-11:].iloc[:n,0:1], label='Orignal_test')
    ax[row, col+4].plot(li[d].iloc[:,-11:].iloc[:n,9:10], label=li[d].iloc[:,-11:].iloc[:n,9:10].columns[0].split(r'_')[0].split(r'-')[1]+'_Pred.')
    ax[row, col+4].plot(li[d].iloc[:,-11:].iloc[:n,10:11], label='MvGR2_Pred')
    #ax[row, col+4].legend(fancybox=True, framealpha=.4)
    ax[row, col+4].legend().set_visible(False)
    
    ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=17))
    if row in range(0,8,2):
        ax[row, col+4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
        ax[row, col+4].yaxis.set_label_coords(1.15, .5)
    else:
        ax[row, col+4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='green')
        ax[row, col+4].yaxis.set_label_coords(1.15, .5)
    if row == 7:
        ax[row, col].set_xlabel('No. of samples', fontsize=12, weight='bold')
        ax[row, col+1].set_xlabel('No. of samples', fontsize=12, weight='bold')
        ax[row, col+2].set_xlabel('No. of samples', fontsize=12, weight='bold')
        ax[row, col+3].set_xlabel('No. of samples', fontsize=12, weight='bold')
        ax[row, col+4].set_xlabel('No. of samples', fontsize=12, weight='bold')
        
    if row == 0:
        ax[row,col].set_title(li[d].iloc[:,-11:].iloc[:n,1:2].columns[0].split(r'_')[0].split(r'-')[0], fontsize=12)
        ax[row,col+1].set_title(li[d].iloc[:,-11:].iloc[:n,3:4].columns[0].split(r'_')[0].split(r'-')[0], fontsize=12)
        ax[row,col+2].set_title(li[d].iloc[:,-11:].iloc[:n,5:6].columns[0].split(r'_')[0].split(r'-')[0], fontsize=12)
        ax[row,col+3].set_title(li[d].iloc[:,-11:].iloc[:n,7:8].columns[0].split(r'_')[0].split(r'-')[0], fontsize=12)
        ax[row,col+4].set_title(li[d].iloc[:,-11:].iloc[:n,9:10].columns[0].split(r'_')[0].split(r'-')[0], fontsize=12)
    row += 1
    for r in range(0,8,2):
        for c in range(5):
            ax[r,c].spines['top'].set_color('red')
            ax[r,c].spines['right'].set_color('red')
            ax[r,c].spines['right'].set_linewidth(3)
            ax[r,c].spines['top'].set_linewidth(3)
            ax[r+1,c].spines['top'].set_color('green')
            ax[r+1,c].spines['right'].set_color('green')
            ax[r+1,c].spines['right'].set_linewidth(3)
            ax[r+1,c].spines['top'].set_linewidth(3)
            c += 1
        r += 1
# Add a common legend outside of the subplots
handles, labels = ax[1,col+4].get_legend_handles_labels()
legend =fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.96, 1.03), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')

plt.savefig('act vs pri',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
# Out:
# C:\Users\vp123\AppData\Local\Temp\ipykernel_24320\2165403488.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend

# %%
fig, axs = plt.subplots(5, 4, figsize=(22, 12), layout='constrained')
#axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label='Trad')
axs[0,0].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,1:2].min(),li[0].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[0,0].spines['top'].set_color('red')
axs[0,0].spines['top'].set_linewidth(3)
axs[0,0].legend(fancybox=True, framealpha=1)
axs[0,1].scatter(li[0].iloc[:,-11:].iloc[:,0:1],li[0].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='Gab')
axs[0,1].plot([li[0].iloc[:,-11:].iloc[:,0:1].min(),li[0].iloc[:,-11:].iloc[:,0:1].max()],[li[0].iloc[:,-11:].iloc[:,2:3].min(),li[0].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[0,1].spines['top'].set_color('red')
axs[0,1].spines['top'].set_linewidth(3)
axs[0,1].legend(fancybox=True, framealpha=1)

# %%
fig, axs = plt.subplots(6, 5, figsize=(21, 14), layout='constrained')
fig.subplots_adjust(right=0.8) # Add space for legend
handles, labels = None, None # Initialize handles and labels
#axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
d=0
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=0
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0].split(r'-')[1])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
# Add a common legend outside of the subplots
handles, labels = axs[r+1,4].get_legend_handles_labels()
legend=fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.99, 1.04), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')
handles, labels = axs[r,4].get_legend_handles_labels()
legend=fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.77, 1.04), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')
ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)


d=1
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=2
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)



d=2
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=4
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)

# set titel
axs[0,0].set_title(li[d].iloc[:,-11:].iloc[:,1:2].columns[0].split(r'-')[0].split(r'(')[0], fontsize=12)
axs[0,1].set_title(li[d].iloc[:,-11:].iloc[:,3:4].columns[0].split(r'-')[0], fontsize=12)
axs[0,2].set_title(li[d].iloc[:,-11:].iloc[:,5:6].columns[0].split(r'-')[0],fontsize=12)
axs[0,3].set_title(li[d].iloc[:,-11:].iloc[:,7:8].columns[0].split(r'-')[0], fontsize=12)
axs[0,4].set_title(li[d].iloc[:,-11:].iloc[:,9:10].columns[0].split(r'-')[0], fontsize=12)

'''for cc in range(0,5):
    
    axs[0,cc].set_title(li[d].iloc[:,-11:].iloc[:,r+1:r+2].columns[0].split(r'-')[0].split(r'(')[0], fontsize=12)
    r +=2'''
for co in range(0,5):
    axs[5,co].set_xlabel('Test Data', fontsize=12, weight='bold')
for ro in range(0,6):
    axs[ro,0].set_ylabel('Pred', fontsize=14, weight='bold')
    
    
plt.savefig('scatter-0',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
# Out:
# C:\Users\vp123\AppData\Local\Temp\ipykernel_24320\3511716495.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend

# %%
fig, axs = plt.subplots(6, 5, figsize=(21, 14), layout='constrained')
fig.subplots_adjust(right=0.8) # Add space for legend
handles, labels = None, None # Initialize handles and labels
#axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
d=3
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=0
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0].split(r'-')[1])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
# Add a common legend outside of the subplots
handles, labels = axs[r+1,4].get_legend_handles_labels()
legend=fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.99, 1.04), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')
handles, labels = axs[r,4].get_legend_handles_labels()
legend=fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.77, 1.04), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')
ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)


d=4
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=2
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)



d=5
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=4
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)

# set titel
axs[0,0].set_title(li[d].iloc[:,-11:].iloc[:,1:2].columns[0].split(r'-')[0].split(r'(')[0], fontsize=12)
axs[0,1].set_title(li[d].iloc[:,-11:].iloc[:,3:4].columns[0].split(r'-')[0], fontsize=12)
axs[0,2].set_title(li[d].iloc[:,-11:].iloc[:,5:6].columns[0].split(r'-')[0],fontsize=12)
axs[0,3].set_title(li[d].iloc[:,-11:].iloc[:,7:8].columns[0].split(r'-')[0], fontsize=12)
axs[0,4].set_title(li[d].iloc[:,-11:].iloc[:,9:10].columns[0].split(r'-')[0], fontsize=12)

'''for cc in range(0,5):
    
    axs[0,cc].set_title(li[d].iloc[:,-11:].iloc[:,r+1:r+2].columns[0].split(r'-')[0].split(r'(')[0], fontsize=12)
    r +=2'''
for co in range(0,5):
    axs[5,co].set_xlabel('Test Data', fontsize=12, weight='bold')
for ro in range(0,6):
    axs[ro,0].set_ylabel('Pred', fontsize=14, weight='bold')

plt.savefig('scatter-1',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
# Out:
# C:\Users\vp123\AppData\Local\Temp\ipykernel_26960\2384478790.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend

# %%
fig, axs = plt.subplots(4, 5, figsize=(21, 10), layout='constrained')
fig.subplots_adjust(right=0.8) # Add space for legend
handles, labels = None, None # Initialize handles and labels
#axs[0,0].scatter(li[0].iloc[:,-11:].iloc[:n,0:1],label=li[d].iloc[:,-11:].iloc[:n,0:1].columns[0])
d=6
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=0
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0].split(r'-')[1])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
# Add a common legend outside of the subplots
handles, labels = axs[r+1,4].get_legend_handles_labels()
legend=fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.99, 1.04), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')
handles, labels = axs[r,4].get_legend_handles_labels()
legend=fig.legend(handles, labels, ncol=5, bbox_to_anchor=(.77, 1.04), fontsize=12, fancybox=True, framealpha=1)
for text in legend.texts:
    text.set_weight('bold')
ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)


d=7
test=li[d].iloc[:,-11:].iloc[:,0:1]
r=2
axs[r,0].scatter(test,li[d].iloc[:,-11:].iloc[:,1:2],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,1:2].columns[0])
axs[r,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,1:2].min(),li[d].iloc[:,-11:].iloc[:,1:2].max()],color='#737373',label='Reference Line')
axs[r,0].spines['top'].set_color('red')
axs[r,0].spines['top'].set_linewidth(3)
axs[r,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 1:2]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,0].scatter(test,li[d].iloc[:,-11:].iloc[:,2:3],color= "#737373",label='MvGR2_Pred')
axs[r+1,0].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,2:3].min(),li[d].iloc[:,-11:].iloc[:,2:3].max()],color='black',label='Reference Line')
axs[r+1,0].spines['top'].set_color('green')
axs[r+1,0].spines['top'].set_linewidth(3)
axs[r+1,0].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1, 0].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 2:3]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,1].scatter(test,li[d].iloc[:,-11:].iloc[:,3:4],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,3:4].columns[0])
axs[r,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,3:4].min(),li[d].iloc[:,-11:].iloc[:,3:4].max()],color='#737373',label='Reference Line')
axs[r,1].spines['top'].set_color('red')
axs[r,1].spines['top'].set_linewidth(3)
axs[r,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 3:4]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,1].scatter(test,li[d].iloc[:,-11:].iloc[:,4:5],color= "#737373",label='MvGR2_Pred')
axs[r+1,1].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,4:5].min(),li[d].iloc[:,-11:].iloc[:,4:5].max()],color='black',label='Reference Line')
axs[r+1,1].spines['top'].set_color('green')
axs[r+1,1].spines['top'].set_linewidth(3)
axs[r+1,1].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,1].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 4:5]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,2].scatter(test,li[d].iloc[:,-11:].iloc[:,5:6],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,5:6].columns[0])
axs[r,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,5:6].min(),li[d].iloc[:,-11:].iloc[:,5:6].max()],color='#737373',label='Reference Line')
axs[r,2].spines['top'].set_color('red')
axs[r,2].spines['top'].set_linewidth(3)
axs[r,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 5:6]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,2].scatter(test,li[d].iloc[:,-11:].iloc[:,6:7],color= "#737373",label='MvGR2_Pred')
axs[r+1,2].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,6:7].min(),li[d].iloc[:,-11:].iloc[:,6:7].max()],color='black',label='Reference Line')
axs[r+1,2].spines['top'].set_color('green')
axs[r+1,2].spines['top'].set_linewidth(3)
axs[r+1,2].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,2].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 6:7]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,3].scatter(test,li[d].iloc[:,-11:].iloc[:,7:8],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,7:8].columns[0])
axs[r,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,7:8].min(),li[d].iloc[:,-11:].iloc[:,7:8].max()],color='#737373',label='Reference Line')
axs[r,3].spines['top'].set_color('red')
axs[r,3].spines['top'].set_linewidth(3)
axs[r,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 7:8]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,3].scatter(test,li[d].iloc[:,-11:].iloc[:,8:9],color= "#737373",label='MvGR2_Pred')
axs[r+1,3].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,8:9].min(),li[d].iloc[:,-11:].iloc[:,8:9].max()],color='black',label='Reference Line')
axs[r+1,3].spines['top'].set_color('green')
axs[r+1,3].spines['top'].set_linewidth(3)
axs[r+1,3].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,3].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 8:9]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

axs[r,4].scatter(test,li[d].iloc[:,-11:].iloc[:,9:10],color= "#00000F",marker='^',label=li[d].iloc[:,-11:].iloc[:,9:10].columns[0])
axs[r,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,9:10].min(),li[d].iloc[:,-11:].iloc[:,9:10].max()],color='#737373',label='Reference Line')
axs[r,4].spines['top'].set_color('red')
axs[r,4].spines['top'].set_linewidth(3)
axs[r,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 9:10]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')
axs[r+1,4].scatter(test,li[d].iloc[:,-11:].iloc[:,10:11],color= "#737373",label='MvGR2_Pred')
axs[r+1,4].plot([test.min(),test.max()],[li[d].iloc[:,-11:].iloc[:,10:11].min(),li[d].iloc[:,-11:].iloc[:,10:11].max()],color='black',label='Reference Line')
axs[r+1,4].spines['top'].set_color('green')
axs[r+1,4].spines['top'].set_linewidth(3)
axs[r+1,4].legend(fancybox=True, framealpha=1).set_visible(False)
axs[r+1,4].annotate(f"R\u00b2: {np.round(r2_score(test,li[d].iloc[:, -11:].iloc[:, 10:11]), 3).astype(np.float64)}", xy=(0.75, 0.05), xycoords='axes fraction', fontsize=12 ,weight='bold')

ylabel_text = '\n'.join(textwrap.wrap(all_f[d].split(r'Pred_')[1].split(r'-')[0].split('_data')[0], width=30))
axs[r+1,4].set_ylabel(ylabel_text, rotation=270, fontsize=12, va='center', linespacing=1.5,color='red')
axs[r+1,4].yaxis.set_label_coords(1.1, 1)





# set titel
axs[0,0].set_title(li[d].iloc[:,-11:].iloc[:,1:2].columns[0].split(r'-')[0].split(r'(')[0], fontsize=12)
axs[0,1].set_title(li[d].iloc[:,-11:].iloc[:,3:4].columns[0].split(r'-')[0], fontsize=12)
axs[0,2].set_title(li[d].iloc[:,-11:].iloc[:,5:6].columns[0].split(r'-')[0],fontsize=12)
axs[0,3].set_title(li[d].iloc[:,-11:].iloc[:,7:8].columns[0].split(r'-')[0], fontsize=12)
axs[0,4].set_title(li[d].iloc[:,-11:].iloc[:,9:10].columns[0].split(r'-')[0], fontsize=12)

'''for cc in range(0,5):
    
    axs[0,cc].set_title(li[d].iloc[:,-11:].iloc[:,r+1:r+2].columns[0].split(r'-')[0].split(r'(')[0], fontsize=12)
    r +=2'''
for co in range(0,5):
    axs[3,co].set_xlabel('Test Data', fontsize=12, weight='bold')
for ro in range(0,4):
    axs[ro,0].set_ylabel('Pred', fontsize=14, weight='bold')
    
plt.savefig('scatter-2',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
# Out:
# C:\Users\vp123\AppData\Local\Temp\ipykernel_26960\310502124.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(right=0.8) # Add space for legend
