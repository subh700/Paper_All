# %%
### Data decribe 
import pandas as pd 
import numpy as np

import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.gridspec as gridspec
import time
#from pycaret.time_series import TSForecastingExperiment
import statsmodels.api as sm

# %%
import glob
all_f= glob.glob('TS_Datasets/*.csv')
all_f
# Out:
# ['TS_Datasets\\Daily_Sunspot_data.csv',
#  'TS_Datasets\\Healthy_control_heart_data.csv',
#  'TS_Datasets\\Metro_Interstate_Traffic_Volume_PD.csv',
#  'TS_Datasets\\Myocardial_infarction_heart_data.csv',
#  'TS_Datasets\\PM2.5_p09_data.csv',
#  'TS_Datasets\\POWER_Point_Daily_Presure_Data.csv',
#  'TS_Datasets\\POWER_Point_Daily_Temperature_Data.csv',
#  'TS_Datasets\\Tetuan_City_Power_Consumption_Zone1_processed.csv']

# %%
li=[]
for file_name in all_f:
    df=pd.read_csv(file_name)
    li.append(df)

# %%
Greenfig, ax = plt.subplots(8, 4, figsize=(20 , 24),layout='constrained')
i=0
j=0

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')
ax[j,0].set_title('Orignal',fontsize = 14,weight='bold')
ax[j,1].set_title('Seasonal',fontsize = 14,weight='bold')
ax[j,2].set_title('Trand',fontsize = 14,weight='bold')
ax[j,3].set_title('Autocorrelation',fontsize = 14,weight='bold')
i=1
j=1

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=2
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Volu")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=3
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=4
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=5
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=6
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=7
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Zone")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_acf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')



# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='DATE', ylabel='PM2.5')
   # ax1.set_xlabel('DATE',fontsize = 14,weight='bold')
    #ax1.set_ylabel('PM2.5',fontsize = 14,weight='bold')
    for tick in ax1.get_xticklabels():
        tick.set_rotation(18)
#plt.show()
plt.savefig('MVgr2_st+acf_g=80.jpeg',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')

# %%
Greenfig, ax = plt.subplots(8, 4, figsize=(20 , 24),layout='constrained')
i=0
j=0

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')
ax[j,0].set_title('Orignal',fontsize = 14,weight='bold')
ax[j,1].set_title('Seasonal',fontsize = 14,weight='bold')
ax[j,2].set_title('Trand',fontsize = 14,weight='bold')
ax[j,3].set_title('Partial Autocorrelation',fontsize = 14,weight='bold')
i=1
j=1

df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=2
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Volu")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=3
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=60)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=4
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=24)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')


i=j=5
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=6
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Data.csv")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize =10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')

i=j=7
df=li[i]

df1=df.iloc[-480:,-1:]
D_n=all_f[i].split("\\")[1].split("_Zone")[0]
decomposition = sm.tsa.seasonal_decompose(df1[df1.iloc[:,-1:].columns[0]], model='additive',period=30)
ax[j,0].plot(df1.index, df1[df1.iloc[:,-1:].columns[0]],color= "#000000" )
ax[j,0].set_ylabel(D_n,fontsize = 10,weight='bold')
ax[j,1].plot(df1.index, decomposition.seasonal,color= "#000000")
ax[j,2].plot(df1.index, decomposition.trend,color= "#000000")
sm.graphics.tsa.plot_pacf(df, lags=80, ax=ax[j,3],color="#000000",vlines_kwargs={"colors": "#000000"})
ax[j,3].set_title('',fontsize = 14,weight='bold')



# Rotating X-axis labels
for ax1 in ax.flat:
    #ax1.set(xlabel='DATE', ylabel='PM2.5')
   # ax1.set_xlabel('DATE',fontsize = 14,weight='bold')
    #ax1.set_ylabel('PM2.5',fontsize = 14,weight='bold')
    for tick in ax1.get_xticklabels():
        tick.set_rotation(18)
#plt.show()
plt.savefig('MVgr2_st+pacf_g=80.jpeg',dpi=600,bbox_inches ="tight",pad_inches = 0.1,transparent = False,facecolor ="w",edgecolor ='w',orientation ='landscape')
