# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential,Model
from keras.layers import Input,Conv1D,MaxPooling1D,GRU,LSTM,Bidirectional,Dense,Dropout,Flatten
from sklearn.preprocessing import MinMaxScaler
from keras.regularizers import l1
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
# Out:
# 2023-04-10 03:56:28.297659: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-10 03:56:28.345324: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-10 03:56:28.345943: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-10 03:56:29.327531: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df=pd.read_csv('../PRSA_data_2010.1.1-2014.12.31.csv')
df=df.iloc[:,1:-7]
df["Date"] = pd.to_datetime(df["year"].apply(str) + "/" + df["month"].apply(str) + "/" + df["day"].apply(str)+ " " + df["hour"].apply(str)+ ":" +"00")
df=df.drop(['year','month','day','hour'],axis=1)
df=df.dropna()
df=df.rename(columns={'Date':'DATE','pm2.5':'PM'})
df=df.set_index('DATE')
df
# Out:
#                         PM
# DATE
# 2010-01-02 00:00:00  129.0
# 2010-01-02 01:00:00  148.0
# 2010-01-02 02:00:00  159.0
# 2010-01-02 03:00:00  181.0
# 2010-01-02 04:00:00  138.0
# ...                    ...
# 2014-12-31 19:00:00    8.0
# 2014-12-31 20:00:00   10.0
# 2014-12-31 21:00:00   10.0
# 2014-12-31 22:00:00    8.0
# 2014-12-31 23:00:00   12.0
#
# [41757 rows x 1 columns]

# %%
df.describe()
# Out:
#                  PM
# count  41757.000000
# mean      98.613215
# std       92.050387
# min        0.000000
# 25%       29.000000
# 50%       72.000000
# 75%      137.000000
# max      994.000000

# %%
data=df

# %%
# Scale data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
data
# Out:
# array([[0.12977867],
#        [0.14889336],
#        [0.15995976],
#        ...,
#        [0.01006036],
#        [0.00804829],
#        [0.01207243]])

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_data, test_data = data[0:train_size,:], data[train_size:len(data),:]

# %%
print(train_size,test_size)
print(train_data,test_data)
print(len(train_data),len(test_data))
# Out:
# 33405 8352
# [[0.12977867]
#  [0.14889336]
#  [0.15995976]
#  ...
#  [0.30080483]
#  [0.25150905]
#  [0.15995976]] [[0.12474849]
#  [0.12374245]
#  [0.04929577]
#  ...
#  [0.01006036]
#  [0.00804829]
#  [0.01207243]]
# 33405 8352

# %%
# Convert data into time series dataset
def create_dataset(dataset, look_back=24):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i+look_back), 0])
        Y.append(dataset[i+look_back, 0])
    return np.array(X), np.array(Y)

# %%
look_back = 24
train_X, train_Y = create_dataset(train_data, look_back)
test_X, test_Y = create_dataset(test_data, look_back)

# %%
#print(train_X,train_Y)
#print(test_X,test_Y)
print(train_Y,test_Y)
# Out:
# [0.09054326 0.06338028 0.06539235 ... 0.30080483 0.25150905 0.15995976] [0.17303823 0.21428571 0.1971831  ... 0.01006036 0.00804829 0.01207243]

# %%
len(test_Y),len(train_Y)
# Out:
# (8328, 33381)

# %%
len(test_X),len(train_X)
# Out:
# (8328, 33381)

# %%
test_X.shape
# Out:
# (8328, 24)

# %%
print(train_X,test_X)
# Out:
# [[0.12977867 0.14889336 0.15995976 ... 0.16498994 0.15694165 0.12676056]
#  [0.14889336 0.15995976 0.18209256 ... 0.15694165 0.12676056 0.09054326]
#  [0.15995976 0.18209256 0.138833   ... 0.12676056 0.09054326 0.06338028]
#  ...
#  [0.05734406 0.05734406 0.07545272 ... 0.13179074 0.17806841 0.28873239]
#  [0.05734406 0.07545272 0.09657948 ... 0.17806841 0.28873239 0.30080483]
#  [0.07545272 0.09657948 0.11066398 ... 0.28873239 0.30080483 0.25150905]] [[0.12474849 0.12374245 0.04929577 ... 0.12273642 0.12374245 0.12273642]
#  [0.12374245 0.04929577 0.0362173  ... 0.12374245 0.12273642 0.17303823]
#  [0.04929577 0.0362173  0.05935614 ... 0.12273642 0.17303823 0.21428571]
#  ...
#  [0.02012072 0.00804829 0.01609658 ... 0.01006036 0.00804829 0.01006036]
#  [0.00804829 0.01609658 0.01006036 ... 0.00804829 0.01006036 0.01006036]
#  [0.01609658 0.01006036 0.0110664  ... 0.01006036 0.01006036 0.00804829]]

# %%
train_X = np.expand_dims(train_X, axis=2)
test_X = np.expand_dims(test_X, axis=2)

# %%
print(train_X,test_X)
# Out:
# [[[0.12977867]
#   [0.14889336]
#   [0.15995976]
#   ...
#   [0.16498994]
#   [0.15694165]
#   [0.12676056]]
#
#  [[0.14889336]
#   [0.15995976]
#   [0.18209256]
#   ...
#   [0.15694165]
#   [0.12676056]
#   [0.09054326]]
#
#  [[0.15995976]
#   [0.18209256]
#   [0.138833  ]
#   ...
#   [0.12676056]
#   [0.09054326]
#   [0.06338028]]
#
#  ...
#
#  [[0.05734406]
#   [0.05734406]
#   [0.07545272]
#   ...
#   [0.13179074]
#   [0.17806841]
#   [0.28873239]]
#
#  [[0.05734406]
#   [0.07545272]
#   [0.09657948]
#   ...
#   [0.17806841]
#   [0.28873239]
#   [0.30080483]]
#
#  [[0.07545272]
#   [0.09657948]
#   [0.11066398]
#   ...
#   [0.28873239]
#   [0.30080483]
#   [0.25150905]]] [[[0.12474849]
#   [0.12374245]
#   [0.04929577]
#   ...
#   [0.12273642]
#   [0.12374245]
#   [0.12273642]]
#
#  [[0.12374245]
#   [0.04929577]
#   [0.0362173 ]
#   ...
#   [0.12374245]
#   [0.12273642]
#   [0.17303823]]
#
#  [[0.04929577]
#   [0.0362173 ]
#   [0.05935614]
#   ...
#   [0.12273642]
#   [0.17303823]
#   [0.21428571]]
#
#  ...
#
#  [[0.02012072]
#   [0.00804829]
#   [0.01609658]
#   ...
#   [0.01006036]
#   [0.00804829]
#   [0.01006036]]
#
#  [[0.00804829]
#   [0.01609658]
#   [0.01006036]
#   ...
#   [0.00804829]
#   [0.01006036]
#   [0.01006036]]
#
#  [[0.01609658]
#   [0.01006036]
#   [0.0110664 ]
#   ...
#   [0.01006036]
#   [0.01006036]
#   [0.00804829]]]

# %%
input_layer = Input(shape=(look_back, 1))
input_layer
# Out:
# <KerasTensor: shape=(None, 24, 1) dtype=float32 (created by layer 'input_1')>

# %%
gru=GRU (units = 256,  return_sequences = True,kernel_regularizer=l1(0.002), bias_regularizer=l1(0.4))(input_layer)
dro=Dropout(0.2)(gru)
gru1=GRU(units = 128, bias_regularizer=l1(0.5))(dro)
drop=Dropout(0.2)(gru1)
den=Dense(1)(drop)
model=Model(inputs=input_layer,outputs=den)
rms_prop=RMSprop(learning_rate=0.002)
model.compile(optimizer=rms_prop, loss='mse',metrics=["mae", "mape","msle"])
model.summary()
# Out:
# 2023-04-10 03:56:31.453473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:31.455513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:31.456941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 1)]           0
#
#  gru (GRU)                   (None, 24, 256)           198912
#
#  dropout (Dropout)           (None, 24, 256)           0
#
#  gru_1 (GRU)                 (None, 128)               148224
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 347,265
# Trainable params: 347,265
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-10 03:56:31.757064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:31.759236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:31.761158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %%
history = model.fit(train_X,train_Y,validation_data=(test_X, test_Y),epochs=500,batch_size=24, steps_per_epoch=32, shuffle=True, callbacks=[es])
# Out:
# Epoch 1/500
# 2023-04-10 03:56:32.324064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:32.326777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:32.328662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-10 03:56:32.668757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:32.671831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:32.674009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-10 03:56:34.474261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:34.477155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:34.479238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-10 03:56:34.825470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:34.828490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:34.830465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 32/32 [==============================] - ETA: 0s - loss: 1.3391 - mae: 0.0670 - mape: 157.6143 - msle: 0.0057
# 2023-04-10 03:56:39.289573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:39.292453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:39.294721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-10 03:56:39.681381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:56:39.686454: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:56:39.690684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 32/32 [==============================] - 13s 254ms/step - loss: 1.3391 - mae: 0.0670 - mape: 157.6143 - msle: 0.0057 - val_loss: 1.0578 - val_mae: 0.0408 - val_mape: 158.4045 - val_msle: 0.0020
# Epoch 2/500
# 32/32 [==============================] - 6s 192ms/step - loss: 1.0140 - mae: 0.0501 - mape: 120.2305 - msle: 0.0033 - val_loss: 1.0633 - val_mae: 0.0485 - val_mape: 193.3265 - val_msle: 0.0026
# Epoch 3/500
# 32/32 [==============================] - 6s 193ms/step - loss: 1.0060 - mae: 0.0422 - mape: 14864.2959 - msle: 0.0023 - val_loss: 1.0497 - val_mae: 0.0355 - val_mape: 128.0379 - val_msle: 0.0016
# Epoch 4/500
# 32/32 [==============================] - 6s 193ms/step - loss: 1.0046 - mae: 0.0370 - mape: 49175.8242 - msle: 0.0019 - val_loss: 1.0534 - val_mae: 0.0320 - val_mape: 67.1656 - val_msle: 0.0016
# Epoch 5/500
# 32/32 [==============================] - 6s 189ms/step - loss: 1.0038 - mae: 0.0341 - mape: 78.7208 - msle: 0.0017 - val_loss: 1.0587 - val_mae: 0.0310 - val_mape: 61.1523 - val_msle: 0.0015
# Epoch 6/500
# 32/32 [==============================] - 6s 205ms/step - loss: 1.0047 - mae: 0.0337 - mape: 68.8262 - msle: 0.0021 - val_loss: 1.0608 - val_mae: 0.0307 - val_mape: 103.6546 - val_msle: 0.0014
# Epoch 7/500
# 32/32 [==============================] - 7s 213ms/step - loss: 1.0030 - mae: 0.0307 - mape: 74.4884 - msle: 0.0015 - val_loss: 1.0630 - val_mae: 0.0262 - val_mape: 68.5424 - val_msle: 0.0012
# Epoch 8/500
# 32/32 [==============================] - 7s 211ms/step - loss: 1.0032 - mae: 0.0296 - mape: 61.3046 - msle: 0.0015 - val_loss: 1.0658 - val_mae: 0.0329 - val_mape: 117.3907 - val_msle: 0.0015
# Epoch 9/500
# 32/32 [==============================] - 7s 216ms/step - loss: 1.0031 - mae: 0.0304 - mape: 74.9558 - msle: 0.0016 - val_loss: 1.0663 - val_mae: 0.0271 - val_mape: 64.0591 - val_msle: 0.0012
# Epoch 10/500
# 32/32 [==============================] - 7s 208ms/step - loss: 1.0035 - mae: 0.0339 - mape: 85.5741 - msle: 0.0019 - val_loss: 1.0682 - val_mae: 0.0293 - val_mape: 54.5114 - val_msle: 0.0014
# Epoch 11/500
# 32/32 [==============================] - 7s 207ms/step - loss: 1.0027 - mae: 0.0301 - mape: 73.1439 - msle: 0.0014 - val_loss: 1.0712 - val_mae: 0.0258 - val_mape: 76.8472 - val_msle: 0.0011
# Epoch 12/500
# 32/32 [==============================] - 6s 207ms/step - loss: 1.0027 - mae: 0.0298 - mape: 66.5490 - msle: 0.0014 - val_loss: 1.0734 - val_mae: 0.0262 - val_mape: 49.2567 - val_msle: 0.0012
# Epoch 13/500
# 32/32 [==============================] - 7s 209ms/step - loss: 1.0031 - mae: 0.0301 - mape: 65.1953 - msle: 0.0016 - val_loss: 1.0760 - val_mae: 0.0324 - val_mape: 117.4237 - val_msle: 0.0014
# Epoch 13: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(loss, 'g+', label='Training loss')
plt.plot(val_loss, 'r', label='Validation loss')
plt.title('Training  and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
prediction_train=model.predict(train_X)
prediction_train.shape
# Out:
# 2023-04-10 03:58:59.635272: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:58:59.638042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:58:59.639767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-10 03:58:59.967477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-10 03:58:59.970287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-10 03:58:59.971957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1044/1044 [==============================] - 21s 20ms/step
# (33381, 1)

# %%
prediction_test=model.predict(test_X)
prediction_test.shape
# Out:
# 261/261 [==============================] - 5s 20ms/step
# (8328, 1)

# %%
from keras.layers import concatenate
print(test_data.shape)
test1=test_data[24:,:]
print(test1.shape)
print(type(test1),type(prediction_test))
pri1=concatenate((prediction_test,test1),axis=1)
# Out:
# (8352, 1)
# (8328, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
rescaled_prediction = scaler.inverse_transform(pri1)
print('rescaled_prediction shape', rescaled_prediction.shape)
#print(rescaled_prediction[-5:,0])
#print(rescaled_prediction[:,0])
rescaled_prediction_pollution=rescaled_prediction[:len(test_X),0]
print(rescaled_prediction_pollution.shape)
test_data_actual_scale=scaler.inverse_transform(test_data)
print('test_data_actual_scale shape', test_data_actual_scale.shape)
test_data_actual_pollution=test_data_actual_scale[22:len(test_X)+22,0]
#test_data_actual_pollution=test_data_actual_scale[0:30,0]
print(test_data_actual_pollution.shape)
# Out:
# rescaled_prediction shape (8328, 2)
# (8328,)
# test_data_actual_scale shape (8352, 1)
# (8328,)

# %%
rescaled_prediction_pollution.shape
# Out:
# (8328,)

# %%
plt.figure(figsize=(30,6))  
plt.plot(test_data_actual_pollution , color = 'red', label = 'Actual Pollution level')
plt.plot(rescaled_prediction_pollution, color= 'green', label = 'Predicted Pollution level')

plt.title("Air Pollution Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("Pollution level")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(rescaled_prediction_pollution,test_data_actual_pollution))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 30.918

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(test_data_actual_pollution,rescaled_prediction_pollution)
print('Test MAE: %.3f' % mae)
# Out:
# Test MAE: 26.092

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(test_data_actual_pollution,rescaled_prediction_pollution)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAPE: 1.029

# %%
df1=pd.DataFrame()
df1['actual'] = pd.DataFrame(test_data_actual_pollution)
df1['predicted']=pd.DataFrame(rescaled_prediction_pollution)
plt.scatter(df1['actual'],df1['predicted'])
plt.plot([0,df1['actual'].max()],[0,df1['predicted'].max()],color='red')

# %% [markdown]
# # train

# %%
from keras.layers import concatenate
print(train_data.shape)
train1=train_data[24:,:]
print(train1.shape)
print(type(train1),type(prediction_train))
pri1=concatenate((prediction_train,train1),axis=1)
# Out:
# (33405, 1)
# (33381, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
rescaled_prediction = scaler.inverse_transform(pri1)
print('rescaled_prediction shape', rescaled_prediction.shape)
#print(rescaled_prediction[-5:,0])
#print(rescaled_prediction[:,0])
rescaled_prediction_pollution=rescaled_prediction[:len(train_X),0]
print(rescaled_prediction_pollution.shape)
train_data_actual_scale=scaler.inverse_transform(train_data)
print('train_data_actual_scale shape', train_data_actual_scale.shape)
train_data_actual_pollution=train_data_actual_scale[22:len(train_X)+22,0]
#train_data_actual_pollution=train_data_actual_scale[0:30,0]
print(train_data_actual_pollution.shape)
# Out:
# rescaled_prediction shape (33381, 2)
# (33381,)
# train_data_actual_scale shape (33405, 1)
# (33381,)

# %%
plt.figure(figsize=(30,6))  
plt.plot(train_data_actual_pollution , color = 'red', label = 'Actual Pollution level')
plt.plot(rescaled_prediction_pollution, color= 'green', label = 'Predicted Pollution level')

plt.title("Air Pollution Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("Pollution level")
plt.legend()
plt.show()

# %%
rmse = sqrt(mean_squared_error(rescaled_prediction_pollution,train_data_actual_pollution))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 32.072

# %%
mae=mean_absolute_error(train_data_actual_pollution,rescaled_prediction_pollution)
print('Train MAE: %.3f' % mae)
# Out:
# Train MAE: 26.375

# %%
mape=mean_absolute_percentage_error(train_data_actual_pollution,rescaled_prediction_pollution)
print('Train MAPE: %.3f' % mape)
# Out:
# Train MAPE: 10018799360575.236

# %%
df1=pd.DataFrame()
df1['actual'] = pd.DataFrame(test_data_actual_pollution)
df1['predicted']=pd.DataFrame(rescaled_prediction_pollution)
plt.scatter(df1['actual'],df1['predicted'])
plt.plot([0,df1['actual'].max()],[0,df1['predicted'].max()],color='red')
