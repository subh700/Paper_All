# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential,Model
from keras.layers import Input,Conv1D,MaxPooling1D,GRU,LSTM,Bidirectional,Dense,Dropout,Flatten
from sklearn.preprocessing import MinMaxScaler
from keras.regularizers import l1
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
# Out:
# 2023-04-09 18:31:06.502649: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-09 18:31:06.547792: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-09 18:31:06.548823: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-09 18:31:07.522000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df=pd.read_csv('PRSA_data_2010.1.1-2014.12.31.csv')
df=df.iloc[:,1:-7]
df["Date"] = pd.to_datetime(df["year"].apply(str) + "/" + df["month"].apply(str) + "/" + df["day"].apply(str)+ " " + df["hour"].apply(str)+ ":" +"00")
df=df.drop(['year','month','day','hour'],axis=1)
df=df.dropna()
df=df.rename(columns={'Date':'DATE','pm2.5':'PM'})
df=df.set_index('DATE')
df
# Out:
#                         PM
# DATE
# 2010-01-02 00:00:00  129.0
# 2010-01-02 01:00:00  148.0
# 2010-01-02 02:00:00  159.0
# 2010-01-02 03:00:00  181.0
# 2010-01-02 04:00:00  138.0
# ...                    ...
# 2014-12-31 19:00:00    8.0
# 2014-12-31 20:00:00   10.0
# 2014-12-31 21:00:00   10.0
# 2014-12-31 22:00:00    8.0
# 2014-12-31 23:00:00   12.0
#
# [41757 rows x 1 columns]

# %%
df.describe()
# Out:
#                  PM
# count  41757.000000
# mean      98.613215
# std       92.050387
# min        0.000000
# 25%       29.000000
# 50%       72.000000
# 75%      137.000000
# max      994.000000

# %%
data=df

# %%
# Scale data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
data
# Out:
# array([[0.12977867],
#        [0.14889336],
#        [0.15995976],
#        ...,
#        [0.01006036],
#        [0.00804829],
#        [0.01207243]])

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_data, test_data = data[0:train_size,:], data[train_size:len(data),:]

# %%
print(train_size,test_size)
print(train_data,test_data)
print(len(train_data),len(test_data))
# Out:
# 33405 8352
# [[0.12977867]
#  [0.14889336]
#  [0.15995976]
#  ...
#  [0.30080483]
#  [0.25150905]
#  [0.15995976]] [[0.12474849]
#  [0.12374245]
#  [0.04929577]
#  ...
#  [0.01006036]
#  [0.00804829]
#  [0.01207243]]
# 33405 8352

# %%
# Convert data into time series dataset
def create_dataset(dataset, look_back=24):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i+look_back), 0])
        Y.append(dataset[i+look_back, 0])
    return np.array(X), np.array(Y)

# %%
look_back = 24
train_X, train_Y = create_dataset(train_data, look_back)
test_X, test_Y = create_dataset(test_data, look_back)

# %%
#print(train_X,train_Y)
#print(test_X,test_Y)
print(train_Y,test_Y)
# Out:
# [0.09054326 0.06338028 0.06539235 ... 0.30080483 0.25150905 0.15995976] [0.17303823 0.21428571 0.1971831  ... 0.01006036 0.00804829 0.01207243]

# %%
len(test_Y),len(train_Y)
# Out:
# (8328, 33381)

# %%
len(test_X),len(train_X)
# Out:
# (8328, 33381)

# %%
test_X.shape
# Out:
# (8328, 24)

# %%
print(train_X,test_X)
# Out:
# [[0.12977867 0.14889336 0.15995976 ... 0.16498994 0.15694165 0.12676056]
#  [0.14889336 0.15995976 0.18209256 ... 0.15694165 0.12676056 0.09054326]
#  [0.15995976 0.18209256 0.138833   ... 0.12676056 0.09054326 0.06338028]
#  ...
#  [0.05734406 0.05734406 0.07545272 ... 0.13179074 0.17806841 0.28873239]
#  [0.05734406 0.07545272 0.09657948 ... 0.17806841 0.28873239 0.30080483]
#  [0.07545272 0.09657948 0.11066398 ... 0.28873239 0.30080483 0.25150905]] [[0.12474849 0.12374245 0.04929577 ... 0.12273642 0.12374245 0.12273642]
#  [0.12374245 0.04929577 0.0362173  ... 0.12374245 0.12273642 0.17303823]
#  [0.04929577 0.0362173  0.05935614 ... 0.12273642 0.17303823 0.21428571]
#  ...
#  [0.02012072 0.00804829 0.01609658 ... 0.01006036 0.00804829 0.01006036]
#  [0.00804829 0.01609658 0.01006036 ... 0.00804829 0.01006036 0.01006036]
#  [0.01609658 0.01006036 0.0110664  ... 0.01006036 0.01006036 0.00804829]]

# %%
train_X = np.expand_dims(train_X, axis=2)
test_X = np.expand_dims(test_X, axis=2)

# %%
print(train_X,test_X)
# Out:
# [[[0.12977867]
#   [0.14889336]
#   [0.15995976]
#   ...
#   [0.16498994]
#   [0.15694165]
#   [0.12676056]]
#
#  [[0.14889336]
#   [0.15995976]
#   [0.18209256]
#   ...
#   [0.15694165]
#   [0.12676056]
#   [0.09054326]]
#
#  [[0.15995976]
#   [0.18209256]
#   [0.138833  ]
#   ...
#   [0.12676056]
#   [0.09054326]
#   [0.06338028]]
#
#  ...
#
#  [[0.05734406]
#   [0.05734406]
#   [0.07545272]
#   ...
#   [0.13179074]
#   [0.17806841]
#   [0.28873239]]
#
#  [[0.05734406]
#   [0.07545272]
#   [0.09657948]
#   ...
#   [0.17806841]
#   [0.28873239]
#   [0.30080483]]
#
#  [[0.07545272]
#   [0.09657948]
#   [0.11066398]
#   ...
#   [0.28873239]
#   [0.30080483]
#   [0.25150905]]] [[[0.12474849]
#   [0.12374245]
#   [0.04929577]
#   ...
#   [0.12273642]
#   [0.12374245]
#   [0.12273642]]
#
#  [[0.12374245]
#   [0.04929577]
#   [0.0362173 ]
#   ...
#   [0.12374245]
#   [0.12273642]
#   [0.17303823]]
#
#  [[0.04929577]
#   [0.0362173 ]
#   [0.05935614]
#   ...
#   [0.12273642]
#   [0.17303823]
#   [0.21428571]]
#
#  ...
#
#  [[0.02012072]
#   [0.00804829]
#   [0.01609658]
#   ...
#   [0.01006036]
#   [0.00804829]
#   [0.01006036]]
#
#  [[0.00804829]
#   [0.01609658]
#   [0.01006036]
#   ...
#   [0.00804829]
#   [0.01006036]
#   [0.01006036]]
#
#  [[0.01609658]
#   [0.01006036]
#   [0.0110664 ]
#   ...
#   [0.01006036]
#   [0.01006036]
#   [0.00804829]]]

# %%
input_layer = Input(shape=(look_back, 1))
input_layer
# Out:
# <KerasTensor: shape=(None, 24, 1) dtype=float32 (created by layer 'input_1')>

# %%
cnn=Conv1D(filters=256,kernel_size=2,activation='relu',kernel_regularizer=l1(0.002),bias_regularizer=l1(0.4))(input_layer)
cnn1=Conv1D(filters=128,kernel_size=2,activation='relu',bias_regularizer=l1(0.4))(cnn)
poll=MaxPooling1D(pool_size=1)(cnn1)
BiLSTM=Bidirectional(LSTM(units=64,activation='relu',return_sequences=False,bias_regularizer=l1(0.2)))(poll)
drop=Dropout(0.3)(BiLSTM)
den=Dense(1)(drop)
model=Model(inputs=input_layer,outputs=den)
rms_prop=RMSprop(learning_rate=0.002)
model.compile(optimizer=rms_prop, loss='mse',metrics=["mae", "mape","msle"])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 1)]           0
#
#  conv1d (Conv1D)             (None, 23, 256)           768
#
#  conv1d_1 (Conv1D)           (None, 22, 128)           65664
#
#  max_pooling1d (MaxPooling1D  (None, 22, 128)          0
#  )
#
#  bidirectional (Bidirectiona  (None, 128)              98816
#  l)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 165,377
# Trainable params: 165,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %%
history = model.fit(train_X,train_Y,validation_data=(test_X, test_Y),epochs=500,batch_size=24, steps_per_epoch=32, shuffle=True, callbacks=[es])
# Out:
# Epoch 1/500
# 32/32 [==============================] - 7s 125ms/step - loss: 24.7383 - mae: 0.0510 - mape: 100.0851 - msle: 0.0041 - val_loss: 23.7269 - val_mae: 0.0434 - val_mape: 159.0495 - val_msle: 0.0025
# Epoch 2/500
# 32/32 [==============================] - 3s 82ms/step - loss: 22.9432 - mae: 0.0446 - mape: 128.6351 - msle: 0.0027 - val_loss: 22.0748 - val_mae: 0.0415 - val_mape: 125.4953 - val_msle: 0.0024
# Epoch 3/500
# 32/32 [==============================] - 3s 85ms/step - loss: 21.2977 - mae: 0.0404 - mape: 123.7921 - msle: 0.0023 - val_loss: 20.4374 - val_mae: 0.0419 - val_mape: 78.7325 - val_msle: 0.0027
# Epoch 4/500
# 32/32 [==============================] - 3s 82ms/step - loss: 19.6599 - mae: 0.0421 - mape: 111.8454 - msle: 0.0028 - val_loss: 18.8026 - val_mae: 0.0323 - val_mape: 84.7072 - val_msle: 0.0016
# Epoch 5/500
# 32/32 [==============================] - 3s 83ms/step - loss: 18.0198 - mae: 0.0360 - mape: 87.6439 - msle: 0.0019 - val_loss: 17.1704 - val_mae: 0.0311 - val_mape: 77.6288 - val_msle: 0.0015
# Epoch 6/500
# 32/32 [==============================] - 3s 96ms/step - loss: 16.3811 - mae: 0.0336 - mape: 82.1817 - msle: 0.0017 - val_loss: 15.5351 - val_mae: 0.0309 - val_mape: 70.2932 - val_msle: 0.0015
# Epoch 7/500
# 32/32 [==============================] - 3s 94ms/step - loss: 14.7428 - mae: 0.0336 - mape: 71.1627 - msle: 0.0017 - val_loss: 13.9007 - val_mae: 0.0314 - val_mape: 65.3336 - val_msle: 0.0015
# Epoch 8/500
# 32/32 [==============================] - 3s 89ms/step - loss: 13.1041 - mae: 0.0330 - mape: 81.4151 - msle: 0.0017 - val_loss: 12.2610 - val_mae: 0.0262 - val_mape: 74.1020 - val_msle: 0.0011
# Epoch 9/500
# 32/32 [==============================] - 3s 88ms/step - loss: 11.4659 - mae: 0.0315 - mape: 74.2377 - msle: 0.0017 - val_loss: 10.6231 - val_mae: 0.0273 - val_mape: 77.3632 - val_msle: 0.0011
# Epoch 10/500
# 32/32 [==============================] - 3s 88ms/step - loss: 9.8272 - mae: 0.0300 - mape: 68.4700 - msle: 0.0015 - val_loss: 8.9839 - val_mae: 0.0266 - val_mape: 91.2285 - val_msle: 0.0011
# Epoch 11/500
# 32/32 [==============================] - 3s 92ms/step - loss: 8.1883 - mae: 0.0273 - mape: 69.6793 - msle: 0.0012 - val_loss: 7.3453 - val_mae: 0.0272 - val_mape: 61.3137 - val_msle: 0.0011
# Epoch 12/500
# 32/32 [==============================] - 3s 91ms/step - loss: 6.5504 - mae: 0.0315 - mape: 67.0950 - msle: 0.0016 - val_loss: 5.7069 - val_mae: 0.0237 - val_mape: 75.7073 - val_msle: 9.0865e-04
# Epoch 13/500
# 32/32 [==============================] - 3s 94ms/step - loss: 4.9129 - mae: 0.0316 - mape: 59.4864 - msle: 0.0019 - val_loss: 4.0683 - val_mae: 0.0216 - val_mape: 64.9376 - val_msle: 8.2169e-04
# Epoch 14/500
# 32/32 [==============================] - 3s 90ms/step - loss: 3.2741 - mae: 0.0316 - mape: 64.5091 - msle: 0.0017 - val_loss: 2.4301 - val_mae: 0.0226 - val_mape: 72.7718 - val_msle: 8.1929e-04
# Epoch 15/500
# 32/32 [==============================] - 3s 89ms/step - loss: 1.6348 - mae: 0.0290 - mape: 56.7580 - msle: 0.0013 - val_loss: 0.7911 - val_mae: 0.0224 - val_mape: 71.5118 - val_msle: 8.0779e-04
# Epoch 16/500
# 32/32 [==============================] - 3s 101ms/step - loss: 0.3532 - mae: 0.0272 - mape: 67.6759 - msle: 0.0013 - val_loss: 0.2785 - val_mae: 0.0206 - val_mape: 62.8092 - val_msle: 7.3672e-04
# Epoch 17/500
# 32/32 [==============================] - 3s 89ms/step - loss: 0.2594 - mae: 0.0254 - mape: 56.5336 - msle: 0.0012 - val_loss: 0.2784 - val_mae: 0.0205 - val_mape: 58.5524 - val_msle: 7.1239e-04
# Epoch 18/500
# 32/32 [==============================] - 3s 88ms/step - loss: 0.2592 - mae: 0.0252 - mape: 55.8594 - msle: 0.0011 - val_loss: 0.2779 - val_mae: 0.0204 - val_mape: 57.3151 - val_msle: 7.0429e-04
# Epoch 19/500
# 32/32 [==============================] - 4s 115ms/step - loss: 0.2590 - mae: 0.0245 - mape: 48.9255 - msle: 9.5530e-04 - val_loss: 0.2785 - val_mae: 0.0279 - val_mape: 44.9589 - val_msle: 0.0011
# Epoch 20/500
# 32/32 [==============================] - 3s 92ms/step - loss: 0.2592 - mae: 0.0266 - mape: 54.9608 - msle: 0.0011 - val_loss: 0.2778 - val_mae: 0.0204 - val_mape: 55.0917 - val_msle: 6.9279e-04
# Epoch 21/500
# 32/32 [==============================] - 3s 91ms/step - loss: 0.2593 - mae: 0.0252 - mape: 60.0762 - msle: 0.0012 - val_loss: 0.2773 - val_mae: 0.0194 - val_mape: 60.1293 - val_msle: 6.5517e-04
# Epoch 22/500
# 32/32 [==============================] - 3s 99ms/step - loss: 0.2590 - mae: 0.0242 - mape: 54.7123 - msle: 9.7457e-04 - val_loss: 0.2769 - val_mae: 0.0212 - val_mape: 71.0856 - val_msle: 7.0453e-04
# Epoch 23/500
# 32/32 [==============================] - 3s 88ms/step - loss: 0.2592 - mae: 0.0241 - mape: 47.0359 - msle: 0.0010 - val_loss: 0.2784 - val_mae: 0.0286 - val_mape: 84.6907 - val_msle: 0.0012
# Epoch 24/500
# 32/32 [==============================] - 3s 93ms/step - loss: 0.2592 - mae: 0.0246 - mape: 45.4050 - msle: 0.0010 - val_loss: 0.2777 - val_mae: 0.0245 - val_mape: 46.9150 - val_msle: 9.0807e-04
# Epoch 25/500
# 32/32 [==============================] - 3s 93ms/step - loss: 0.2589 - mae: 0.0241 - mape: 55.3973 - msle: 9.8726e-04 - val_loss: 0.2772 - val_mae: 0.0196 - val_mape: 50.2262 - val_msle: 6.5335e-04
# Epoch 26/500
# 32/32 [==============================] - 3s 107ms/step - loss: 0.2588 - mae: 0.0235 - mape: 54.1525 - msle: 8.9272e-04 - val_loss: 0.2774 - val_mae: 0.0191 - val_mape: 56.2251 - val_msle: 6.2021e-04
# Epoch 27/500
# 32/32 [==============================] - 3s 96ms/step - loss: 0.2587 - mae: 0.0219 - mape: 47.7514 - msle: 7.8391e-04 - val_loss: 0.2781 - val_mae: 0.0196 - val_mape: 48.8538 - val_msle: 6.4404e-04
# Epoch 28/500
# 32/32 [==============================] - 3s 96ms/step - loss: 0.2588 - mae: 0.0231 - mape: 51.2259 - msle: 8.7458e-04 - val_loss: 0.2788 - val_mae: 0.0250 - val_mape: 39.8463 - val_msle: 9.3846e-04
# Epoch 29/500
# 32/32 [==============================] - 3s 92ms/step - loss: 0.2586 - mae: 0.0220 - mape: 49.5127 - msle: 7.9287e-04 - val_loss: 0.2780 - val_mae: 0.0214 - val_mape: 71.1915 - val_msle: 7.1933e-04
# Epoch 30/500
# 32/32 [==============================] - 3s 92ms/step - loss: 0.2596 - mae: 0.0247 - mape: 25011.4844 - msle: 0.0013 - val_loss: 0.2775 - val_mae: 0.0176 - val_mape: 49.3760 - val_msle: 5.7187e-04
# Epoch 31/500
# 32/32 [==============================] - 3s 90ms/step - loss: 0.2586 - mae: 0.0223 - mape: 45.0268 - msle: 8.0079e-04 - val_loss: 0.2780 - val_mae: 0.0185 - val_mape: 44.3487 - val_msle: 6.0056e-04
# Epoch 32/500
# 32/32 [==============================] - 3s 94ms/step - loss: 0.2585 - mae: 0.0216 - mape: 47.6296 - msle: 7.5597e-04 - val_loss: 0.2792 - val_mae: 0.0182 - val_mape: 50.2377 - val_msle: 5.8081e-04
# Epoch 32: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(loss, 'g+', label='Training loss')
plt.plot(val_loss, 'r', label='Validation loss')
plt.title('Training  and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
prediction_train=model.predict(train_X)
prediction_train.shape
# Out:
# 1044/1044 [==============================] - 8s 8ms/step
# (33381, 1)

# %%
prediction_test=model.predict(test_X)
prediction_test.shape
# Out:
# 261/261 [==============================] - 2s 8ms/step
# (8328, 1)

# %%
from keras.layers import concatenate
print(test_data.shape)
test1=test_data[24:,:]
print(test1.shape)
print(type(test1),type(prediction_test))
pri1=concatenate((prediction_test,test1),axis=1)
# Out:
# (8352, 1)
# (8328, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
rescaled_prediction = scaler.inverse_transform(pri1)
print('rescaled_prediction shape', rescaled_prediction.shape)
#print(rescaled_prediction[-5:,0])
#print(rescaled_prediction[:,0])
rescaled_prediction_pollution=rescaled_prediction[:len(test_X),0]
print(rescaled_prediction_pollution.shape)
test_data_actual_scale=scaler.inverse_transform(test_data)
print('test_data_actual_scale shape', test_data_actual_scale.shape)
test_data_actual_pollution=test_data_actual_scale[22:len(test_X)+22,0]
#test_data_actual_pollution=test_data_actual_scale[0:30,0]
print(test_data_actual_pollution.shape)
# Out:
# rescaled_prediction shape (8328, 2)
# (8328,)
# test_data_actual_scale shape (8352, 1)
# (8328,)

# %%
plt.figure(figsize=(30,6))  
plt.plot(rescaled_prediction_pollution, color= 'green', label = 'Predicted Pollution level')
plt.plot(test_data_actual_pollution , color = 'red', label = 'Actual Pollution level')
plt.title("Air Pollution Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("Pollution level")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(rescaled_prediction_pollution,test_data_actual_pollution))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 15.373

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(test_data_actual_pollution,rescaled_prediction_pollution)
print('Test MAE: %.3f' % mae)
# Out:
# Test MAE: 10.310

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(test_data_actual_pollution,rescaled_prediction_pollution)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAPE: 0.364

# %% [markdown]
# # train

# %%
from keras.layers import concatenate
print(train_data.shape)
train1=train_data[24:,:]
print(train1.shape)
print(type(train1),type(prediction_train))
pri1=concatenate((prediction_train,train1),axis=1)
# Out:
# (33405, 1)
# (33381, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
rescaled_prediction = scaler.inverse_transform(pri1)
print('rescaled_prediction shape', rescaled_prediction.shape)
#print(rescaled_prediction[-5:,0])
#print(rescaled_prediction[:,0])
rescaled_prediction_pollution=rescaled_prediction[:len(train_X),0]
print(rescaled_prediction_pollution.shape)
train_data_actual_scale=scaler.inverse_transform(train_data)
print('train_data_actual_scale shape', train_data_actual_scale.shape)
train_data_actual_pollution=train_data_actual_scale[22:len(train_X)+22,0]
#train_data_actual_pollution=train_data_actual_scale[0:30,0]
print(train_data_actual_pollution.shape)
# Out:
# rescaled_prediction shape (33381, 2)
# (33381,)
# train_data_actual_scale shape (33405, 1)
# (33381,)

# %%
plt.figure(figsize=(30,6))  
plt.plot(rescaled_prediction_pollution, color= 'green', label = 'Predicted Pollution level')
plt.plot(train_data_actual_pollution , color = 'red', label = 'Actual Pollution level')
plt.title("Air Pollution Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("Pollution level")
plt.legend()
plt.show()

# %%
rmse = sqrt(mean_squared_error(rescaled_prediction_pollution,train_data_actual_pollution))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 16.227

# %%
mae=mean_absolute_error(train_data_actual_pollution,rescaled_prediction_pollution)
print('Train MAE: %.3f' % mae)
# Out:
# Train MAE: 10.643

# %%
mape=mean_absolute_percentage_error(train_data_actual_pollution,rescaled_prediction_pollution)
print('Train MAPE: %.3f' % mape)
# Out:
# Train MAPE: 5671211429541.422
