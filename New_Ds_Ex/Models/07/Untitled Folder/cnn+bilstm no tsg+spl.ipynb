# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential,Model
from keras.layers import Input,Conv1D,MaxPooling1D,GRU,LSTM,Bidirectional,Dense,Dropout,Flatten
from sklearn.preprocessing import MinMaxScaler
from keras.regularizers import l1
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop

# %%
df=pd.read_csv('../PRSA_data_2010.1.1-2014.12.31.csv')
df=df.iloc[:,1:-7]
df["Date"] = pd.to_datetime(df["year"].apply(str) + "/" + df["month"].apply(str) + "/" + df["day"].apply(str)+ " " + df["hour"].apply(str)+ ":" +"00")
df=df.drop(['year','month','day','hour'],axis=1)
df=df.dropna()
df=df.rename(columns={'Date':'DATE','pm2.5':'PM'})
df=df.set_index('DATE')
df.to_csv("PRSA_data_2010_12_data.csv")
df
# Out:
#                         PM
# DATE
# 2010-01-02 00:00:00  129.0
# 2010-01-02 01:00:00  148.0
# 2010-01-02 02:00:00  159.0
# 2010-01-02 03:00:00  181.0
# 2010-01-02 04:00:00  138.0
# ...                    ...
# 2014-12-31 19:00:00    8.0
# 2014-12-31 20:00:00   10.0
# 2014-12-31 21:00:00   10.0
# 2014-12-31 22:00:00    8.0
# 2014-12-31 23:00:00   12.0
#
# [41757 rows x 1 columns]

# %%
df.describe()
# Out:
#                  PM
# count  41757.000000
# mean      98.613215
# std       92.050387
# min        0.000000
# 25%       29.000000
# 50%       72.000000
# 75%      137.000000
# max      994.000000

# %%
data=df

# %%
# Scale data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
data
# Out:
# array([[0.12977867],
#        [0.14889336],
#        [0.15995976],
#        ...,
#        [0.01006036],
#        [0.00804829],
#        [0.01207243]])

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train_data, test_data = data[0:train_size,:], data[train_size:len(data),:]

# %%
print(train_size,test_size)
print(train_data,test_data)
print(len(train_data),len(test_data))
# Out:
# 33405 8352
# [[0.12977867]
#  [0.14889336]
#  [0.15995976]
#  ...
#  [0.30080483]
#  [0.25150905]
#  [0.15995976]] [[0.12474849]
#  [0.12374245]
#  [0.04929577]
#  ...
#  [0.01006036]
#  [0.00804829]
#  [0.01207243]]
# 33405 8352

# %%
# Convert data into time series dataset
def create_dataset(dataset, look_back=24):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i+look_back), 0])
        Y.append(dataset[i+look_back, 0])
    return np.array(X), np.array(Y)

# %%
look_back = 24
train_X, train_Y = create_dataset(train_data, look_back)
test_X, test_Y = create_dataset(test_data, look_back)

# %%
#print(train_X,train_Y)
#print(test_X,test_Y)
print(train_Y,test_Y)
# Out:
# [0.09054326 0.06338028 0.06539235 ... 0.30080483 0.25150905 0.15995976] [0.17303823 0.21428571 0.1971831  ... 0.01006036 0.00804829 0.01207243]

# %%
len(test_Y),len(train_Y)
# Out:
# (8328, 33381)

# %%
len(test_X),len(train_X)
# Out:
# (8328, 33381)

# %%
test_X.shape
# Out:
# (8328, 24)

# %%
print(train_X,test_X)
# Out:
# [[0.12977867 0.14889336 0.15995976 ... 0.16498994 0.15694165 0.12676056]
#  [0.14889336 0.15995976 0.18209256 ... 0.15694165 0.12676056 0.09054326]
#  [0.15995976 0.18209256 0.138833   ... 0.12676056 0.09054326 0.06338028]
#  ...
#  [0.05734406 0.05734406 0.07545272 ... 0.13179074 0.17806841 0.28873239]
#  [0.05734406 0.07545272 0.09657948 ... 0.17806841 0.28873239 0.30080483]
#  [0.07545272 0.09657948 0.11066398 ... 0.28873239 0.30080483 0.25150905]] [[0.12474849 0.12374245 0.04929577 ... 0.12273642 0.12374245 0.12273642]
#  [0.12374245 0.04929577 0.0362173  ... 0.12374245 0.12273642 0.17303823]
#  [0.04929577 0.0362173  0.05935614 ... 0.12273642 0.17303823 0.21428571]
#  ...
#  [0.02012072 0.00804829 0.01609658 ... 0.01006036 0.00804829 0.01006036]
#  [0.00804829 0.01609658 0.01006036 ... 0.00804829 0.01006036 0.01006036]
#  [0.01609658 0.01006036 0.0110664  ... 0.01006036 0.01006036 0.00804829]]

# %%
train_X = np.expand_dims(train_X, axis=2)
test_X = np.expand_dims(test_X, axis=2)

# %%
print(train_X,test_X)
# Out:
# [[[0.12977867]
#   [0.14889336]
#   [0.15995976]
#   ...
#   [0.16498994]
#   [0.15694165]
#   [0.12676056]]
#
#  [[0.14889336]
#   [0.15995976]
#   [0.18209256]
#   ...
#   [0.15694165]
#   [0.12676056]
#   [0.09054326]]
#
#  [[0.15995976]
#   [0.18209256]
#   [0.138833  ]
#   ...
#   [0.12676056]
#   [0.09054326]
#   [0.06338028]]
#
#  ...
#
#  [[0.05734406]
#   [0.05734406]
#   [0.07545272]
#   ...
#   [0.13179074]
#   [0.17806841]
#   [0.28873239]]
#
#  [[0.05734406]
#   [0.07545272]
#   [0.09657948]
#   ...
#   [0.17806841]
#   [0.28873239]
#   [0.30080483]]
#
#  [[0.07545272]
#   [0.09657948]
#   [0.11066398]
#   ...
#   [0.28873239]
#   [0.30080483]
#   [0.25150905]]] [[[0.12474849]
#   [0.12374245]
#   [0.04929577]
#   ...
#   [0.12273642]
#   [0.12374245]
#   [0.12273642]]
#
#  [[0.12374245]
#   [0.04929577]
#   [0.0362173 ]
#   ...
#   [0.12374245]
#   [0.12273642]
#   [0.17303823]]
#
#  [[0.04929577]
#   [0.0362173 ]
#   [0.05935614]
#   ...
#   [0.12273642]
#   [0.17303823]
#   [0.21428571]]
#
#  ...
#
#  [[0.02012072]
#   [0.00804829]
#   [0.01609658]
#   ...
#   [0.01006036]
#   [0.00804829]
#   [0.01006036]]
#
#  [[0.00804829]
#   [0.01609658]
#   [0.01006036]
#   ...
#   [0.00804829]
#   [0.01006036]
#   [0.01006036]]
#
#  [[0.01609658]
#   [0.01006036]
#   [0.0110664 ]
#   ...
#   [0.01006036]
#   [0.01006036]
#   [0.00804829]]]

# %%
input_layer = Input(shape=(look_back, 1))
input_layer
# Out:
# <KerasTensor: shape=(None, 24, 1) dtype=float32 (created by layer 'input_1')>

# %%
cnn=Conv1D(filters=256,kernel_size=2,activation='relu',kernel_regularizer=l1(0.002),bias_regularizer=l1(0.4))(input_layer)
cnn1=Conv1D(filters=128,kernel_size=2,activation='relu',bias_regularizer=l1(0.4))(cnn)
poll=MaxPooling1D(pool_size=1)(cnn1)
BiLSTM=Bidirectional(LSTM(units=64,activation='relu',return_sequences=False,bias_regularizer=l1(0.2)))(poll)
drop=Dropout(0.3)(BiLSTM)
den=Dense(1)(drop)
model=Model(inputs=input_layer,outputs=den)
rms_prop=RMSprop(learning_rate=0.002)
model.compile(optimizer=rms_prop, loss='mse',metrics=["mae", "mape","msle"])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 1)]           0
#
#  conv1d (Conv1D)             (None, 23, 256)           768
#
#  conv1d_1 (Conv1D)           (None, 22, 128)           65664
#
#  max_pooling1d (MaxPooling1D  (None, 22, 128)          0
#  )
#
#  bidirectional (Bidirectiona  (None, 128)              98816
#  l)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 165,377
# Trainable params: 165,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %%
history = model.fit(train_X,train_Y,validation_data=(test_X, test_Y),epochs=500,batch_size=24, steps_per_epoch=32, shuffle=True, callbacks=[es])
# Out:
# Epoch 1/500
# 32/32 [==============================] - 13s 216ms/step - loss: 24.7311 - mae: 0.0537 - mape: 110.5377 - msle: 0.0043 - val_loss: 23.7260 - val_mae: 0.0451 - val_mape: 164.3554 - val_msle: 0.0028
# Epoch 2/500
# 32/32 [==============================] - 7s 215ms/step - loss: 22.9453 - mae: 0.0502 - mape: 137.7048 - msle: 0.0035 - val_loss: 22.0770 - val_mae: 0.0465 - val_mape: 177.0940 - val_msle: 0.0027
# Epoch 3/500
# 32/32 [==============================] - 7s 233ms/step - loss: 21.2985 - mae: 0.0474 - mape: 135.7905 - msle: 0.0030 - val_loss: 20.4293 - val_mae: 0.0388 - val_mape: 123.4221 - val_msle: 0.0021
# Epoch 4/500
# 32/32 [==============================] - 7s 211ms/step - loss: 19.6597 - mae: 0.0420 - mape: 113.0715 - msle: 0.0029 - val_loss: 18.8023 - val_mae: 0.0396 - val_mape: 74.1112 - val_msle: 0.0024
# Epoch 5/500
# 32/32 [==============================] - 8s 239ms/step - loss: 18.0201 - mae: 0.0411 - mape: 101.1664 - msle: 0.0025 - val_loss: 17.1709 - val_mae: 0.0352 - val_mape: 67.2417 - val_msle: 0.0019
# Epoch 6/500
# 32/32 [==============================] - 7s 227ms/step - loss: 16.3806 - mae: 0.0347 - mape: 87.0026 - msle: 0.0018 - val_loss: 15.5340 - val_mae: 0.0286 - val_mape: 81.0820 - val_msle: 0.0013
# Epoch 7/500
# 32/32 [==============================] - 7s 230ms/step - loss: 14.7422 - mae: 0.0332 - mape: 85.8768 - msle: 0.0017 - val_loss: 13.8969 - val_mae: 0.0259 - val_mape: 63.1172 - val_msle: 0.0011
# Epoch 8/500
# 32/32 [==============================] - 6s 202ms/step - loss: 13.1035 - mae: 0.0317 - mape: 46233.5430 - msle: 0.0016 - val_loss: 12.2622 - val_mae: 0.0278 - val_mape: 68.5017 - val_msle: 0.0012
# Epoch 9/500
# 32/32 [==============================] - 6s 193ms/step - loss: 11.4653 - mae: 0.0306 - mape: 67.3710 - msle: 0.0017 - val_loss: 10.6266 - val_mae: 0.0271 - val_mape: 73.4524 - val_msle: 0.0011
# Epoch 10/500
# 32/32 [==============================] - 6s 205ms/step - loss: 9.8264 - mae: 0.0298 - mape: 66.3188 - msle: 0.0014 - val_loss: 8.9893 - val_mae: 0.0280 - val_mape: 95.4350 - val_msle: 0.0012
# Epoch 11/500
# 32/32 [==============================] - 3s 96ms/step - loss: 8.1880 - mae: 0.0300 - mape: 61.5911 - msle: 0.0014 - val_loss: 7.3493 - val_mae: 0.0246 - val_mape: 80.6051 - val_msle: 9.4745e-04
# Epoch 12/500
# 32/32 [==============================] - 3s 94ms/step - loss: 6.5492 - mae: 0.0272 - mape: 65.2982 - msle: 0.0011 - val_loss: 5.7098 - val_mae: 0.0264 - val_mape: 91.3669 - val_msle: 0.0010
# Epoch 13/500
# 32/32 [==============================] - 3s 105ms/step - loss: 4.9110 - mae: 0.0296 - mape: 61.8585 - msle: 0.0013 - val_loss: 4.0704 - val_mae: 0.0227 - val_mape: 57.7259 - val_msle: 8.5442e-04
# Epoch 14/500
# 32/32 [==============================] - 7s 210ms/step - loss: 3.2724 - mae: 0.0266 - mape: 63.5766 - msle: 0.0012 - val_loss: 2.4323 - val_mae: 0.0228 - val_mape: 56.3320 - val_msle: 8.5174e-04
# Epoch 15/500
# 32/32 [==============================] - 6s 185ms/step - loss: 1.6338 - mae: 0.0247 - mape: 51.7538 - msle: 0.0010 - val_loss: 0.7940 - val_mae: 0.0235 - val_mape: 54.3608 - val_msle: 8.8033e-04
# Epoch 16/500
# 32/32 [==============================] - 7s 220ms/step - loss: 0.3525 - mae: 0.0274 - mape: 60.1686 - msle: 0.0011 - val_loss: 0.2814 - val_mae: 0.0229 - val_mape: 71.8254 - val_msle: 8.7759e-04
# Epoch 17/500
# 32/32 [==============================] - 6s 185ms/step - loss: 0.2589 - mae: 0.0275 - mape: 64.7879 - msle: 0.0013 - val_loss: 0.2820 - val_mae: 0.0212 - val_mape: 67.2230 - val_msle: 7.4740e-04
# Epoch 18/500
# 32/32 [==============================] - 4s 136ms/step - loss: 0.2586 - mae: 0.0266 - mape: 56.5350 - msle: 0.0011 - val_loss: 0.2832 - val_mae: 0.0210 - val_mape: 52.8656 - val_msle: 7.4681e-04
# Epoch 19/500
# 32/32 [==============================] - 3s 94ms/step - loss: 0.2590 - mae: 0.0251 - mape: 49.7245 - msle: 0.0012 - val_loss: 0.2839 - val_mae: 0.0220 - val_mape: 71.1941 - val_msle: 8.1179e-04
# Epoch 20/500
# 32/32 [==============================] - 3s 97ms/step - loss: 0.2588 - mae: 0.0272 - mape: 57.0116 - msle: 0.0012 - val_loss: 0.2844 - val_mae: 0.0219 - val_mape: 70.4660 - val_msle: 7.8385e-04
# Epoch 21/500
# 32/32 [==============================] - 3s 112ms/step - loss: 0.2584 - mae: 0.0243 - mape: 52.0419 - msle: 9.8511e-04 - val_loss: 0.2848 - val_mae: 0.0210 - val_mape: 45.1204 - val_msle: 7.4107e-04
# Epoch 22/500
# 32/32 [==============================] - 6s 196ms/step - loss: 0.2583 - mae: 0.0241 - mape: 52.1279 - msle: 9.9769e-04 - val_loss: 0.2860 - val_mae: 0.0223 - val_mape: 44.3373 - val_msle: 8.0517e-04
# Epoch 23/500
# 32/32 [==============================] - 6s 185ms/step - loss: 0.2585 - mae: 0.0255 - mape: 56.6708 - msle: 0.0011 - val_loss: 0.2870 - val_mae: 0.0197 - val_mape: 57.7507 - val_msle: 6.5652e-04
# Epoch 24/500
# 32/32 [==============================] - 6s 203ms/step - loss: 0.2590 - mae: 0.0255 - mape: 50.5702 - msle: 0.0010 - val_loss: 0.2879 - val_mae: 0.0188 - val_mape: 55.4952 - val_msle: 6.4176e-04
# Epoch 25/500
# 32/32 [==============================] - 7s 238ms/step - loss: 0.2592 - mae: 0.0253 - mape: 55.1989 - msle: 0.0011 - val_loss: 0.2870 - val_mae: 0.0195 - val_mape: 46.8423 - val_msle: 6.5103e-04
# Epoch 26/500
# 32/32 [==============================] - 4s 134ms/step - loss: 0.2593 - mae: 0.0259 - mape: 55.5494 - msle: 0.0012 - val_loss: 0.2866 - val_mae: 0.0196 - val_mape: 61.4978 - val_msle: 6.7129e-04
# Epoch 26: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(loss, 'g+', label='Training loss')
plt.plot(val_loss, 'r', label='Validation loss')
plt.title('Training  and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
prediction_train=model.predict(train_X)
prediction_train.shape
# Out:
# 1044/1044 [==============================] - 10s 10ms/step
# (33381, 1)

# %%
prediction_test=model.predict(test_X)
prediction_test.shape
# Out:
# 261/261 [==============================] - 2s 9ms/step
# (8328, 1)

# %%
from keras.layers import concatenate
print(test_data.shape)
test1=test_data[24:,:]
print(test1.shape)
print(type(test1),type(prediction_test))
pri1=concatenate((prediction_test,test1),axis=1)
# Out:
# (8352, 1)
# (8328, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
rescaled_prediction = scaler.inverse_transform(pri1)
print('rescaled_prediction shape', rescaled_prediction.shape)
#print(rescaled_prediction[-5:,0])
#print(rescaled_prediction[:,0])
rescaled_prediction_pollution=rescaled_prediction[:len(test_X),0]
print(rescaled_prediction_pollution.shape)
test_data_actual_scale=scaler.inverse_transform(test_data)
print('test_data_actual_scale shape', test_data_actual_scale.shape)
test_data_actual_pollution=test_data_actual_scale[22:len(test_X)+22,0]
#test_data_actual_pollution=test_data_actual_scale[0:30,0]
print(test_data_actual_pollution.shape)
# Out:
# rescaled_prediction shape (8328, 2)
# (8328,)
# test_data_actual_scale shape (8352, 1)
# (8328,)

# %%
plt.figure(figsize=(30,6))  
plt.plot(test_data_actual_pollution , color = 'red', label = 'Actual Pollution level')
plt.plot(rescaled_prediction_pollution, color= 'green', label = 'Predicted Pollution level')

plt.title("Air Pollution Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("Pollution level")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(rescaled_prediction_pollution,test_data_actual_pollution))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 14.586

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(test_data_actual_pollution,rescaled_prediction_pollution)
print('Test MAE: %.3f' % mae)
# Out:
# Test MAE: 11.835

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(test_data_actual_pollution,rescaled_prediction_pollution)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAPE: 0.478

# %%
df1=pd.DataFrame()
df1['actual'] = pd.DataFrame(test_data_actual_pollution)
df1['predicted']=pd.DataFrame(rescaled_prediction_pollution)
plt.scatter(df1['actual'],df1['predicted'])
plt.plot([0,df1['actual'].max()],[0,df1['predicted'].max()],color='red')

# %% [markdown]
# # train

# %%
from keras.layers import concatenate
print(train_data.shape)
train1=train_data[24:,:]
print(train1.shape)
print(type(train1),type(prediction_train))
pri1=concatenate((prediction_train,train1),axis=1)
# Out:
# (33405, 1)
# (33381, 1)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
rescaled_prediction = scaler.inverse_transform(pri1)
print('rescaled_prediction shape', rescaled_prediction.shape)
#print(rescaled_prediction[-5:,0])
#print(rescaled_prediction[:,0])
rescaled_prediction_pollution=rescaled_prediction[:len(train_X),0]
print(rescaled_prediction_pollution.shape)
train_data_actual_scale=scaler.inverse_transform(train_data)
print('train_data_actual_scale shape', train_data_actual_scale.shape)
train_data_actual_pollution=train_data_actual_scale[22:len(train_X)+22,0]
#train_data_actual_pollution=train_data_actual_scale[0:30,0]
print(train_data_actual_pollution.shape)
# Out:
# rescaled_prediction shape (33381, 2)
# (33381,)
# train_data_actual_scale shape (33405, 1)
# (33381,)

# %%
plt.figure(figsize=(30,6))  
plt.plot(train_data_actual_pollution , color = 'red', label = 'Actual Pollution level')
plt.plot(rescaled_prediction_pollution, color= 'green', label = 'Predicted Pollution level')

plt.title("Air Pollution Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("Pollution level")
plt.legend()
plt.show()

# %%
rmse = sqrt(mean_squared_error(rescaled_prediction_pollution,train_data_actual_pollution))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 15.344

# %%
mae=mean_absolute_error(train_data_actual_pollution,rescaled_prediction_pollution)
print('Train MAE: %.3f' % mae)
# Out:
# Train MAE: 12.146

# %%
mape=mean_absolute_percentage_error(train_data_actual_pollution,rescaled_prediction_pollution)
print('Train MAPE: %.3f' % mape)
# Out:
# Train MAPE: 6361552068895.787

# %%
df1=pd.DataFrame()
df1['actual'] = pd.DataFrame(test_data_actual_pollution)
df1['predicted']=pd.DataFrame(rescaled_prediction_pollution)
plt.scatter(df1['actual'],df1['predicted'])
plt.plot([0,df1['actual'].max()],[0,df1['predicted'].max()],color='red')
