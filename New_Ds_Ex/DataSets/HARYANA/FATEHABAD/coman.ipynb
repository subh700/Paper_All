# %%
import pandas as pd
import numpy as np
import glob
import time


from pycaret.time_series import *

# %%
file=glob.glob('*INDEX*.csv')
file
# Out:
# ['H_Fate_1_1_19-2_12_22-*32* (copy)_INDEX_Median.csv']

# %%
li=[]

# %%
for fd in file:
    df=pd.read_csv(fd,index_col=None,header=0)
    li.append(df)
df
# Out:
#                       DATE   PM2.5
# 0      2019-01-09 10:00:00  107.92
# 1      2019-01-09 11:00:00   49.01
# 2      2019-01-09 12:00:00   49.01
# 3      2019-01-09 13:00:00   49.01
# 4      2019-01-09 14:00:00   61.75
# ...                    ...     ...
# 34155  2022-12-02 13:00:00   95.20
# 34156  2022-12-02 14:00:00   87.90
# 34157  2022-12-02 15:00:00   75.20
# 34158  2022-12-02 16:00:00   71.05
# 34159  2022-12-02 17:00:00   99.50
#
# [34160 rows x 2 columns]

# %%
df['DATE']=pd.DatetimeIndex(df['DATE'])

# %%
df=df.set_index('DATE')
df
# Out:
#                       PM2.5
# DATE
# 2019-01-09 10:00:00  107.92
# 2019-01-09 11:00:00   49.01
# 2019-01-09 12:00:00   49.01
# 2019-01-09 13:00:00   49.01
# 2019-01-09 14:00:00   61.75
# ...                     ...
# 2022-12-02 13:00:00   95.20
# 2022-12-02 14:00:00   87.90
# 2022-12-02 15:00:00   75.20
# 2022-12-02 16:00:00   71.05
# 2022-12-02 17:00:00   99.50
#
# [34160 rows x 1 columns]

# %%
s = setup(df, fh = 3426, fold = 5, session_id = 123)
# Out:
# <style type="text/css">
# #T_937df_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_937df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_937df_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_937df_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_937df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_937df_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_937df_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_937df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_937df_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_937df_row1_col1" class="data row1 col1" >PM2.5</td>
#     </tr>
#     <tr>
#       <th id="T_937df_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                                           22:47:42
# Status                                       Fitting 5 Folds
# Estimator  Random Forest w/ Cond. Deseasonalize & Detrending
# <style type="text/css">
# #T_d7d82 th {
#   text-align: left;
# }
# ...

# %%
plot_model()

# %%
plot_model(plot='ts')
