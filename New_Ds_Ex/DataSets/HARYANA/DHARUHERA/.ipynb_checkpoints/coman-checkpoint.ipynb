# %%
import pandas as pd
import numpy as np
import glob
import time


from pycaret.time_series import *

# %%
file=glob.glob('*INDEX*.csv')
file
# Out:
# ['H_Char_1_3_20-2_12_22-*58* (copy)_INDEX_Mean.csv']

# %%
li=[]

# %%
for fd in file:
    df=pd.read_csv(fd,index_col=None,header=0)
    li.append(df)
df
# Out:
#                       DATE   PM2.5
# 0      2020-03-03 15:00:00   68.28
# 1      2020-03-03 16:00:00   54.98
# 2      2020-03-03 17:00:00   50.02
# 3      2020-03-03 18:00:00   86.07
# 4      2020-03-03 19:00:00   98.34
# ...                    ...     ...
# 24094  2022-12-02 13:00:00  100.67
# 24095  2022-12-02 14:00:00   98.97
# 24096  2022-12-02 15:00:00   89.00
# 24097  2022-12-02 16:00:00   89.38
# 24098  2022-12-02 17:00:00   87.45
#
# [24099 rows x 2 columns]

# %%
df['DATE']=pd.DatetimeIndex(df['DATE'])

# %%
df=df.set_index('DATE')
df
# Out:
#                       PM2.5
# DATE
# 2020-03-03 15:00:00   68.28
# 2020-03-03 16:00:00   54.98
# 2020-03-03 17:00:00   50.02
# 2020-03-03 18:00:00   86.07
# 2020-03-03 19:00:00   98.34
# ...                     ...
# 2022-12-02 13:00:00  100.67
# 2022-12-02 14:00:00   98.97
# 2022-12-02 15:00:00   89.00
# 2022-12-02 16:00:00   89.38
# 2022-12-02 17:00:00   87.45
#
# [24099 rows x 1 columns]

# %%
s = setup(df, fh = 3, fold = 5, session_id = 123)
# Out:
# <style type="text/css">
# #T_dd5d5_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dd5d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd5d5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dd5d5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd5d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd5d5_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_dd5d5_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd5d5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dd5d5_row1_col1" class="data row1 col1" >PM2.5</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd5d5_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_dd5d5_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd5d5_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_dd5d5_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd5d5_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_dd5d5_row4_col1" class="data row4 col1" >(24099, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd5d5_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_dd5d5_row5_col1" class="data row5 col1" >(24099, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd5d5_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_dd5d5_row6_col1" class="data row6 col1" >(24096, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd5d5_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_dd5d5_row7_col1" class="data row7 col1" >(3, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd5d5_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_dd5d5_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd5d5_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_dd5d5_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dd5d5_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_dd5d5_row10_col1" class="data row10 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dd5d5_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_dd5d5_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dd5d5_row12_col0" class="data row12 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_dd5d5_row12_col1" class="data row12 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dd5d5_row13_col0" class="data row13 col0" >Seasonality Present</td>
#       <td id="T_dd5d5_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dd5d5_row14_col0" class="data row14 col0" >Seasonalities Detected</td>
#       <td id="T_dd5d5_row14_col1" class="data row14 col1" >[24]</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dd5d5_row15_col0" class="data row15 col0" >Primary Seasonality</td>
#       <td id="T_dd5d5_row15_col1" class="data row15 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dd5d5_row16_col0" class="data row16 col0" >Target Strictly Positive</td>
#       <td id="T_dd5d5_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dd5d5_row17_col0" class="data row17 col0" >Target White Noise</td>
#       <td id="T_dd5d5_row17_col1" class="data row17 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dd5d5_row18_col0" class="data row18 col0" >Recommended d</td>
#       <td id="T_dd5d5_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dd5d5_row19_col0" class="data row19 col0" >Recommended Seasonal D</td>
#       <td id="T_dd5d5_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dd5d5_row20_col0" class="data row20 col0" >Preprocess</td>
#       <td id="T_dd5d5_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_dd5d5_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_dd5d5_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_dd5d5_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_dd5d5_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_dd5d5_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_dd5d5_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_dd5d5_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_dd5d5_row24_col1" class="data row24 col1" >ts-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dd5d5_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_dd5d5_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_dd5d5_row25_col1" class="data row25 col1" >152c</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6b5a3 th {
#   text-align: left;
# }
# #T_6b5a3_row0_col0, #T_6b5a3_row1_col0, #T_6b5a3_row1_col1, #T_6b5a3_row1_col2, #T_6b5a3_row1_col3, #T_6b5a3_row1_col4, #T_6b5a3_row1_col5, #T_6b5a3_row1_col6, #T_6b5a3_row1_col7, #T_6b5a3_row2_col0, #T_6b5a3_row2_col1, #T_6b5a3_row2_col2, #T_6b5a3_row2_col3, #T_6b5a3_row2_col4, #T_6b5a3_row2_col5, #T_6b5a3_row2_col6, #T_6b5a3_row2_col7, #T_6b5a3_row3_col0, #T_6b5a3_row3_col1, #T_6b5a3_row3_col2, #T_6b5a3_row3_col3, #T_6b5a3_row3_col4, #T_6b5a3_row3_col5, #T_6b5a3_row3_col6, #T_6b5a3_row3_col7, #T_6b5a3_row4_col0, #T_6b5a3_row4_col1, #T_6b5a3_row4_col2, #T_6b5a3_row4_col3, #T_6b5a3_row4_col4, #T_6b5a3_row4_col5, #T_6b5a3_row4_col6, #T_6b5a3_row4_col7, #T_6b5a3_row5_col0, #T_6b5a3_row5_col1, #T_6b5a3_row5_col2, #T_6b5a3_row5_col3, #T_6b5a3_row5_col4, #T_6b5a3_row5_col5, #T_6b5a3_row5_col6, #T_6b5a3_row5_col7, #T_6b5a3_row6_col0, #T_6b5a3_row6_col1, #T_6b5a3_row6_col2, #T_6b5a3_row6_col3, #T_6b5a3_row6_col4, #T_6b5a3_row6_col5, #T_6b5a3_row6_col6, #T_6b5a3_row6_col7, #T_6b5a3_row7_col0, #T_6b5a3_row7_col1, #T_6b5a3_row7_col2, #T_6b5a3_row7_col3, #T_6b5a3_row7_col4, #T_6b5a3_row7_col5, #T_6b5a3_row7_col6, #T_6b5a3_row7_col7, #T_6b5a3_row8_col0, #T_6b5a3_row8_col1, #T_6b5a3_row8_col2, #T_6b5a3_row8_col3, #T_6b5a3_row8_col4, #T_6b5a3_row8_col5, #T_6b5a3_row8_col6, #T_6b5a3_row8_col7, #T_6b5a3_row9_col0, #T_6b5a3_row9_col1, #T_6b5a3_row9_col2, #T_6b5a3_row9_col3, #T_6b5a3_row9_col4, #T_6b5a3_row9_col5, #T_6b5a3_row9_col6, #T_6b5a3_row9_col7, #T_6b5a3_row10_col0, #T_6b5a3_row10_col1, #T_6b5a3_row10_col2, #T_6b5a3_row10_col3, #T_6b5a3_row10_col4, #T_6b5a3_row10_col5, #T_6b5a3_row10_col6, #T_6b5a3_row10_col7, #T_6b5a3_row11_col0, #T_6b5a3_row11_col1, #T_6b5a3_row11_col2, #T_6b5a3_row11_col3, #T_6b5a3_row11_col4, #T_6b5a3_row11_col5, #T_6b5a3_row11_col6, #T_6b5a3_row11_col7, #T_6b5a3_row12_col0, #T_6b5a3_row12_col1, #T_6b5a3_row12_col2, #T_6b5a3_row12_col3, #T_6b5a3_row12_col4, #T_6b5a3_row12_col5, #T_6b5a3_row12_col6, #T_6b5a3_row12_col7, #T_6b5a3_row13_col0, #T_6b5a3_row13_col1, #T_6b5a3_row13_col2, #T_6b5a3
row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6b5a3_row0_col8, #T_6b5a3_row1_col8, #T_6b5a3_row2_col8, #T_6b5a3_row3_col8, #T_6b5a3_row4_col8, #T_6b5a3_row5_col8, #T_6b5a3_row6_col8, #T_6b5a3_row7_col8, #T_6b5a3_row8_col8, #T_6b5a3_row9_col8, #T_6b5a3_row10_col8, #T_6b5a3_row11_col8, #T_6b5a3_row12_col8, #T_6b5a3_row13_col8, #T_6b5a3_row14_col8, #T_6b5a3_row15_col8, #T_6b5a3_row16_col8, #T_6b5a3_row18_col8, #T_6b5a3_row19_col8, #T_6b5a3_row20_col8, #T_6b5a3_row21_col8, #T_6b5a3_row22_col8, #T_6b5a3_row23_col8, #T_6b5a3_row24_col8, #T_6b5a3_row25_col8, #T_6b5a3_row26_col8, #T_6b5a3_row27_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6b5a3_row17_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6b5a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b5a3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6b5a3_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_6b5a3_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_6b5a3_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_6b5a3_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_6b5a3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_6b5a3_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_6b5a3_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_6b5a3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b5a3_level0_row0" class="row_heading level0 row0" >catboost_cds_dt</th>
#       <td id="T_6b5a3_row0_col0" class="data row0 col0" >CatBoost Regressor w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_6b5a3_row0_col1" class="data row0 col1" >0.3195</td>
#       <td id="T_6b5a3_row0_col2" class="data row0 col2" >0.2122</td>
#       <td id="T_6b5a3_row0_col3" class="data row0 col3" >11.6509</td>
#       <td id="T_6b5a3_row0_col4" class="data row0 col4" >13.2351</td>
#       <td id="T_6b5a3_row0_col5" class="data row0 col5" >0.0905</td>
#       <td id="T_6b5a3_row0_col6" class="data row0 col6" >0.0889</td>
#       <td id="T_6b5a3_row0_col7" class="data row0 col7" >-0.1420</td>
#       <td id="T_6b5a3_row0_col8" class="data row0 col8" >21.4920</td>
#     </tr>
#     <tr>
#       <th id="T_6b5a3_level0_row1" class="row_heading level0 row1" >xgboost_cds_dt</th>
#       <td id="T_6b5a3_row1_col0" class="data row1 col0" >Extreme Gradient Boosting w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_6b5a3_row1_col1" class="data row1 col1" >0.3798</td>
#       <td id="T_6b5a3_row1_col2" class="data row1 col2" >0.2424</td>
#       <td id="T_6b5a3_row1_col3" class="data row1 col3" >13.8460</td>
#       <td id="T_6b5a3_row1_col4" class="data row1 col4" >15.1220</td>
#       <td id="T_6b5a3_row1_col5" class="data row1 col5" >0.1092</td>
#       <td id="T_6b5a3_row1_col6" class="data row1 col6" >0.1073</td>
#       <td id="T_6b5a3_row1_col7" class="data row1 col7" >-0.7196</td>
#       <td id="T_6b5a3_row1_col8" class="data row1 col8" >20.0060</td>
#     </tr>
#     <tr>
#       <th id="T_6b5a3_level0_row2" class="row_heading level0 row2" >et_cds_dt</th>
#       <td id="T_6b5a3_row2_col0" class

# %%
plot_model()

# %%
plot_model(plot='ts')
