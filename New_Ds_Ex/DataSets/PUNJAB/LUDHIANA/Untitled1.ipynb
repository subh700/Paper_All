# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('H_Ludh_1_5_17-_2_12_22-*07* (copy)_INDEX_Mean.csv')
df.head()

# Updating the header
df.columns=["DATE","PM"]
df.head()
df.describe()
df.set_index('DATE',inplace=True)

from pylab import rcParams
rcParams['figure.figsize'] = 15, 7
df.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(df['PM'])

# %%
def adfuller_test(PM):
    result=adfuller(PM)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

if result[1] <= 0.05:
    print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
else:
    print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(df['PM'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 7
#       4     for value,label in zip(result,labels):
#       5         print(label+' : '+str(value) )
# ----> 7 if result[1] <= 0.05:
#       8     print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
#       9 else:
#
# NameError: name 'result' is not defined
